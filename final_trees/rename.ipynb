# %%
import pandas as pd
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

pth = '/home/yulia/parampampam/'

# %% [markdown]
# #### SSU ML tree

# %%
stats = 'final_trees/SSU_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'trees/18S/tree_6/ml/RAxML_bipartitions.result', 'r') as in_f:
    with open(pth+'final_trees/ml/SSU/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el]
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/ml/SSU/RAxML_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/ml/SSU/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/ml/SSU/RAxML_ete_tree.newick', quoted_node_names=True)

leafs = t.get_leaf_names()
leafs.remove('Paramecium nephridiatum dup BMS16-23 MK764889.1')
t.prune(leafs)

for node in t.traverse():
    node.img_style['size'] = 0

style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 10000
t.show(tree_style=ts)
t.render(pth+'final_trees/ml/SSU/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)

# %% [markdown]
# #### SSU MrB tree

# %%
stats = 'final_trees/SSU_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'trees/18S/tree_6/mb/con_50_majrule', 'r') as in_f:
    with open(pth+'final_trees/mb/SSU/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el]
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/mb/SSU/mb_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/mb/SSU/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/mb/SSU/mb_ete_tree.newick', quoted_node_names=True)

leafs = t.get_leaf_names()
leafs.remove('Paramecium nephridiatum dup BMS16-23 MK764889.1')
t.prune(leafs)

for node in t.traverse():
    node.img_style['size'] = 0
    
style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 10000
t.show(tree_style=ts)
t.render(pth+'final_trees/mb/SSU/mb_ete_tree.pdf', dpi=1200, tree_style=ts)

# %% [markdown]
# #### ITS ML tree

# %%
stats = 'final_trees/ITS_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'trees/ITS/tree_6/ml/RAxML_bipartitions.result', 'r') as in_f:
    with open(pth+'final_trees/ml/ITS/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el]
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/ml/ITS/RAxML_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/ml/ITS/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/ml/ITS/RAxML_ete_tree.newick', quoted_node_names=True)

for node in t.traverse():
    node.img_style['size'] = 0

style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 5000
t.show(tree_style=ts)
t.render(pth+'final_trees/ml/ITS/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)

# %% [markdown]
# #### ITS MrB tree

# %%
stats = 'final_trees/ITS_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'trees/ITS/tree_6/mb/con_50_majrule', 'r') as in_f:
    with open(pth+'final_trees/mb/ITS/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el].strip()
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/mb/ITS/mb_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/mb/ITS/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/mb/ITS/mb_ete_tree.newick', quoted_node_names=True)

for node in t.traverse():
    node.img_style['size'] = 0
    
style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 3000
t.show(tree_style=ts)
t.render(pth+'final_trees/mb/ITS/mb_ete_tree.pdf', dpi=1200, tree_style=ts)

# %% [markdown]
# #### COI ML tree

# %%
stats = 'final_trees/COI_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'final_trees/ml/COI/RAxML_bipartitions.result', 'r') as in_f:
    with open(pth+'final_trees/ml/COI/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el]
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/ml/COI/RAxML_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/ml/COI/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/ml/COI/RAxML_ete_tree.newick', quoted_node_names=True)

for node in t.traverse():
    node.img_style['size'] = 0

style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 1000
t.show(tree_style=ts)
t.render(pth+'final_trees/ml/COI/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [[722.9648800000001, 66.5, 726.9648800000001, 70.5, 27, None],
#   [699.8952, 96.5, 703.8952, 100.5, 29, None],
#   [698.8952, 126.5, 702.8952, 130.5, 32, None],
#   [698.8952, 141.5, 702.8952, 145.5, 33, None],
#   [675.96424, 156.5, 679.96424, 160.5, 34, None],
#   [696.6824, 276.5, 700.6824, 280.5, 50, None],
#   [689.6824, 291.5, 693.6824, 295.5, 51, None],
#   [677.96748, 321.5, 681.96748, 325.5, 54, None],
#   [684.0946, 351.5, 688.0946, 355.5, 61, None],
#   [684.0946, 366.5, 688.0946, 370.5, 62, None],
#   [672.6459600000001, 396.5, 676.6459600000001, 400.5, 65, None],
#   [662.7631, 456.5, 666.7631, 460.5, 71, None],
#   [651.0946, 471.5, 655.0946, 475.5, 73, None],
#   [651.0946, 486.5, 655.0946, 490.5, 74, None],
#   [744.1780200000001, 516.5, 748.1780200000001, 520.5, 84, None],
#   [745.8332, 531.5, 749.8332, 535.5, 85, None],
#   [700.9081, 576.5, 704.9081, 580.5, 88, None],
#   [693.9081, 591.5, 697.9081, 595.5, 89, None],
#   [682.4973600000001, 606.5, 686.4973600000001, 610.5, 90, None],
#   [724.81256, 621.5, 728.81256, 625.5, 94, None],
#   [641.6416999999999, 846.5, 645.6416999999999, 850.5, 120, None],
#   [637.112, 1146.5, 641.112, 1150.5, 164, None],
#   [608.2475499999999, 1281.5, 612.2475499999999, 1285.5, 179, None],
#   [602.0781999999999, 1296.5, 606.0781999999999, 1300.5, 181, None],
#   [629.9079999999999, 1341.5, 633.9079999999999, 1345.5, 187, None],
#   [589.11709, 1386.5, 593.11709, 1390.5, 190, None]],
#  'faces': [[1.0, 1588.7737700939178, 20.0, 1601.7737700939178, 0, '100'],
#   [43.3476, 1547.1725401878357, 50.3476, 1560.1725401878357, 1, '1'],
#   [68.3562, 1510.8450803756714, 81.3562, 1523.8450803756714, 2, '13'],
#   [159.21769999999998,
#    1460.6901607513428,
#    172.21769999999998,
#    1473.6901607513428,
#    3,
#    '29'],
#   [255.79019999999997,
#    1382.8803215026855,
#    268.79019999999997,
#    1395.8803215026855,
#    4,
#    '47'],
#   [407.2222, 1269.448143005371, 420.2222, 1282.448143005371, 5, '95'],
#   [460.577, 1135.3962860107422, 473.577, 1148.3962860107422, 6, '60'],
#   [483.1364, 928.2300720214844, 496.1364, 941.2300720214844, 7, '39'],
#   [499.5408, 661.1950073242188, 512.5408, 674.1950073242188, 8, '34'],
#   [587.5936, 489.5638427734375, 606.5936, 502.5638427734375, 9, '100'],
#   [606.5936, 349.944091796875, 619.5936, 362.944091796875, 10, '59'],
#   [619.5936, 250.29443359375, 632.5936, 263.29443359375, 11, '38'],
#   [632.5936, 187.8701171875, 645.5936, 200.8701171875, 12, '55'],
#   [647.3942000000001,
#    155.365234375,
#    660.3942000000001,
#    168.365234375,
#    13,
#    '97'],
#   [660.3942000000001, 137.23046875, 673.3942000000001, 150.23046875, 14, '61'],
#   [673.3942000000001, 115.9609375, 686.3942000000001, 128.9609375, 15, '23'],
#   [686.3942000000001, 95.921875, 693.3942000000001, 108.921875, 16, '0'],
#   [693.3942000000001, 78.34375, 700.3942000000001, 91.34375, 17, '1'],
#   [700.3942000000001, 58.1875, 707.3942000000001, 71.1875, 18, '7'],
#   [707.3942000000001, 40.375, 720.3942000000001, 53.375, 19, '97'],
#   [720.3942000000001, 27.25, 733.3942000000001, 40.25, 20, '82'],
#   [733.3942000000001, 16.0, 746.3942000000001, 29.0, 21, '99'],
#   [746.3952,
#    1.0,
#    1070.3952,
#    16.0,
#    22,
#    'Paramecium multimicronucleatum AMA5-7 MN264578.1'],
#   [746.3952, 16.0, 951.3952, 31.0, 23, 'Paramecium sp. G1-2 MN264582.1'],
#   [735.1257800000001,
#    31.0,
#    1047.12578,
#    46.0,
#    24,
#    'Paramecium multimicronucleatum AH1-5 AM072768.1'],
#   [720.3952,
#    46.0,
#    1037.3952,
#    61.0,
#    25,
#    'Paramecium multimicronucleatum ISN-11 AM072769.1'],
#   [707.3942000000001, 76.0, 720.3942000000001, 89.0, 26, '18'],
#   [726.4648800000001,
#    61.0,
#    968.4648800000001,
#    76.0,
#    27,
#    'Paramecium multimicronucleatum ThK-16'],
#   [721.92699,
#    76.0,
#    1075.92699,
#    91.0,
#    28,
#    'Paramecium multimicronucleatum haplotype C7 MH544195.1'],
#   [703.3952,
#    91.0,
#    946.3952,
#    106.0,
#    29,
#    'Paramecium multimicronucleatum CyP5-3'],
#   [693.3952,
#    106.0,
#    1003.3952,
#    121.0,
#    30,
#    'Paramecium multimicronucleatum C1(1) MH544185.1'],
#   [686.3942000000001, 136.0, 699.3942000000001, 149.0, 31, '27'],
#   [702.3952,
#    121.0,
#    941.3952,
#    136.0,
#    32,
#    'Paramecium multimicronucleatum ID1-13'],
#   [702.3952,
#    136.0,
#    941.3952,
#    151.0,
#    33,
#    'Paramecium multimicronucleatum MSA-5'],
#   [679.46424,
#    151.0,
#    921.46424,
#    166.0,
#    34,
#    'Paramecium multimicronucleatum Ns2-16'],
#   [663.4554800000001,
#    166.0,
#    957.4554800000001,
#    181.0,
#    35,
#    'Paramecium multimicronucleatum C6 MH544194.1'],
#   [645.5936, 220.375, 658.5936, 233.375, 36, '44'],
#   [658.5936, 207.25, 671.5936, 220.25, 37, '14'],
#   [671.5936, 196.0, 684.5936, 209.0, 38, '15'],
#   [684.5946,
#    181.0,
#    994.5946,
#    196.0,
#    39,
#    'Paramecium multimicronucleatum C3(2) MH544191.1'],
#   [727.6821,
#    196.0,
#    1041.6821,
#    211.0,
#    40,
#    'Paramecium multimicronucleatum BSP-7 AM072772.1'],
#   [671.5946,
#    211.0,
#    981.5946,
#    226.0,
#    41,
#    'Paramecium multimicronucleatum C3(1) MH544190.1'],
#   [660.7565400000001,
#    226.0,
#    982.7565400000001,
#    241.0,
#    42,
#    'Paramecium multimicronucleatum SPb63-2 JF741248.1'],
#   [645.1814, 312.71875, 664.1814, 325.71875, 43, '100'],
#   [664.1814, 294.4375, 677.1814, 307.4375, 44, '60'],
#   [677.1814, 280.375, 690.1814, 293.375, 45, '55'],
#   [690.1814, 267.25, 697.1814, 280.25, 46, '7'],
#   [697.1814, 256.0, 710.1814, 269.0, 47, '21'],
#   [710.1824,
#    241.0,
#    1011.1824,
#    256.0,
#    48,
#    'Paramecium multimicronucleatum C12 MH544200.1'],
#   [710.1824,
#    256.0,
#    1100.1824000000001,
#    271.0,
#    49,
#    'Paramecium multimicronucleatum OLI-Parame-mult-03 FJ905145.1'],
#   [700.1824,
#    271.0,
#    931.1824,
#    286.0,
#    50,
#    'Paramecium multimicronucleatum IP2-1'],
#   [693.1824,
#    286.0,
#    936.1824,
#    301.0,
#    51,
#    'Paramecium multimicronucleatum E59-1B'],
#   [677.1824,
#    301.0,
#    996.1824,
#    316.0,
#    52,
#    'Paramecium multimicronucleatum Chp5-3 MT078147.1'],
#   [664.1814, 331.0, 677.1814, 344.0, 53, '58'],
#   [681.46748,
#    316.0,
#    925.46748,
#    331.0,
#    54,
#    'Paramecium multimicronucleatum ChP3-4'],
#   [680.65007,
#    331.0,
#    990.65007,
#    346.0,
#    55,
#    'Paramecium multimicronucleatum MB2-5 JF741245.1'],
#   [619.5936, 449.59375, 632.5936, 462.59375, 56, '74'],
#   [632.5936, 418.1875, 645.5936, 431.1875, 57, '71'],
#   [645.5936, 389.125, 658.5936, 402.125, 58, '92'],
#   [658.5936, 372.25, 671.5936, 385.25, 59, '87'],
#   [671.5936, 361.0, 684.5936, 374.0, 60, '85'],
#   [687.5946,
#    346.0,
#    950.5946,
#    361.0,
#    61,
#    'Paramecium multimicronucleatum SMM80-11'],
#   [687.5946,
#    361.0,
#    926.5946,
#    376.0,
#    62,
#    'Paramecium multimicronucleatum R51-6 '],
#   [674.6878300000001,
#    376.0,
#    978.6878300000001,
#    391.0,
#    63,
#    'Paramecium multimicronucleatum K4-2 MT078146.1'],
#   [658.5936, 406.0, 671.5936, 419.0, 64, '83'],
#   [676.1459600000001,
#    391.0,
#    927.1459600000001,
#    406.0,
#    65,
#    'Paramecium multimicronucleatum ChP10-2'],
#   [671.5946,
#    406.0,
#    980.5946,
#    421.0,
#    66,
#    'Paramecium multimicronucleatum L72-1 MT078145.1'],
#   [645.5936, 447.25, 658.5936, 460.25, 67, '67'],
#   [658.5936, 436.0, 671.5936, 449.0, 68, '64'],
#   [673.3506,
#    421.0,
#    972.3506,
#    436.0,
#    69,
#    'Paramecium multimicronucleatum Wg8 JF741271.1'],
#   [671.5946,
#    436.0,
#    1014.5946,
#    451.0,
#    70,
#    'P.multimicronucleatum Peniche31(ParameciumDB)Portugal'],
#   [666.2631,
#    451.0,
#    908.2631,
#    466.0,
#    71,
#    'Paramecium multimicronucleatum OmN-1'],
#   [632.5936, 481.0, 651.5936, 494.0, 72, '100'],
#   [654.5946,
#    466.0,
#    890.5946,
#    481.0,
#    73,
#    'Paramecium multimicronucleatum SK6-3'],
#   [654.5946, 481.0, 877.5946, 496.0, 74, 'Paramecium multimicronucleatum LB2'],
#   [623.0988, 629.18359375, 642.0988, 642.18359375, 75, '100'],
#   [662.4071, 593.6171875, 681.4071, 606.6171875, 76, '100'],
#   [681.4071, 578.734375, 694.4071, 591.734375, 77, '49'],
#   [694.4071, 563.96875, 701.4071, 576.96875, 78, '9'],
#   [701.4071, 549.4375, 708.4071, 562.4375, 79, '4'],
#   [708.4071, 535.375, 715.4071, 548.375, 80, '7'],
#   [715.4071, 522.25, 728.4071, 535.25, 81, '47'],
#   [728.4071, 511.0, 741.4071, 524.0, 82, '91'],
#   [741.4081,
#    496.0,
#    1037.4081,
#    511.0,
#    83,
#    'Paramecium multimicronucleatum AM MN264577.1'],
#   [747.6780200000001,
#    511.0,
#    887.6780200000001,
#    526.0,
#    84,
#    'Paramecium fokini PP-2'],
#   [749.3332, 526.0, 893.3332, 541.0, 85, 'Paramecium fokini OP13'],
#   [715.4081,
#    541.0,
#    1025.4081,
#    556.0,
#    86,
#    'Paramecium multimicronucleatum T42-1 MT078148.1'],
#   [708.4081,
#    556.0,
#    1040.4081,
#    571.0,
#    87,
#    'Paramecium multimicronucleatum SMM81-1 MT078149.1'],
#   [704.4081, 571.0, 929.4081, 586.0, 88, 'Paramecium multimicronucleatum M04'],
#   [697.4081, 586.0, 861.4081, 601.0, 89, 'Paramecium fokini CyL3-21 '],
#   [685.9973600000001,
#    601.0,
#    831.9973600000001,
#    616.0,
#    90,
#    'Paramecium fokini PL4-1'],
#   [662.0692, 664.75, 681.0692, 677.75, 91, '100'],
#   [691.7691, 646.0, 704.7691, 659.0, 92, '99'],
#   [704.7691, 631.0, 723.7691, 644.0, 93, '100'],
#   [728.31256, 616.0, 874.31256, 631.0, 94, 'Paramecium fokini AB9-8'],
#   [725.35755,
#    631.0,
#    1015.35755,
#    646.0,
#    95,
#    'Paramecium multimicronucleatum BR JF304189.1'],
#   [704.7691, 661.0, 717.7691, 674.0, 96, '97'],
#   [717.7701,
#    646.0,
#    1107.7701,
#    661.0,
#    97,
#    'Paramecium multimicronucleatum OLI-Parame-mult-02 FJ905144.1'],
#   [717.7701,
#    661.0,
#    1036.7701,
#    676.0,
#    98,
#    'Paramecium bursaria OLI-Parame-burs-01 FJ905152.1'],
#   [700.7635,
#    676.0,
#    1043.7635,
#    691.0,
#    99,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK806287.1'],
#   [536.4915, 832.826171875, 549.4915, 845.826171875, 100, '73'],
#   [804.3525, 817.15234375, 823.3525, 830.15234375, 101, '100'],
#   [927.1575, 800.8046875, 940.1575, 813.8046875, 102, '89'],
#   [954.8596, 783.109375, 967.8596, 796.109375, 103, '32'],
#   [969.2357, 762.71875, 982.2357, 775.71875, 104, '22'],
#   [999.1139999999999, 744.4375, 1012.1139999999999, 757.4375, 105, '46'],
#   [1022.1874999999999, 730.375, 1035.1875, 743.375, 106, '37'],
#   [1036.1772, 717.25, 1049.1772, 730.25, 107, '43'],
#   [1063.913, 706.0, 1076.913, 719.0, 108, '53'],
#   [1164.464,
#    691.0,
#    1420.464,
#    706.0,
#    109,
#    ' 223 PDECA.223.MITO.1.G040 P.decaurelia'],
#   [1221.738,
#    706.0,
#    1435.738,
#    721.0,
#    110,
#    'Paramecium tetraurelia 51 M15281.1'],
#   [1118.9851,
#    721.0,
#    1390.9851,
#    736.0,
#    111,
#    ' 274 PDODE.274.MITO.1.G040 P.dodecaurelia'],
#   [1171.1765,
#    736.0,
#    1452.1765,
#    751.0,
#    112,
#    ' AZ8-4 PSEXA.AZ8-4.MITO.1.G040 P.sexaurelia'],
#   [1119.2369999999999,
#    751.0,
#    1367.2369999999999,
#    766.0,
#    113,
#    'V1-4 PBIAU.V1-4.MITO.1.G040 P.biaurelia'],
#   [995.8487, 781.0, 1008.8487, 794.0, 114, '39'],
#   [1140.0297,
#    766.0,
#    1418.0297,
#    781.0,
#    115,
#    'N1A PQUAD.NiA.MITO.1.G040 P.quadecaurelia'],
#   [1081.7432,
#    781.0,
#    1324.7432,
#    796.0,
#    116,
#    'TE PNOVA.TE.MITO.1.G040 P.novaurelia'],
#   [1056.533,
#    796.0,
#    1298.533,
#    811.0,
#    117,
#    'Paramecium septaurelia 227 MT318934.1'],
#   [992.9994,
#    811.0,
#    1273.9994000000002,
#    826.0,
#    118,
#    'AZ9-3 PPRIM.AZ9-3.MITO.1.G040 P.primaurelia'],
#   [895.8561,
#    826.0,
#    1114.8561,
#    841.0,
#    119,
#    'M PJENN.M.MITO.1.G040 P.jenningsi'],
#   [645.1416999999999,
#    841.0,
#    766.1416999999999,
#    856.0,
#    120,
#    'Paramecium sp. FT8'],
#   [506.3689, 1195.26513671875, 519.3688999999999, 1208.26513671875, 121, '51'],
#   [519.3688999999999,
#    1148.2802734375,
#    532.3688999999999,
#    1161.2802734375,
#    122,
#    '40'],
#   [541.7099, 1088.060546875, 554.7099, 1101.060546875, 123, '67'],
#   [568.8540999999999, 1007.875, 581.8540999999999, 1020.875, 124, '85'],
#   [581.8540999999999, 987.25, 594.8540999999999, 1000.25, 125, '45'],
#   [594.8540999999999, 961.0, 607.8540999999999, 974.0, 126, '37'],
#   [607.8540999999999, 931.0, 620.8540999999999, 944.0, 127, '81'],
#   [620.8540999999999, 904.75, 633.8540999999999, 917.75, 128, '55'],
#   [633.8540999999999, 886.0, 646.8540999999999, 899.0, 129, '53'],
#   [646.8540999999999, 871.0, 659.8540999999999, 884.0, 130, '43'],
#   [659.8550999999999,
#    856.0,
#    980.8550999999999,
#    871.0,
#    131,
#    'Paramecium caudatum RanNy1602-AP18 MG589328.1'],
#   [666.5299899999999,
#    871.0,
#    998.5299899999999,
#    886.0,
#    132,
#    'Paramecium caudatum HUN-BA PcCOI_a12 FN256277.1'],
#   [646.8540999999999, 901.0, 659.8540999999999, 914.0, 133, '61'],
#   [661.56369,
#    886.0,
#    983.56369,
#    901.0,
#    134,
#    'Paramecium multimicronucleatum GB4-26 MN264576.1'],
#   [659.8550999999999,
#    901.0,
#    908.8550999999999,
#    916.0,
#    135,
#    'Paramecium caudatum SH42 MG013510.1'],
#   [635.37952,
#    916.0,
#    862.37952,
#    931.0,
#    136,
#    'Paramecium caudatum CA JF304187.1'],
#   [620.8540999999999, 957.25, 633.8540999999999, 970.25, 137, '99'],
#   [633.8540999999999, 946.0, 646.8540999999999, 959.0, 138, '35'],
#   [646.8550999999999,
#    931.0,
#    780.8550999999999,
#    946.0,
#    139,
#    'Paramecium caudatum'],
#   [646.8550999999999,
#    946.0,
#    780.8550999999999,
#    961.0,
#    140,
#    'Paramecium caudatum'],
#   [633.8550999999999,
#    961.0,
#    965.8550999999999,
#    976.0,
#    141,
#    'Paramecium caudatum OLI-Parame-caud-02 FJ905148.1'],
#   [607.8540999999999, 991.0, 620.8540999999999, 1004.0, 142, '43'],
#   [624.6394999999999,
#    976.0,
#    879.6394999999999,
#    991.0,
#    143,
#    'Paramecium caudatum G-PL-2 FN256264.1'],
#   [629.00766,
#    991.0,
#    879.00766,
#    1006.0,
#    144,
#    'Paramecium caudatum G-E12 FN256263.1'],
#   [598.5806799999999,
#    1006.0,
#    850.5806799999999,
#    1021.0,
#    145,
#    'Paramecium caudatum SLO-R FN256281.1'],
#   [581.8550999999999,
#    1021.0,
#    835.8550999999999,
#    1036.0,
#    146,
#    'Paramecium caudatum POE-1 HQ149725.1'],
#   [585.611, 1168.24609375, 598.611, 1181.24609375, 147, '96'],
#   [598.611, 1142.9921875, 611.611, 1155.9921875, 148, '42'],
#   [611.611, 1118.734375, 624.611, 1131.734375, 149, '33'],
#   [624.611, 1103.96875, 637.611, 1116.96875, 150, '34'],
#   [637.611, 1089.4375, 650.611, 1102.4375, 151, '49'],
#   [650.611, 1075.375, 663.611, 1088.375, 152, '99'],
#   [663.611, 1062.25, 676.611, 1075.25, 153, '88'],
#   [676.611, 1051.0, 689.611, 1064.0, 154, '86'],
#   [689.612,
#    1036.0,
#    923.612,
#    1051.0,
#    155,
#    'Paramecium caudatum V-1 MT078150.1'],
#   [689.612,
#    1051.0,
#    931.612,
#    1066.0,
#    156,
#    'Paramecium caudatum K5-2 MT078151.1'],
#   [676.612,
#    1066.0,
#    1008.612,
#    1081.0,
#    157,
#    'Paramecium caudatum OLI-Parame-caud-01 FJ905142.1'],
#   [665.3408999999999,
#    1081.0,
#    1003.3408999999999,
#    1096.0,
#    158,
#    'Paramecium caudatum BRA-RIO PcCOI_b03 FN256282.1'],
#   [661.5364,
#    1096.0,
#    892.5364,
#    1111.0,
#    159,
#    'Paramecium caudatum M3 KY399443.1'],
#   [637.612,
#    1111.0,
#    887.612,
#    1126.0,
#    160,
#    'Paramecium caudatum PcC30 JX082093.1'],
#   [627.6249399999999,
#    1126.0,
#    761.6249399999999,
#    1141.0,
#    161,
#    'Paramecium caudatum'],
#   [611.611, 1167.25, 624.611, 1180.25, 162, '71'],
#   [624.611, 1156.0, 637.611, 1169.0, 163, '34'],
#   [640.612, 1141.0, 811.612, 1156.0, 164, 'Paramecium caudatum Or4-4'],
#   [639.34977,
#    1156.0,
#    957.34977,
#    1171.0,
#    165,
#    'Paramecium multimicronucleatum Kr113-3 JF741258.1'],
#   [626.11115, 1171.0, 760.11115, 1186.0, 166, 'Paramecium caudatum'],
#   [598.612,
#    1186.0,
#    848.612,
#    1201.0,
#    167,
#    'Paramecium caudatum PcC24 JX082077.1'],
#   [602.8955, 1201.0, 736.8955, 1216.0, 168, 'Paramecium caudatum'],
#   [556.9622999999999, 1242.25, 569.9622999999999, 1255.25, 169, '99'],
#   [569.9622999999999, 1231.0, 582.9622999999999, 1244.0, 170, '98'],
#   [582.9632999999999,
#    1216.0,
#    829.9632999999999,
#    1231.0,
#    171,
#    'Paramecium caudatum INL-1 HQ149723.1'],
#   [584.6835899999999,
#    1231.0,
#    832.6835899999999,
#    1246.0,
#    172,
#    'Paramecium caudatum INP-3 HQ149724.1'],
#   [569.9632999999999,
#    1246.0,
#    817.9632999999999,
#    1261.0,
#    173,
#    'Paramecium caudatum INK-1 HQ149722.1'],
#   [555.7574, 1342.5625, 568.7574, 1355.5625, 174, '99'],
#   [568.7574, 1309.75, 581.7574, 1322.75, 175, '64'],
#   [581.7574, 1291.0, 588.7574, 1304.0, 176, '3'],
#   [588.7574, 1276.0, 601.7574, 1289.0, 177, '66'],
#   [601.7583999999999,
#    1261.0,
#    722.7583999999999,
#    1276.0,
#    178,
#    'Paramecium SD11-9'],
#   [611.7475499999999,
#    1276.0,
#    763.7475499999999,
#    1291.0,
#    179,
#    'Paramecium lynni PO16-1'],
#   [588.7574, 1306.0, 595.7574, 1319.0, 180, '6'],
#   [605.5781999999999,
#    1291.0,
#    741.5781999999999,
#    1306.0,
#    181,
#    'Paramecium lynni SP-1'],
#   [597.5903, 1306.0, 810.5903, 1321.0, 182, 'Paramecium sp. CB8-2 MN264581.1'],
#   [581.7583999999999,
#    1321.0,
#    799.7583999999999,
#    1336.0,
#    183,
#    'Paramecium sp. V105-1 MN264579.1'],
#   [568.7574, 1375.375, 581.7574, 1388.375, 184, '39'],
#   [598.4069999999999, 1362.25, 617.4069999999999, 1375.25, 185, '100'],
#   [617.4069999999999, 1351.0, 630.4069999999999, 1364.0, 186, '86'],
#   [633.4079999999999,
#    1336.0,
#    794.4079999999999,
#    1351.0,
#    187,
#    'Paramecium lynni ShKm41 '],
#   [630.4079999999999,
#    1351.0,
#    961.4079999999999,
#    1366.0,
#    188,
#    'Paramecium multimicronucleatum TRB101-4 JF741263.1'],
#   [619.1788099999999,
#    1366.0,
#    950.1788099999999,
#    1381.0,
#    189,
#    'Paramecium multimicronucleatum TRB101-1 JF741262.1'],
#   [592.61709, 1381.0, 753.61709, 1396.0, 190, 'Paramecium lynni HSG3-10'],
#   [529.3481999999999,
#    1396.0,
#    786.3481999999999,
#    1411.0,
#    191,
#    'Paramecium germanicum GO1 KM091240.1'],
#   [288.15569999999997, 1496.3125, 301.15569999999997, 1509.3125, 192, '74'],
#   [336.3735, 1476.625, 349.3735, 1489.625, 193, '80'],
#   [386.0225, 1459.75, 399.0225, 1472.75, 194, '55'],
#   [679.4224999999999, 1441.0, 698.4224999999999, 1454.0, 195, '100'],
#   [698.4224999999999, 1426.0, 711.4224999999999, 1439.0, 196, '51'],
#   [712.8323599999999,
#    1411.0,
#    980.8323599999999,
#    1426.0,
#    197,
#    'Paramecium nephridiatum PnC72 JX082120.1'],
#   [715.4838399999999,
#    1426.0,
#    983.4838399999999,
#    1441.0,
#    198,
#    'Paramecium nephridiatum PnC77 JX082125.1'],
#   [698.4224999999999, 1456.0, 711.4224999999999, 1469.0, 199, '46'],
#   [712.78037,
#    1441.0,
#    980.78037,
#    1456.0,
#    200,
#    'Paramecium nephridiatum PnC43 JX082111.1'],
#   [715.4842199999998,
#    1456.0,
#    983.4842199999998,
#    1471.0,
#    201,
#    'Paramecium nephridiatum PnC75 JX082123.1'],
#   [566.6044999999999,
#    1471.0,
#    906.6044999999999,
#    1486.0,
#    202,
#    'Paramecium polycaryum OLI-Parame-poly-01 FJ905155.1 '],
#   [660.6965,
#    1486.0,
#    894.6965,
#    1501.0,
#    203,
#    'Paramecium calkinsi GN5-1 FJ905147.1'],
#   [759.9637, 1516.0, 778.9637, 1529.0, 204, '100'],
#   [778.9647,
#    1501.0,
#    1011.9647,
#    1516.0,
#    205,
#    'Paramecium chlorelligerum KX669634.1'],
#   [778.9647,
#    1516.0,
#    1069.9647,
#    1531.0,
#    206,
#    'Paramecium chlorelligerum HSG1-11 KX669632.1'],
#   [470.98569999999995,
#    1531.0,
#    678.9857,
#    1546.0,
#    207,
#    'Paramecium buetschlii KM091238.1'],
#   [182.50220000000002, 1561.0, 201.50220000000002, 1574.0, 208, '100'],
#   [298.78970000000004,
#    1546.0,
#    550.7897,
#    1561.0,
#    209,
#    'Paramecium putrinum Etu 7-4 MG589327.1'],
#   [253.95280000000002,
#    1561.0,
#    573.9528,
#    1576.0,
#    210,
#    'Paramecium putrinum OLI-Parame-putr-01 FJ905153.1'],
#   [316.7416,
#    1576.0,
#    568.7416000000001,
#    1591.0,
#    211,
#    'Paramecium duboscqui PdC95 JX082147.1'],
#   [589.604, 1630.375, 596.604, 1643.375, 212, '1'],
#   [658.5804, 1617.25, 677.5804, 1630.25, 213, '100'],
#   [677.5804, 1606.0, 690.5804, 1619.0, 214, '85'],
#   [692.0776000000001,
#    1591.0,
#    939.0776000000001,
#    1606.0,
#    215,
#    'Paramecium bursaria Pb1C30 JX082041.1'],
#   [690.5814,
#    1606.0,
#    937.5814,
#    1621.0,
#    216,
#    'Paramecium bursaria K11-4B MT078144.1'],
#   [677.5814,
#    1621.0,
#    889.5814,
#    1636.0,
#    217,
#    'Paramecium bursaria IP JF304186.1'],
#   [682.7623000000001,
#    1636.0,
#    1001.7623000000001,
#    1651.0,
#    218,
#    'Paramecium bursaria OLI-Parame-burs-01 FJ905152.1']],
#  'node_areas': {0: [1.0, 1.0, 1452.1765, 1651.0],
#   1: [20.0, 1.0, 1452.1765, 1591.0],
#   2: [50.3476, 1.0, 1452.1765, 1576.0],
#   3: [81.3562, 1.0, 1452.1765, 1546.0],
#   4: [172.21769999999998, 1.0, 1452.1765, 1531.0],
#   5: [268.79019999999997, 1.0, 1452.1765, 1411.0],
#   6: [420.2222, 1.0, 1452.1765, 1396.0],
#   7: [473.577, 1.0, 1452.1765, 1261.0],
#   8: [496.1364, 1.0, 1452.1765, 856.0],
#   9: [512.5408, 1.0, 1107.7701, 691.0],
#   10: [606.5936, 1.0, 1100.1824000000001, 496.0],
#   11: [619.5936, 1.0, 1100.1824000000001, 346.0],
#   12: [632.5936, 1.0, 1075.92699, 241.0],
#   13: [645.5936, 1.0, 1075.92699, 181.0],
#   14: [660.3942000000001, 1.0, 1075.92699, 166.0],
#   15: [673.3942000000001, 1.0, 1075.92699, 151.0],
#   16: [686.3942000000001, 1.0, 1075.92699, 121.0],
#   17: [693.3942000000001, 1.0, 1075.92699, 106.0],
#   18: [700.3942000000001, 1.0, 1075.92699, 91.0],
#   19: [707.3942000000001, 1.0, 1070.3952, 61.0],
#   20: [720.3942000000001, 1.0, 1070.3952, 46.0],
#   21: [733.3942000000001, 1.0, 1070.3952, 31.0],
#   22: [746.3942000000001, 1.0, 1070.3952, 16.0],
#   23: [746.3942000000001, 16.0, 951.3952, 31.0],
#   24: [733.3942000000001, 31.0, 1047.12578, 46.0],
#   25: [720.3942000000001, 46.0, 1037.3952, 61.0],
#   26: [707.3942000000001, 61.0, 1075.92699, 91.0],
#   27: [720.3942000000001, 61.0, 968.4648800000001, 76.0],
#   28: [720.3942000000001, 76.0, 1075.92699, 91.0],
#   29: [700.3942000000001, 91.0, 946.3952, 106.0],
#   30: [693.3942000000001, 106.0, 1003.3952, 121.0],
#   31: [686.3942000000001, 121.0, 941.3952, 151.0],
#   32: [699.3942000000001, 121.0, 941.3952, 136.0],
#   33: [699.3942000000001, 136.0, 941.3952, 151.0],
#   34: [673.3942000000001, 151.0, 921.46424, 166.0],
#   35: [660.3942000000001, 166.0, 957.4554800000001, 181.0],
#   36: [645.5936, 181.0, 1041.6821, 241.0],
#   37: [658.5936, 181.0, 1041.6821, 226.0],
#   38: [671.5936, 181.0, 1041.6821, 211.0],
#   39: [684.5936, 181.0, 994.5946, 196.0],
#   40: [684.5936, 196.0, 1041.6821, 211.0],
#   41: [671.5936, 211.0, 981.5946, 226.0],
#   42: [658.5936, 226.0, 982.7565400000001, 241.0],
#   43: [632.5936, 241.0, 1100.1824000000001, 346.0],
#   44: [664.1814, 241.0, 1100.1824000000001, 316.0],
#   45: [677.1814, 241.0, 1100.1824000000001, 301.0],
#   46: [690.1814, 241.0, 1100.1824000000001, 286.0],
#   47: [697.1814, 241.0, 1100.1824000000001, 271.0],
#   48: [710.1814, 241.0, 1011.1824, 256.0],
#   49: [710.1814, 256.0, 1100.1824000000001, 271.0],
#   50: [697.1814, 271.0, 931.1824, 286.0],
#   51: [690.1814, 286.0, 936.1824, 301.0],
#   52: [677.1814, 301.0, 996.1824, 316.0],
#   53: [664.1814, 316.0, 990.65007, 346.0],
#   54: [677.1814, 316.0, 925.46748, 331.0],
#   55: [677.1814, 331.0, 990.65007, 346.0],
#   56: [619.5936, 346.0, 1014.5946, 496.0],
#   57: [632.5936, 346.0, 1014.5946, 466.0],
#   58: [645.5936, 346.0, 980.5946, 421.0],
#   59: [658.5936, 346.0, 978.6878300000001, 391.0],
#   60: [671.5936, 346.0, 950.5946, 376.0],
#   61: [684.5936, 346.0, 950.5946, 361.0],
#   62: [684.5936, 361.0, 926.5946, 376.0],
#   63: [671.5936, 376.0, 978.6878300000001, 391.0],
#   64: [658.5936, 391.0, 980.5946, 421.0],
#   65: [671.5936, 391.0, 927.1459600000001, 406.0],
#   66: [671.5936, 406.0, 980.5946, 421.0],
#   67: [645.5936, 421.0, 1014.5946, 466.0],
#   68: [658.5936, 421.0, 1014.5946, 451.0],
#   69: [671.5936, 421.0, 972.3506, 436.0],
#   70: [671.5936, 436.0, 1014.5946, 451.0],
#   71: [658.5936, 451.0, 908.2631, 466.0],
#   72: [632.5936, 466.0, 890.5946, 496.0],
#   73: [651.5936, 466.0, 890.5946, 481.0],
#   74: [651.5936, 481.0, 877.5946, 496.0],
#   75: [606.5936, 496.0, 1107.7701, 691.0],
#   76: [642.0988, 496.0, 1040.4080999999999, 616.0],
#   77: [681.4071, 496.0, 1040.4081, 601.0],
#   78: [694.4071, 496.0, 1040.4081, 586.0],
#   79: [701.4071, 496.0, 1040.4081, 571.0],
#   80: [708.4071, 496.0, 1037.4081, 556.0],
#   81: [715.4071, 496.0, 1037.4081, 541.0],
#   82: [728.4071, 496.0, 1037.4081, 526.0],
#   83: [741.4071, 496.0, 1037.4081, 511.0],
#   84: [741.4071, 511.0, 887.6780200000001, 526.0],
#   85: [728.4071, 526.0, 893.3332, 541.0],
#   86: [715.4071, 541.0, 1025.4081, 556.0],
#   87: [708.4071, 556.0, 1040.4081, 571.0],
#   88: [701.4071, 571.0, 929.4081, 586.0],
#   89: [694.4071, 586.0, 861.4081, 601.0],
#   90: [681.4071, 601.0, 831.9973600000001, 616.0],
#   91: [642.0988, 616.0, 1107.7701, 691.0],
#   92: [681.0692, 616.0, 1107.7701, 676.0],
#   93: [704.7691, 616.0, 1015.35755, 646.0],
#   94: [723.7691, 616.0, 874.31256, 631.0],
#   95: [723.7691, 631.0, 1015.35755, 646.0],
#   96: [704.7691, 646.0, 1107.7701, 676.0],
#   97: [717.7691, 646.0, 1107.7701, 661.0],
#   98: [717.7691, 661.0, 1036.7701, 676.0],
#   99: [681.0692, 676.0, 1043.7635, 691.0],
#   100: [512.5408, 691.0, 1452.1765, 856.0],
#   101: [549.4915, 691.0, 1452.1765, 841.0],
#   102: [823.3525, 691.0, 1452.1765, 826.0],
#   103: [940.1575, 691.0, 1452.1765, 811.0],
#   104: [967.8596, 691.0, 1452.1765, 796.0],
#   105: [982.2357, 691.0, 1452.1765, 766.0],
#   106: [1012.1139999999999, 691.0, 1452.1765, 751.0],
#   107: [1035.1875, 691.0, 1435.738, 736.0],
#   108: [1049.1772, 691.0, 1435.738, 721.0],
#   109: [1076.913, 691.0, 1420.464, 706.0],
#   110: [1076.913, 706.0, 1435.738, 721.0],
#   111: [1049.1772, 721.0, 1390.9851, 736.0],
#   112: [1035.1875, 736.0, 1452.1765, 751.0],
#   113: [1012.1139999999999, 751.0, 1367.2369999999999, 766.0],
#   114: [982.2357, 766.0, 1418.0297, 796.0],
#   115: [1008.8487, 766.0, 1418.0297, 781.0],
#   116: [1008.8487, 781.0, 1324.7432, 796.0],
#   117: [967.8596, 796.0, 1298.533, 811.0],
#   118: [940.1575, 811.0, 1273.9994000000002, 826.0],
#   119: [823.3525, 826.0, 1114.8561, 841.0],
#   120: [549.4915, 841.0, 766.1416999999999, 856.0],
#   121: [496.1364, 856.0, 1008.612, 1261.0],
#   122: [519.3688999999999, 856.0, 1008.6119999999999, 1216.0],
#   123: [532.3688999999999, 856.0, 1008.6119999999999, 1201.0],
#   124: [554.7099, 856.0, 998.52999, 1036.0],
#   125: [581.8540999999999, 856.0, 998.5299899999999, 1021.0],
#   126: [594.8540999999999, 856.0, 998.5299899999999, 1006.0],
#   127: [607.8540999999999, 856.0, 998.5299899999999, 976.0],
#   128: [620.8540999999999, 856.0, 998.5299899999999, 931.0],
#   129: [633.8540999999999, 856.0, 998.5299899999999, 916.0],
#   130: [646.8540999999999, 856.0, 998.5299899999999, 886.0],
#   131: [659.8540999999999, 856.0, 980.8550999999999, 871.0],
#   132: [659.8540999999999, 871.0, 998.5299899999999, 886.0],
#   133: [646.8540999999999, 886.0, 983.56369, 916.0],
#   134: [659.8540999999999, 886.0, 983.56369, 901.0],
#   135: [659.8540999999999, 901.0, 908.8550999999999, 916.0],
#   136: [633.8540999999999, 916.0, 862.37952, 931.0],
#   137: [620.8540999999999, 931.0, 965.8550999999999, 976.0],
#   138: [633.8540999999999, 931.0, 780.8550999999999, 961.0],
#   139: [646.8540999999999, 931.0, 780.8550999999999, 946.0],
#   140: [646.8540999999999, 946.0, 780.8550999999999, 961.0],
#   141: [633.8540999999999, 961.0, 965.8550999999999, 976.0],
#   142: [607.8540999999999, 976.0, 879.6394999999999, 1006.0],
#   143: [620.8540999999999, 976.0, 879.6394999999999, 991.0],
#   144: [620.8540999999999, 991.0, 879.00766, 1006.0],
#   145: [594.8540999999999, 1006.0, 850.5806799999999, 1021.0],
#   146: [581.8540999999999, 1021.0, 835.8550999999999, 1036.0],
#   147: [554.7099, 1036.0, 1008.6119999999999, 1201.0],
#   148: [598.611, 1036.0, 1008.612, 1186.0],
#   149: [611.611, 1036.0, 1008.612, 1141.0],
#   150: [624.611, 1036.0, 1008.612, 1126.0],
#   151: [637.611, 1036.0, 1008.612, 1111.0],
#   152: [650.611, 1036.0, 1008.612, 1096.0],
#   153: [663.611, 1036.0, 1008.612, 1081.0],
#   154: [676.611, 1036.0, 931.612, 1066.0],
#   155: [689.611, 1036.0, 923.612, 1051.0],
#   156: [689.611, 1051.0, 931.612, 1066.0],
#   157: [676.611, 1066.0, 1008.612, 1081.0],
#   158: [663.611, 1081.0, 1003.3408999999999, 1096.0],
#   159: [650.611, 1096.0, 892.5364, 1111.0],
#   160: [637.611, 1111.0, 887.612, 1126.0],
#   161: [624.611, 1126.0, 761.6249399999999, 1141.0],
#   162: [611.611, 1141.0, 957.34977, 1186.0],
#   163: [624.611, 1141.0, 957.34977, 1171.0],
#   164: [637.611, 1141.0, 811.612, 1156.0],
#   165: [637.611, 1156.0, 957.34977, 1171.0],
#   166: [624.611, 1171.0, 760.11115, 1186.0],
#   167: [598.611, 1186.0, 848.612, 1201.0],
#   168: [532.3688999999999, 1201.0, 736.8955, 1216.0],
#   169: [519.3688999999999, 1216.0, 832.6835899999999, 1261.0],
#   170: [569.9622999999999, 1216.0, 832.6835899999999, 1246.0],
#   171: [582.9622999999999, 1216.0, 829.9632999999999, 1231.0],
#   172: [582.9622999999999, 1231.0, 832.6835899999999, 1246.0],
#   173: [569.9622999999999, 1246.0, 817.9632999999999, 1261.0],
#   174: [473.577, 1261.0, 961.408, 1396.0],
#   175: [568.7574, 1261.0, 810.5903, 1336.0],
#   176: [581.7574, 1261.0, 810.5903, 1321.0],
#   177: [588.7574, 1261.0, 763.7475499999999, 1291.0],
#   178: [601.7574, 1261.0, 722.7583999999999, 1276.0],
#   179: [601.7574, 1276.0, 763.7475499999999, 1291.0],
#   180: [588.7574, 1291.0, 810.5903, 1321.0],
#   181: [595.7574, 1291.0, 741.5781999999999, 1306.0],
#   182: [595.7574, 1306.0, 810.5903, 1321.0],
#   183: [581.7574, 1321.0, 799.7583999999999, 1336.0],
#   184: [568.7574, 1336.0, 961.4079999999999, 1396.0],
#   185: [581.7574, 1336.0, 961.4079999999999, 1381.0],
#   186: [617.4069999999999, 1336.0, 961.4079999999999, 1366.0],
#   187: [630.4069999999999, 1336.0, 794.4079999999999, 1351.0],
#   188: [630.4069999999999, 1351.0, 961.4079999999999, 1366.0],
#   189: [617.4069999999999, 1366.0, 950.1788099999999, 1381.0],
#   190: [581.7574, 1381.0, 753.61709, 1396.0],
#   191: [420.2222, 1396.0, 786.3481999999999, 1411.0],
#   192: [268.79019999999997, 1411.0, 1069.9647, 1531.0],
#   193: [301.15569999999997, 1411.0, 983.48422, 1501.0],
#   194: [349.3735, 1411.0, 983.48422, 1486.0],
#   195: [399.0225, 1411.0, 983.48422, 1471.0],
#   196: [698.4224999999999, 1411.0, 983.4838399999999, 1441.0],
#   197: [711.4224999999999, 1411.0, 980.8323599999999, 1426.0],
#   198: [711.4224999999999, 1426.0, 983.4838399999999, 1441.0],
#   199: [698.4224999999999, 1441.0, 983.4842199999998, 1471.0],
#   200: [711.4224999999999, 1441.0, 980.78037, 1456.0],
#   201: [711.4224999999999, 1456.0, 983.4842199999998, 1471.0],
#   202: [399.0225, 1471.0, 906.6044999999999, 1486.0],
#   203: [349.3735, 1486.0, 894.6965, 1501.0],
#   204: [301.15569999999997, 1501.0, 1069.9647, 1531.0],
#   205: [778.9637, 1501.0, 1011.9647, 1516.0],
#   206: [778.9637, 1516.0, 1069.9647, 1531.0],
#   207: [172.21769999999998, 1531.0, 678.9857, 1546.0],
#   208: [81.3562, 1546.0, 573.9528, 1576.0],
#   209: [201.50220000000002, 1546.0, 550.7897, 1561.0],
#   210: [201.50220000000002, 1561.0, 573.9528, 1576.0],
#   211: [50.3476, 1576.0, 568.7416000000001, 1591.0],
#   212: [20.0, 1591.0, 1001.7623000000001, 1651.0],
#   213: [596.604, 1591.0, 939.0776000000001, 1636.0],
#   214: [677.5804, 1591.0, 939.0776000000001, 1621.0],
#   215: [690.5804, 1591.0, 939.0776000000001, 1606.0],
#   216: [690.5804, 1606.0, 937.5814, 1621.0],
#   217: [677.5804, 1621.0, 889.5814, 1636.0],
#   218: [596.604, 1636.0, 1001.7623000000001, 1651.0]}}

# %% [markdown]
# #### COI MrB tree

# %%
stats = 'final_trees/COI_stats.tsv'

df = pd.read_csv(pth+stats, sep='\t', index_col=0)

with open(pth+'final_trees/mb/COI/con_50_majrule', 'r') as in_f:
    with open(pth+'final_trees/mb/COI/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['new'][el].strip()
                    line = line.replace(el, new_name)
            out_f.write(line)

# укоренить в seaview            
            
with open(pth+'final_trees/mb/COI/mb_rooted.newick', 'r') as in_f:
    with open(pth+'final_trees/mb/COI/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.new):
                name = name.lstrip(' ')
                if name in line:
                    new_name = '"' + df['new'][ind] + '"'
                    line = line.replace(name, new_name)
            out_f.write(line)
            
ours = list(df[df.current_study == True].new)

t = Tree(pth+'final_trees/mb/COI/mb_ete_tree.newick', quoted_node_names=True)

for node in t.traverse():
    node.img_style['size'] = 0
    
style = NodeStyle()
style['bgcolor'] = 'LightBlue'
    
for leaf in t.iter_leaves():
    if str(leaf)[3:] in set(ours):
        leaf.img_style = style
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale = 1000
t.show(tree_style=ts)
t.render(pth+'final_trees/mb/COI/mb_ete_tree.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [[611.37779, 51.5, 615.37779, 55.5, 24, None],
#   [590.38103, 96.5, 594.38103, 100.5, 27, None],
#   [583.3474799999999, 111.5, 587.3474799999999, 115.5, 28, None],
#   [573.60811, 141.5, 577.60811, 145.5, 30, None],
#   [559.60112, 171.5, 563.60112, 175.5, 32, None],
#   [587.2127700000001, 276.5, 591.2127700000001, 280.5, 47, None],
#   [589.3727100000001, 291.5, 593.3727100000001, 295.5, 49, None],
#   [582.61789, 351.5, 586.61789, 355.5, 55, None],
#   [557.72596, 366.5, 561.72596, 370.5, 57, None],
#   [557.75931, 381.5, 561.75931, 385.5, 58, None],
#   [584.24992, 396.5, 588.24992, 400.5, 65, None],
#   [554.3424, 471.5, 558.3424, 475.5, 70, None],
#   [547.3507999999999, 486.5, 551.3507999999999, 490.5, 71, None],
#   [624.8134, 546.5, 628.8134, 550.5, 83, None],
#   [614.9427000000001, 576.5, 618.9427000000001, 580.5, 85, None],
#   [605.9561699999999, 591.5, 609.9561699999999, 595.5, 86, None],
#   [621.9737, 606.5, 625.9737, 610.5, 87, None],
#   [649.5884900000001, 636.5, 653.5884900000001, 640.5, 92, None],
#   [544.4878, 846.5, 548.4878, 850.5, 117, None],
#   [530.9476199999999, 1146.5, 534.9476199999999, 1150.5, 161, None],
#   [443.6283, 1311.5, 447.6283, 1315.5, 179, None],
#   [431.92129, 1341.5, 435.92129, 1345.5, 184, None],
#   [429.40408, 1356.5, 433.40408, 1360.5, 185, None],
#   [411.50855, 1386.5, 415.50855, 1390.5, 187, None]],
#  'faces': [[1.0, 1517.0910868644714, 8.0, 1530.0910868644714, 0, '1'],
#   [34.6119, 1403.8071737289429, 41.6119, 1416.8071737289429, 1, '1'],
#   [191.3489, 1273.6846599578857, 198.3489, 1286.6846599578857, 2, '1'],
#   [246.2952, 1143.8693199157715, 268.2952, 1156.8693199157715, 3, '0.92'],
#   [294.35650000000004,
#    928.301139831543,
#    316.35650000000004,
#    941.301139831543,
#    4,
#    '0.88'],
#   [330.8122, 662.4797210693359, 346.8122, 675.4797210693359, 5, '0.9'],
#   [473.2302, 499.7797546386719, 480.2302, 512.7797546386719, 6, '1'],
#   [480.2302, 370.37591552734375, 502.2302, 383.37591552734375, 7, '0.72'],
#   [502.2302, 267.0174560546875, 509.2302, 280.0174560546875, 8, '1'],
#   [509.2302, 189.441162109375, 531.2302, 202.441162109375, 9, '0.88'],
#   [547.3502, 158.50732421875, 554.3502, 171.50732421875, 10, '1'],
#   [554.3502, 143.5146484375, 561.3502, 156.5146484375, 11, '1'],
#   [561.3502, 128.529296875, 568.3502, 141.529296875, 12, '1'],
#   [568.3502, 113.55859375, 575.3502, 126.55859375, 13, '1'],
#   [575.3502, 98.6171875, 582.3502, 111.6171875, 14, '1'],
#   [582.3502, 83.734375, 589.3502, 96.734375, 15, '1'],
#   [589.3502, 68.96875, 596.3502, 81.96875, 16, '1'],
#   [596.3502, 54.4375, 603.3502, 67.4375, 17, '1'],
#   [603.3502, 40.375, 610.3502, 53.375, 18, '1'],
#   [610.3502, 27.25, 617.3502, 40.25, 19, '1'],
#   [617.3502, 16.0, 624.3502, 29.0, 20, '1'],
#   [626.07602, 1.0, 831.07602, 16.0, 21, 'Paramecium sp. G1-2 MN264582.1'],
#   [628.00087,
#    16.0,
#    982.00087,
#    31.0,
#    22,
#    'Paramecium multimicronucleatum haplotype C7 MH544195.1'],
#   [619.04234,
#    31.0,
#    943.04234,
#    46.0,
#    23,
#    'Paramecium multimicronucleatum AMA5-7 MN264578.1'],
#   [614.87779,
#    46.0,
#    857.87779,
#    61.0,
#    24,
#    'Paramecium multimicronucleatum CyP5-3'],
#   [605.0264299999999,
#    61.0,
#    922.0264299999999,
#    76.0,
#    25,
#    'Paramecium multimicronucleatum ISN-11 AM072769.1'],
#   [597.8406299999999,
#    76.0,
#    907.8406299999999,
#    91.0,
#    26,
#    'Paramecium multimicronucleatum C1(1) MH544185.1'],
#   [593.88103,
#    91.0,
#    832.88103,
#    106.0,
#    27,
#    'Paramecium multimicronucleatum ID1-13'],
#   [586.8474799999999,
#    106.0,
#    825.8474799999999,
#    121.0,
#    28,
#    'Paramecium multimicronucleatum MSA-5'],
#   [579.47272,
#    121.0,
#    891.47272,
#    136.0,
#    29,
#    'Paramecium multimicronucleatum AH1-5 AM072768.1'],
#   [577.10811,
#    136.0,
#    819.10811,
#    151.0,
#    30,
#    'Paramecium multimicronucleatum Ns2-16'],
#   [567.05827,
#    151.0,
#    861.05827,
#    166.0,
#    31,
#    'Paramecium multimicronucleatum C6 MH544194.1'],
#   [563.10112,
#    166.0,
#    805.10112,
#    181.0,
#    32,
#    'Paramecium multimicronucleatum ThK-16'],
#   [531.2302, 220.375, 553.2302, 233.375, 33, '0.72'],
#   [553.2302, 207.25, 575.2302, 220.25, 34, '0.67'],
#   [575.2302, 196.0, 597.2302, 209.0, 35, '0.84'],
#   [600.01123,
#    181.0,
#    910.01123,
#    196.0,
#    36,
#    'Paramecium multimicronucleatum C3(2) MH544191.1'],
#   [599.31061,
#    196.0,
#    909.31061,
#    211.0,
#    37,
#    'Paramecium multimicronucleatum C3(1) MH544190.1'],
#   [580.5076799999999,
#    211.0,
#    902.5076799999999,
#    226.0,
#    38,
#    'Paramecium multimicronucleatum SPb63-2 JF741248.1'],
#   [610.3497,
#    226.0,
#    924.3497,
#    241.0,
#    39,
#    'Paramecium multimicronucleatum BSP-7 AM072772.1'],
#   [509.2302, 344.59375, 531.2302, 357.59375, 40, '0.94'],
#   [531.2302, 313.1875, 553.2302, 326.1875, 41, '0.94'],
#   [557.2037, 284.125, 564.2037, 297.125, 42, '1'],
#   [564.2037, 267.25, 586.2037, 280.25, 43, '0.99'],
#   [586.2037, 256.0, 593.2037, 269.0, 44, '1'],
#   [594.73942,
#    241.0,
#    829.73942,
#    256.0,
#    45,
#    'Paramecium multimicronucleatum R51-6'],
#   [598.9441300000001,
#    256.0,
#    902.9441300000001,
#    271.0,
#    46,
#    'Paramecium multimicronucleatum K4-2 MT078146.1'],
#   [590.7127700000001,
#    271.0,
#    853.7127700000001,
#    286.0,
#    47,
#    'Paramecium multimicronucleatum SMM80-11'],
#   [564.2037, 301.0, 586.2037, 314.0, 48, '0.94'],
#   [592.8727100000001,
#    286.0,
#    843.8727100000001,
#    301.0,
#    49,
#    'Paramecium multimicronucleatum ChP10-2'],
#   [587.7558300000001,
#    301.0,
#    896.7558300000001,
#    316.0,
#    50,
#    'Paramecium multimicronucleatum L72-1 MT078145.1'],
#   [553.2302, 342.25, 575.2302, 355.25, 51, '0.56'],
#   [575.2302, 331.0, 582.2302, 344.0, 52, '1'],
#   [585.22845,
#    316.0,
#    928.22845,
#    331.0,
#    53,
#    'P.multimicronucleatum Peniche31(ParameciumDB)Portugal'],
#   [586.35357,
#    331.0,
#    885.35357,
#    346.0,
#    54,
#    'Paramecium multimicronucleatum Wg8 JF741271.1'],
#   [586.11789,
#    346.0,
#    828.11789,
#    361.0,
#    55,
#    'Paramecium multimicronucleatum OmN-1'],
#   [549.7336, 376.0, 556.7336, 389.0, 56, '1'],
#   [561.22596,
#    361.0,
#    797.22596,
#    376.0,
#    57,
#    'Paramecium multimicronucleatum SK6-3'],
#   [561.25931,
#    376.0,
#    784.25931,
#    391.0,
#    58,
#    'Paramecium multimicronucleatum LB2'],
#   [539.3922, 473.734375, 546.3922, 486.734375, 59, '1'],
#   [546.3922, 458.96875, 553.3922, 471.96875, 60, '1'],
#   [553.3922, 444.4375, 560.3922, 457.4375, 61, '1'],
#   [560.3922, 430.375, 567.3922, 443.375, 62, '1'],
#   [567.3922, 417.25, 574.3922, 430.25, 63, '1'],
#   [574.3922, 406.0, 581.3922, 419.0, 64, '1'],
#   [587.74992,
#    391.0,
#    831.74992,
#    406.0,
#    65,
#    'Paramecium multimicronucleatum ChP3-4'],
#   [587.7706800000001,
#    406.0,
#    897.7706800000001,
#    421.0,
#    66,
#    'Paramecium multimicronucleatum MB2-5 JF741245.1'],
#   [575.86501,
#    421.0,
#    965.86501,
#    436.0,
#    67,
#    'Paramecium multimicronucleatum OLI-Parame-mult-03 FJ905145.1'],
#   [568.8594,
#    436.0,
#    869.8594,
#    451.0,
#    68,
#    'Paramecium multimicronucleatum C12 MH544200.1'],
#   [561.8863200000001,
#    451.0,
#    880.8863200000001,
#    466.0,
#    69,
#    'Paramecium multimicronucleatum Chp5-3 MT078147.1'],
#   [557.8424,
#    466.0,
#    800.8424,
#    481.0,
#    70,
#    'Paramecium multimicronucleatum E59-1B'],
#   [550.8507999999999,
#    481.0,
#    781.8507999999999,
#    496.0,
#    71,
#    'Paramecium multimicronucleatum IP2-1'],
#   [529.2508, 629.18359375, 536.2508, 642.18359375, 72, '1'],
#   [588.7269, 593.6171875, 595.7269, 606.6171875, 73, '1'],
#   [595.7269, 578.734375, 602.7269, 591.734375, 74, '1'],
#   [602.7269, 563.96875, 609.7269, 576.96875, 75, '1'],
#   [609.7269, 549.4375, 616.7269, 562.4375, 76, '1'],
#   [616.7269, 535.375, 623.7269, 548.375, 77, '1'],
#   [623.7269, 522.25, 630.7269, 535.25, 78, '1'],
#   [630.7269, 511.0, 637.7269, 524.0, 79, '1'],
#   [639.33285,
#    496.0,
#    971.33285,
#    511.0,
#    80,
#    'Paramecium multimicronucleatum SMM81-1 MT078149.1'],
#   [639.31936,
#    511.0,
#    949.31936,
#    526.0,
#    81,
#    'Paramecium multimicronucleatum T42-1 MT078148.1'],
#   [632.54845,
#    526.0,
#    928.54845,
#    541.0,
#    82,
#    'Paramecium multimicronucleatum AM MN264577.1'],
#   [628.3134, 541.0, 853.3134, 556.0, 83, 'Paramecium multimicronucleatum M04'],
#   [618.32394, 556.0, 778.32394, 571.0, 84, 'Paramecium fokini CyL3-21'],
#   [618.4427000000001,
#    571.0,
#    758.4427000000001,
#    586.0,
#    85,
#    'Paramecium fokini PP-2'],
#   [609.4561699999999,
#    586.0,
#    755.4561699999999,
#    601.0,
#    86,
#    'Paramecium fokini PL4-1'],
#   [625.4737, 601.0, 769.4737, 616.0, 87, 'Paramecium fokini OP13'],
#   [587.3473, 664.75, 594.3473, 677.75, 88, '1'],
#   [624.8747000000001, 646.0, 631.8747000000001, 659.0, 89, '1'],
#   [639.3997, 631.0, 646.3997, 644.0, 90, '1'],
#   [650.14283,
#    616.0,
#    940.14283,
#    631.0,
#    91,
#    'Paramecium multimicronucleatum BR JF304189.1'],
#   [653.0884900000001,
#    631.0,
#    799.0884900000001,
#    646.0,
#    92,
#    'Paramecium fokini AB9-8'],
#   [631.8747000000001, 661.0, 653.8747000000001, 674.0, 93, '0.98'],
#   [655.4389700000002,
#    646.0,
#    1045.4389700000002,
#    661.0,
#    94,
#    'Paramecium multimicronucleatum OLI-Parame-mult-02 FJ905144.1'],
#   [655.5444,
#    661.0,
#    1045.5444,
#    676.0,
#    95,
#    'Paramecium multimicronucleatum OLI-Parame-mult-01 FJ905143.1'],
#   [620.5928,
#    676.0,
#    963.5928,
#    691.0,
#    96,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK806287.1'],
#   [384.5878, 825.1796875, 406.5878, 838.1796875, 97, '0.95'],
#   [730.3758, 801.859375, 737.3758, 814.859375, 98, '1'],
#   [844.9118000000001, 770.21875, 866.9118000000001, 783.21875, 99, '0.85'],
#   [879.0191000000001, 744.4375, 901.0191000000001, 757.4375, 100, '0.61'],
#   [905.6982, 730.375, 927.6982, 743.375, 101, '0.73'],
#   [927.6982, 717.25, 949.6982, 730.25, 102, '0.68'],
#   [955.4773, 706.0, 977.4773, 719.0, 103, '0.88'],
#   [1136.1803,
#    691.0,
#    1350.1803,
#    706.0,
#    104,
#    'Paramecium tetraurelia 51 M15281.1'],
#   [1084.3553,
#    706.0,
#    1340.3553,
#    721.0,
#    105,
#    ' 223 PDECA.223.MITO.1.G040 P.decaurelia'],
#   [1033.8137000000002,
#    721.0,
#    1305.8137000000002,
#    736.0,
#    106,
#    ' 274 PDODE.274.MITO.1.G040 P.dodecaurelia'],
#   [1078.5172,
#    736.0,
#    1359.5172,
#    751.0,
#    107,
#    ' AZ8-4 PSEXA.AZ8-4.MITO.1.G040 P.sexaurelia'],
#   [1018.5491000000001,
#    751.0,
#    1266.5491000000002,
#    766.0,
#    108,
#    'V1-4 PBIAU.V1-4.MITO.1.G040 P.biaurelia'],
#   [866.9118000000001, 796.0, 873.9118000000001, 809.0, 109, '1'],
#   [880.6864, 781.0, 902.6864, 794.0, 110, '0.76'],
#   [1053.8034,
#    766.0,
#    1331.8034,
#    781.0,
#    111,
#    'N1A PQUAD.NiA.MITO.1.G040 P.quadecaurelia'],
#   [987.8744,
#    781.0,
#    1230.8744000000002,
#    796.0,
#    112,
#    'TE PNOVA.TE.MITO.1.G040 P.novaurelia'],
#   [873.9118000000001, 811.0, 880.9118000000001, 824.0, 113, '1'],
#   [964.7296000000001,
#    796.0,
#    1245.7296000000001,
#    811.0,
#    114,
#    'AZ9-3 PPRIM.AZ9-3.MITO.1.G040 P.primaurelia'],
#   [985.4748000000001,
#    811.0,
#    1227.4748,
#    826.0,
#    115,
#    'Paramecium septaurelia 227 MT318934.1'],
#   [818.118, 826.0, 1037.118, 841.0, 116, 'M PJENN.M.MITO.1.G040 P.jenningsi'],
#   [547.9878, 841.0, 668.9878, 856.0, 117, 'Paramecium sp. FT8'],
#   [340.7762, 1194.12255859375, 356.7762, 1207.12255859375, 118, '0.8'],
#   [356.7762, 1145.9951171875, 378.7762, 1158.9951171875, 119, '0.72'],
#   [389.9492, 1083.490234375, 411.9492, 1096.490234375, 120, '0.98'],
#   [442.5161, 998.734375, 449.5161, 1011.734375, 121, '1'],
#   [449.5161, 976.46875, 465.5161, 989.46875, 122, '0.5'],
#   [465.5161, 954.4375, 472.5161, 967.4375, 123, '1'],
#   [474.90788, 925.375, 481.90788, 938.375, 124, '1'],
#   [481.90788, 895.375, 503.90788, 908.375, 125, '0.85'],
#   [503.90788, 882.25, 510.90788, 895.25, 126, '1'],
#   [510.90788, 871.0, 532.90788, 884.0, 127, '0.93'],
#   [536.78745,
#    856.0,
#    858.78745,
#    871.0,
#    128,
#    'Paramecium multimicronucleatum GB4-26 MN264576.1'],
#   [534.4731899999999,
#    871.0,
#    783.4731899999999,
#    886.0,
#    129,
#    'Paramecium caudatum SH42 MG013510.1'],
#   [512.58233,
#    886.0,
#    833.58233,
#    901.0,
#    130,
#    'Paramecium caudatum RanNy1602-AP18 MG589328.1'],
#   [514.55978,
#    901.0,
#    846.55978,
#    916.0,
#    131,
#    'Paramecium caudatum HUN-BA PcCOI_a12 FN256277.1'],
#   [481.90788, 955.375, 488.90788, 968.375, 132, '1'],
#   [488.90788, 942.25, 495.90788, 955.25, 133, '1'],
#   [495.90788, 931.0, 502.90788, 944.0, 134, '1'],
#   [504.27991999999995,
#    916.0,
#    673.27992,
#    931.0,
#    135,
#    'Paramecium caudatum GB-E'],
#   [504.28675,
#    931.0,
#    836.28675,
#    946.0,
#    136,
#    'Paramecium caudatum OLI-Parame-caud-02 FJ905148.1'],
#   [497.28386, 946.0, 666.28386, 961.0, 137, 'Paramecium caudatum C104'],
#   [491.88829,
#    961.0,
#    718.88829,
#    976.0,
#    138,
#    'Paramecium caudatum CA JF304187.1'],
#   [480.61447,
#    976.0,
#    734.61447,
#    991.0,
#    139,
#    'Paramecium caudatum POE-1 HQ149725.1'],
#   [471.73551,
#    991.0,
#    723.73551,
#    1006.0,
#    140,
#    'Paramecium caudatum SLO-R FN256281.1'],
#   [449.5161, 1021.0, 465.5161, 1034.0, 141, '0.5'],
#   [470.53504,
#    1006.0,
#    725.53504,
#    1021.0,
#    142,
#    'Paramecium caudatum G-PL-2 FN256264.1'],
#   [476.9899,
#    1021.0,
#    726.9899,
#    1036.0,
#    143,
#    'Paramecium caudatum G-E12 FN256263.1'],
#   [471.9987, 1168.24609375, 478.9987, 1181.24609375, 144, '1'],
#   [478.9987, 1142.9921875, 500.9987, 1155.9921875, 145, '0.64'],
#   [500.9987, 1118.734375, 522.9987, 1131.734375, 146, '0.78'],
#   [522.9987, 1103.96875, 544.9987, 1116.96875, 147, '0.73'],
#   [544.9987, 1089.4375, 566.9987, 1102.4375, 148, '0.91'],
#   [570.7983, 1075.375, 577.7983, 1088.375, 149, '1'],
#   [577.7983, 1062.25, 584.7983, 1075.25, 150, '1'],
#   [584.7983, 1051.0, 591.7983, 1064.0, 151, '1'],
#   [593.35769,
#    1036.0,
#    925.35769,
#    1051.0,
#    152,
#    'Paramecium caudatum OLI-Parame-caud-01 FJ905142.1'],
#   [593.32674,
#    1051.0,
#    827.32674,
#    1066.0,
#    153,
#    'Paramecium caudatum V-1 MT078150.1'],
#   [586.3184000000001,
#    1066.0,
#    828.3184000000001,
#    1081.0,
#    154,
#    'Paramecium caudatum K5-2 MT078151.1'],
#   [581.9199600000001,
#    1081.0,
#    919.9199600000001,
#    1096.0,
#    155,
#    'Paramecium caudatum BRA-RIO PcCOI_b03 FN256282.1'],
#   [583.9696,
#    1096.0,
#    814.9696,
#    1111.0,
#    156,
#    'Paramecium caudatum M3 KY399443.1'],
#   [546.95191,
#    1111.0,
#    796.95191,
#    1126.0,
#    157,
#    'Paramecium caudatum PcC30 JX082093.1'],
#   [528.58057, 1126.0, 697.58057, 1141.0, 158, 'Paramecium caudatum C083'],
#   [500.9987, 1167.25, 522.9987, 1180.25, 159, '0.72'],
#   [522.9987, 1156.0, 529.9987, 1169.0, 160, '1'],
#   [534.4476199999999,
#    1141.0,
#    705.4476199999999,
#    1156.0,
#    161,
#    'Paramecium caudatum Or4-4'],
#   [534.0822000000001,
#    1156.0,
#    852.0822000000001,
#    1171.0,
#    162,
#    'Paramecium multimicronucleatum Kr113-3 JF741258.1'],
#   [526.54214, 1171.0, 699.54214, 1186.0, 163, 'Paramecium caudatum 43c3d'],
#   [481.30782999999997,
#    1186.0,
#    731.30783,
#    1201.0,
#    164,
#    'Paramecium caudatum PcC24 JX082077.1'],
#   [469.764, 1201.0, 638.764, 1216.0, 165, 'Paramecium caudatum C026'],
#   [422.6566, 1242.25, 429.6566, 1255.25, 166, '1'],
#   [429.6566, 1231.0, 451.6566, 1244.0, 167, '0.99'],
#   [453.43910000000005,
#    1216.0,
#    700.4391,
#    1231.0,
#    168,
#    'Paramecium caudatum INL-1 HQ149723.1'],
#   [455.4997,
#    1231.0,
#    703.4997000000001,
#    1246.0,
#    169,
#    'Paramecium caudatum INP-3 HQ149724.1'],
#   [432.08834,
#    1246.0,
#    680.08834,
#    1261.0,
#    170,
#    'Paramecium caudatum INK-1 HQ149722.1'],
#   [395.7642, 1359.4375, 402.7642, 1372.4375, 171, '1'],
#   [402.7642, 1330.375, 409.7642, 1343.375, 172, '1'],
#   [409.7642, 1300.375, 431.7642, 1313.375, 173, '0.56'],
#   [472.6634, 1287.25, 479.6634, 1300.25, 174, '1'],
#   [479.6634, 1276.0, 486.6634, 1289.0, 175, '1'],
#   [488.39086000000003,
#    1261.0,
#    819.39086,
#    1276.0,
#    176,
#    'Paramecium multimicronucleatum TRB101-4 JF741263.1'],
#   [490.91622,
#    1276.0,
#    821.9162200000001,
#    1291.0,
#    177,
#    'Paramecium multimicronucleatum TRB101-1 JF741262.1'],
#   [482.12154000000004,
#    1291.0,
#    639.1215400000001,
#    1306.0,
#    178,
#    'Paramecium lynni ShKm41'],
#   [447.1283,
#    1306.0,
#    608.1283000000001,
#    1321.0,
#    179,
#    'Paramecium lynni HSG3-10'],
#   [409.7642, 1360.375, 416.7642, 1373.375, 180, '1'],
#   [416.7642, 1347.25, 423.7642, 1360.25, 181, '1'],
#   [423.7642, 1336.0, 430.7642, 1349.0, 182, '1'],
#   [432.55619,
#    1321.0,
#    650.55619,
#    1336.0,
#    183,
#    'Paramecium sp. V105-1 MN264579.1'],
#   [435.42129, 1336.0, 586.42129, 1351.0, 184, 'Paramecium lynni SD11-9'],
#   [432.90408, 1351.0, 584.90408, 1366.0, 185, 'Paramecium lynni PO16-1'],
#   [421.14813000000004,
#    1366.0,
#    634.14813,
#    1381.0,
#    186,
#    'Paramecium sp. CB8-2 MN264581.1'],
#   [415.00855, 1381.0, 551.00855, 1396.0, 187, 'Paramecium lynni SP-1'],
#   [366.36789999999996,
#    1396.0,
#    623.3679,
#    1411.0,
#    188,
#    'Paramecium germanicum GO1 KM091240.1'],
#   [146.8719, 1533.9296875, 168.8719, 1546.9296875, 189, '0.63'],
#   [202.5249, 1497.484375, 224.5249, 1510.484375, 190, '0.74'],
#   [312.131, 1478.96875, 319.131, 1491.96875, 191, '1'],
#   [391.6239, 1464.4375, 413.6239, 1477.4375, 192, '0.73'],
#   [721.9359, 1450.375, 728.9359, 1463.375, 193, '1'],
#   [728.9359, 1437.25, 735.9359, 1450.25, 194, '1'],
#   [735.9359, 1426.0, 757.9359, 1439.0, 195, '0.52'],
#   [764.1098,
#    1411.0,
#    1032.1098,
#    1426.0,
#    196,
#    'Paramecium nephridiatum PnC77 JX082125.1'],
#   [761.20902,
#    1426.0,
#    1029.20902,
#    1441.0,
#    197,
#    'Paramecium nephridiatum PnC72 JX082120.1'],
#   [738.6851399999999,
#    1441.0,
#    1006.6851399999999,
#    1456.0,
#    198,
#    'Paramecium nephridiatum PnC43 JX082111.1'],
#   [734.95256,
#    1456.0,
#    1002.95256,
#    1471.0,
#    199,
#    'Paramecium nephridiatum PnC75 JX082123.1'],
#   [808.5699,
#    1471.0,
#    1042.5699,
#    1486.0,
#    200,
#    'Paramecium calkinsi GN5-1 FJ905147.1'],
#   [557.38,
#    1486.0,
#    894.38,
#    1501.0,
#    201,
#    'Paramecium polycaryum OLI-Parame-poly-01 FJ905155.1'],
#   [755.5958999999999, 1516.0, 762.5958999999999, 1529.0, 202, '1'],
#   [763.9728899999999,
#    1501.0,
#    996.9728899999999,
#    1516.0,
#    203,
#    'Paramecium chlorelligerum KX669634.1'],
#   [764.0070899999998,
#    1516.0,
#    1055.0070899999998,
#    1531.0,
#    204,
#    'Paramecium chlorelligerum HSG1-11 KX669632.1'],
#   [283.8109, 1570.375, 305.8109, 1583.375, 205, '0.69'],
#   [408.4489, 1557.25, 430.4489, 1570.25, 206, '0.85'],
#   [591.0238999999999, 1546.0, 598.0238999999999, 1559.0, 207, '1'],
#   [728.6469,
#    1531.0,
#    980.6469,
#    1546.0,
#    208,
#    'Paramecium putrinum Etu 7-4 MG589327.1'],
#   [677.5059999999999,
#    1546.0,
#    997.5059999999999,
#    1561.0,
#    209,
#    'Paramecium putrinum OLI-Parame-putr-01 FJ905153.1'],
#   [799.0198999999999,
#    1561.0,
#    1051.0198999999998,
#    1576.0,
#    210,
#    'Paramecium duboscqui PdC95 JX082147.1'],
#   [679.9679000000001,
#    1576.0,
#    887.9679000000001,
#    1591.0,
#    211,
#    'Paramecium buetschlii KM091238.1'],
#   [639.626, 1630.375, 646.626, 1643.375, 212, '1'],
#   [758.2339999999999, 1617.25, 765.2339999999999, 1630.25, 213, '1'],
#   [765.2339999999999, 1606.0, 772.2339999999999, 1619.0, 214, '1'],
#   [775.3070399999999,
#    1591.0,
#    987.3070399999999,
#    1606.0,
#    215,
#    'Paramecium bursaria IP JF304186.1'],
#   [775.5727299999999,
#    1606.0,
#    1022.5727299999999,
#    1621.0,
#    216,
#    'Paramecium bursaria Pb1C30 JX082041.1'],
#   [766.7271099999999,
#    1621.0,
#    1013.7271099999999,
#    1636.0,
#    217,
#    'Paramecium bursaria K11-4B MT078144.1'],
#   [761.213,
#    1636.0,
#    1080.213,
#    1651.0,
#    218,
#    'Paramecium bursaria OLI-Parame-burs-01 FJ905152.1']],
#  'node_areas': {0: [1.0, 1.0, 1359.5172000000002, 1651.0],
#   1: [8.0, 1.0, 1359.5172000000002, 1591.0],
#   2: [41.6119, 1.0, 1359.5172000000002, 1411.0],
#   3: [198.3489, 1.0, 1359.5172, 1396.0],
#   4: [268.2952, 1.0, 1359.5172, 1261.0],
#   5: [316.35650000000004, 1.0, 1359.5172, 856.0],
#   6: [346.8122, 1.0, 1045.5444, 691.0],
#   7: [480.2302, 1.0, 982.0008700000001, 496.0],
#   8: [502.2302, 1.0, 982.0008700000001, 391.0],
#   9: [509.2302, 1.0, 982.0008700000001, 241.0],
#   10: [531.2302, 1.0, 982.00087, 181.0],
#   11: [554.3502, 1.0, 982.00087, 166.0],
#   12: [561.3502, 1.0, 982.00087, 151.0],
#   13: [568.3502, 1.0, 982.00087, 136.0],
#   14: [575.3502, 1.0, 982.00087, 121.0],
#   15: [582.3502, 1.0, 982.00087, 106.0],
#   16: [589.3502, 1.0, 982.00087, 91.0],
#   17: [596.3502, 1.0, 982.00087, 76.0],
#   18: [603.3502, 1.0, 982.00087, 61.0],
#   19: [610.3502, 1.0, 982.00087, 46.0],
#   20: [617.3502, 1.0, 982.00087, 31.0],
#   21: [624.3502, 1.0, 831.07602, 16.0],
#   22: [624.3502, 16.0, 982.00087, 31.0],
#   23: [617.3502, 31.0, 943.04234, 46.0],
#   24: [610.3502, 46.0, 857.87779, 61.0],
#   25: [603.3502, 61.0, 922.0264299999999, 76.0],
#   26: [596.3502, 76.0, 907.8406299999999, 91.0],
#   27: [589.3502, 91.0, 832.88103, 106.0],
#   28: [582.3502, 106.0, 825.8474799999999, 121.0],
#   29: [575.3502, 121.0, 891.47272, 136.0],
#   30: [568.3502, 136.0, 819.10811, 151.0],
#   31: [561.3502, 151.0, 861.05827, 166.0],
#   32: [554.3502, 166.0, 805.10112, 181.0],
#   33: [531.2302, 181.0, 924.3497, 241.0],
#   34: [553.2302, 181.0, 910.01123, 226.0],
#   35: [575.2302, 181.0, 910.01123, 211.0],
#   36: [597.2302, 181.0, 910.01123, 196.0],
#   37: [597.2302, 196.0, 909.31061, 211.0],
#   38: [575.2302, 211.0, 902.5076799999999, 226.0],
#   39: [553.2302, 226.0, 924.3497, 241.0],
#   40: [509.2302, 241.0, 928.2284500000001, 391.0],
#   41: [531.2302, 241.0, 928.22845, 361.0],
#   42: [553.2302, 241.0, 902.94413, 316.0],
#   43: [564.2037, 241.0, 902.9441300000001, 286.0],
#   44: [586.2037, 241.0, 902.9441300000001, 271.0],
#   45: [593.2037, 241.0, 829.73942, 256.0],
#   46: [593.2037, 256.0, 902.9441300000001, 271.0],
#   47: [586.2037, 271.0, 853.7127700000001, 286.0],
#   48: [564.2037, 286.0, 896.7558300000001, 316.0],
#   49: [586.2037, 286.0, 843.8727100000001, 301.0],
#   50: [586.2037, 301.0, 896.7558300000001, 316.0],
#   51: [553.2302, 316.0, 928.22845, 361.0],
#   52: [575.2302, 316.0, 928.22845, 346.0],
#   53: [582.2302, 316.0, 928.22845, 331.0],
#   54: [582.2302, 331.0, 885.35357, 346.0],
#   55: [575.2302, 346.0, 828.11789, 361.0],
#   56: [531.2302, 361.0, 797.22596, 391.0],
#   57: [556.7336, 361.0, 797.22596, 376.0],
#   58: [556.7336, 376.0, 784.25931, 391.0],
#   59: [502.2302, 391.0, 965.86501, 496.0],
#   60: [546.3922, 391.0, 965.86501, 481.0],
#   61: [553.3922, 391.0, 965.86501, 466.0],
#   62: [560.3922, 391.0, 965.86501, 451.0],
#   63: [567.3922, 391.0, 965.86501, 436.0],
#   64: [574.3922, 391.0, 897.7706800000001, 421.0],
#   65: [581.3922, 391.0, 831.74992, 406.0],
#   66: [581.3922, 406.0, 897.7706800000001, 421.0],
#   67: [574.3922, 421.0, 965.86501, 436.0],
#   68: [567.3922, 436.0, 869.8594, 451.0],
#   69: [560.3922, 451.0, 880.8863200000001, 466.0],
#   70: [553.3922, 466.0, 800.8424, 481.0],
#   71: [546.3922, 481.0, 781.8507999999999, 496.0],
#   72: [480.2302, 496.0, 1045.5444, 691.0],
#   73: [536.2508, 496.0, 971.33285, 616.0],
#   74: [595.7269, 496.0, 971.33285, 601.0],
#   75: [602.7269, 496.0, 971.33285, 586.0],
#   76: [609.7269, 496.0, 971.33285, 571.0],
#   77: [616.7269, 496.0, 971.33285, 556.0],
#   78: [623.7269, 496.0, 971.33285, 541.0],
#   79: [630.7269, 496.0, 971.33285, 526.0],
#   80: [637.7269, 496.0, 971.33285, 511.0],
#   81: [637.7269, 511.0, 949.31936, 526.0],
#   82: [630.7269, 526.0, 928.54845, 541.0],
#   83: [623.7269, 541.0, 853.3134, 556.0],
#   84: [616.7269, 556.0, 778.32394, 571.0],
#   85: [609.7269, 571.0, 758.4427000000001, 586.0],
#   86: [602.7269, 586.0, 755.4561699999999, 601.0],
#   87: [595.7269, 601.0, 769.4737, 616.0],
#   88: [536.2508, 616.0, 1045.5444, 691.0],
#   89: [594.3473, 616.0, 1045.5444, 676.0],
#   90: [631.8747000000001, 616.0, 940.14283, 646.0],
#   91: [646.3997, 616.0, 940.14283, 631.0],
#   92: [646.3997, 631.0, 799.0884900000001, 646.0],
#   93: [631.8747000000001, 646.0, 1045.5444, 676.0],
#   94: [653.8747000000001, 646.0, 1045.4389700000002, 661.0],
#   95: [653.8747000000001, 661.0, 1045.5444, 676.0],
#   96: [594.3473, 676.0, 963.5928, 691.0],
#   97: [346.8122, 691.0, 1359.5172, 856.0],
#   98: [406.5878, 691.0, 1359.5172, 841.0],
#   99: [737.3758, 691.0, 1359.5172, 826.0],
#   100: [866.9118000000001, 691.0, 1359.5172000000002, 766.0],
#   101: [901.0191000000001, 691.0, 1359.5172000000002, 751.0],
#   102: [927.6982, 691.0, 1350.1803, 736.0],
#   103: [949.6982, 691.0, 1350.1803, 721.0],
#   104: [977.4773, 691.0, 1350.1803, 706.0],
#   105: [977.4773, 706.0, 1340.3553, 721.0],
#   106: [949.6982, 721.0, 1305.8137000000002, 736.0],
#   107: [927.6982, 736.0, 1359.5172, 751.0],
#   108: [901.0191000000001, 751.0, 1266.5491000000002, 766.0],
#   109: [866.9118000000001, 766.0, 1331.8034, 826.0],
#   110: [873.9118000000001, 766.0, 1331.8034, 796.0],
#   111: [902.6864, 766.0, 1331.8034, 781.0],
#   112: [902.6864, 781.0, 1230.8744000000002, 796.0],
#   113: [873.9118000000001, 796.0, 1245.7296000000001, 826.0],
#   114: [880.9118000000001, 796.0, 1245.7296000000001, 811.0],
#   115: [880.9118000000001, 811.0, 1227.4748, 826.0],
#   116: [737.3758, 826.0, 1037.118, 841.0],
#   117: [406.5878, 841.0, 668.9878, 856.0],
#   118: [316.35650000000004, 856.0, 925.35769, 1261.0],
#   119: [356.7762, 856.0, 925.35769, 1216.0],
#   120: [378.7762, 856.0, 925.35769, 1201.0],
#   121: [411.9492, 856.0, 858.78745, 1036.0],
#   122: [449.5161, 856.0, 858.78745, 1006.0],
#   123: [465.5161, 856.0, 858.78745, 991.0],
#   124: [472.5161, 856.0, 858.78745, 976.0],
#   125: [481.90788, 856.0, 858.78745, 916.0],
#   126: [503.90788, 856.0, 858.78745, 901.0],
#   127: [510.90788, 856.0, 858.78745, 886.0],
#   128: [532.90788, 856.0, 858.78745, 871.0],
#   129: [532.90788, 871.0, 783.4731899999999, 886.0],
#   130: [510.90788, 886.0, 833.58233, 901.0],
#   131: [503.90788, 901.0, 846.55978, 916.0],
#   132: [481.90788, 916.0, 836.28675, 976.0],
#   133: [488.90788, 916.0, 836.28675, 961.0],
#   134: [495.90788, 916.0, 836.28675, 946.0],
#   135: [502.90788, 916.0, 673.27992, 931.0],
#   136: [502.90788, 931.0, 836.28675, 946.0],
#   137: [495.90788, 946.0, 666.28386, 961.0],
#   138: [488.90788, 961.0, 718.88829, 976.0],
#   139: [472.5161, 976.0, 734.61447, 991.0],
#   140: [465.5161, 991.0, 723.73551, 1006.0],
#   141: [449.5161, 1006.0, 726.9899, 1036.0],
#   142: [465.5161, 1006.0, 725.53504, 1021.0],
#   143: [465.5161, 1021.0, 726.9899, 1036.0],
#   144: [411.9492, 1036.0, 925.35769, 1201.0],
#   145: [478.9987, 1036.0, 925.35769, 1186.0],
#   146: [500.9987, 1036.0, 925.35769, 1141.0],
#   147: [522.9987, 1036.0, 925.35769, 1126.0],
#   148: [544.9987, 1036.0, 925.35769, 1111.0],
#   149: [566.9987, 1036.0, 925.35769, 1096.0],
#   150: [577.7983, 1036.0, 925.35769, 1081.0],
#   151: [584.7983, 1036.0, 925.35769, 1066.0],
#   152: [591.7983, 1036.0, 925.35769, 1051.0],
#   153: [591.7983, 1051.0, 827.32674, 1066.0],
#   154: [584.7983, 1066.0, 828.3184000000001, 1081.0],
#   155: [577.7983, 1081.0, 919.9199600000001, 1096.0],
#   156: [566.9987, 1096.0, 814.9696, 1111.0],
#   157: [544.9987, 1111.0, 796.95191, 1126.0],
#   158: [522.9987, 1126.0, 697.58057, 1141.0],
#   159: [500.9987, 1141.0, 852.0822000000001, 1186.0],
#   160: [522.9987, 1141.0, 852.0822000000001, 1171.0],
#   161: [529.9987, 1141.0, 705.4476199999999, 1156.0],
#   162: [529.9987, 1156.0, 852.0822000000001, 1171.0],
#   163: [522.9987, 1171.0, 699.54214, 1186.0],
#   164: [478.9987, 1186.0, 731.30783, 1201.0],
#   165: [378.7762, 1201.0, 638.764, 1216.0],
#   166: [356.7762, 1216.0, 703.4997000000001, 1261.0],
#   167: [429.6566, 1216.0, 703.4997000000001, 1246.0],
#   168: [451.6566, 1216.0, 700.4391, 1231.0],
#   169: [451.6566, 1231.0, 703.4997000000001, 1246.0],
#   170: [429.6566, 1246.0, 680.08834, 1261.0],
#   171: [268.2952, 1261.0, 821.9162200000001, 1396.0],
#   172: [402.7642, 1261.0, 821.9162200000001, 1381.0],
#   173: [409.7642, 1261.0, 821.9162200000001, 1321.0],
#   174: [431.7642, 1261.0, 821.9162200000001, 1306.0],
#   175: [479.6634, 1261.0, 821.9162200000001, 1291.0],
#   176: [486.6634, 1261.0, 819.39086, 1276.0],
#   177: [486.6634, 1276.0, 821.9162200000001, 1291.0],
#   178: [479.6634, 1291.0, 639.1215400000001, 1306.0],
#   179: [431.7642, 1306.0, 608.1283000000001, 1321.0],
#   180: [409.7642, 1321.0, 650.55619, 1381.0],
#   181: [416.7642, 1321.0, 650.55619, 1366.0],
#   182: [423.7642, 1321.0, 650.55619, 1351.0],
#   183: [430.7642, 1321.0, 650.55619, 1336.0],
#   184: [430.7642, 1336.0, 586.42129, 1351.0],
#   185: [423.7642, 1351.0, 584.90408, 1366.0],
#   186: [416.7642, 1366.0, 634.14813, 1381.0],
#   187: [402.7642, 1381.0, 551.00855, 1396.0],
#   188: [198.3489, 1396.0, 623.3679, 1411.0],
#   189: [41.6119, 1411.0, 1055.00709, 1591.0],
#   190: [168.8719, 1411.0, 1055.00709, 1531.0],
#   191: [224.5249, 1411.0, 1042.5699, 1501.0],
#   192: [319.131, 1411.0, 1042.5699, 1486.0],
#   193: [413.6239, 1411.0, 1032.1098, 1471.0],
#   194: [728.9359, 1411.0, 1032.1098, 1456.0],
#   195: [735.9359, 1411.0, 1032.1098, 1441.0],
#   196: [757.9359, 1411.0, 1032.1098, 1426.0],
#   197: [757.9359, 1426.0, 1029.20902, 1441.0],
#   198: [735.9359, 1441.0, 1006.6851399999999, 1456.0],
#   199: [728.9359, 1456.0, 1002.95256, 1471.0],
#   200: [413.6239, 1471.0, 1042.5699, 1486.0],
#   201: [319.131, 1486.0, 894.38, 1501.0],
#   202: [224.5249, 1501.0, 1055.00709, 1531.0],
#   203: [762.5958999999999, 1501.0, 996.9728899999999, 1516.0],
#   204: [762.5958999999999, 1516.0, 1055.0070899999998, 1531.0],
#   205: [168.8719, 1531.0, 1051.0199, 1591.0],
#   206: [305.8109, 1531.0, 1051.0199, 1576.0],
#   207: [430.4489, 1531.0, 997.506, 1561.0],
#   208: [598.0238999999999, 1531.0, 980.6469, 1546.0],
#   209: [598.0238999999999, 1546.0, 997.5059999999999, 1561.0],
#   210: [430.4489, 1561.0, 1051.0198999999998, 1576.0],
#   211: [305.8109, 1576.0, 887.9679000000001, 1591.0],
#   212: [8.0, 1591.0, 1080.213, 1651.0],
#   213: [646.626, 1591.0, 1022.57273, 1636.0],
#   214: [765.2339999999999, 1591.0, 1022.5727299999999, 1621.0],
#   215: [772.2339999999999, 1591.0, 987.3070399999999, 1606.0],
#   216: [772.2339999999999, 1606.0, 1022.5727299999999, 1621.0],
#   217: [765.2339999999999, 1621.0, 1013.7271099999999, 1636.0],
#   218: [646.626, 1636.0, 1080.213, 1651.0]}}
