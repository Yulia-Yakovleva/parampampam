# %%
pth_to_stats = '/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv'
pth_to_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S/formated_id_full.fa'
pth_to_its = '/home/yulia/parampampam/raw_data/fasta_files/ITS/formated_id_with_add.fa'

outf_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa'
outf_its = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa'

# %%
import pandas as pd
from Bio import SeqIO

ssu_out = []
its_out = []


df = pd.read_csv(pth_to_stats, sep='\t')
ssu_recs = [rec for rec in SeqIO.parse(pth_to_ssu, 'fasta')]
its_recs = [rec for rec in SeqIO.parse(pth_to_its, 'fasta')]

foursev_its_recs = []
c = 0
with open(outf_its, 'w') as out_f:
    for its in df.its_id:
        foursev_its_recs.append(its)
        c+=1
        for rec in its_recs:
            if its == rec.name:
                its_out.append(rec)
                SeqIO.write(rec, out_f, 'fasta')
print(c)

foursev_ssu_recs = []
c = 0
with open(outf_ssu, 'w') as out_f:
    for ssu in df.ssu_id:
        foursev_ssu_recs.append(ssu)
        c+=1
        for rec in ssu_recs:
            if ssu == rec.name:
                ssu_out.append(rec)
                SeqIO.write(rec, out_f, 'fasta')

ssu_names = set()
with open(outf_ssu, 'r') as ssu_f:
    for line in ssu_f:
        line = line.strip()
        if line.startswith('>'):
            ssu_names.add(line[1:])
            
its_names = set()
with open(outf_its, 'r') as its_f:
    for line in its_f:
        line = line.strip()
        if line.startswith('>'):
            its_names.add(line[1:])

# check fails
for name in foursev_its_recs:
    print(name)
    if name not in its_names:
        print(name, 'here')
# Out:
# 47
# 954787BF1B
# 55CEC58B7B
# A22A7EB077
# 84CE765D07
# A9D77FB142
# C0FF30338F
# 6A22C8816B
# A100F8A811
# FFCD65A9C1
# FE6BF56E99
# BAFBB32B3C
# 9F17B676E6
# A28E935B8D
# E4C28EC0EC
# D4CE20BD5A
# E24B3A4289
# 7EB0465780
# 87876A753A
# 5EDFE55A10
# 3B4F40C1B6
# 4C5F4E4CDE
# A50EB0413A
# 20D1316E5D
# 8E203F786B
# 4571A227E6
# 317A91CB34
# 754C622D24
# AFED3029BB
# 0C044FF14F
# F5F4A73DA3
# 3232DFC4C6
# 70890594D2
# 7AB785E8EB
# F2145CCC2C
# 7760F61162
# ABB2EFBA0D
# 06BCC826BF
# 7337CC22D1
# 55622BCCF2
# E5A80E2658
# 1B54F3DD84
# 4EC675C343
# 05EB3CB2EF
# FT8_ITS
# E53453BD54
# E53453BD54 here
# 27457DB888
# 27457DB888 here
# B9FA7E99CC
# B9FA7E99CC here

# %%
# для Максима
import pandas as pd

def rename_ids(stats, in_f, out_f):
    df = pd.read_csv(stats, sep='\t')
    with open(in_f) as inf, open(out_f, 'w') as outf:
        for line in inf:
            for idx, descr in zip(df['Unnamed: 0'], df['description']):
                if idx in line:
                    line = line.replace(idx, descr)
            outf.write(line)
                
                
stats = '/home/yulia/parampampam/raw_data/stats/COI/stats_final.tsv'
in_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/mafft_aln_fianl_more_outgroup_full.fa'
out_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/COI_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/18S/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/18S/18S_GBlocks_regions_3.fst'
out_f = '/home/yulia/parampampam/alignments/18S/SSU_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/ITS/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/ITS/ITS_GBlocks_2.fst'
out_f = '/home/yulia/parampampam/alignments/ITS/ITS_normal_names.fa'

rename_ids(stats, in_f, out_f)

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa > /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    45 /46
# Reallocating..done. *alloclen = 6654
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-2851
# STEP 003-006-1  identical.    identical.    accepted. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    rejected. identical.    rejected. identical.    rejected. identical.    accepted. identical.    identical.    identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    identical.    rejected. identical.    identical.    accepted. accepted. accepted. identical.    identical.    accepted. identical.    identical.    identical.    accepted. identical.    identical.    accepted. identical.    identical.    rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    rejected. rejected. identical.    rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 1.4 s, sys: 224 ms, total: 1.62 s
# Wall time: 51.3 s

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa > /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    41 /46
# Reallocating..done. *alloclen = 6844
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-3086
# STEP 003-004-1  identical.    identical.    identical.    identical.    identical.    identical.    identical.    accepted. identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    rejected. identical.    rejected. identical.    rejected. identical.    identical.    accepted. rejected. identical.    accepted. accepted. accepted. identical.    accepted. identical.    accepted. accepted. identical.    rejected. rejected. accepted. rejected. identical.    rejected. rejected. rejected. identical.    identical.    rejected. rejected. identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 1.73 s, sys: 263 ms, total: 1.99 s
# Wall time: 1min 6s

# %%
# назвать ssu сиквенсы айдишниками its 
from Bio import SeqIO

ssu_in = '/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions.fa'
its_in = '/home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln_regions.fa'
ssu_out ='/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions_renamed.fa'

names = []
its_recs = [rec for rec in SeqIO.parse(its_in, 'fasta')]
for rec in its_recs:
    names.append(rec.name)

out_recs = []
ssu_recs = [rec for rec in SeqIO.parse(ssu_in, 'fasta')]
for rec, its_name in zip(ssu_recs, names):
    rec.id = its_name
    rec.name = its_name
    rec.description = its_name
    out_recs.append(rec)
    
with open(ssu_out, 'w') as out_f:
    for rec in out_recs:
        SeqIO.write(rec, out_f, 'fasta')

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/con_50_majrule.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# ((Paramecium putrinum ETu 7-4 MG573199.1:0.159966,(Pdub HE819875.1:0.000968492,HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.000897751)1.00:0.0781682)1.00:0.0799076,(Paramecium nephridiatum Sr 2-6 MG573198.1:0.0658341,(MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000522479,KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000519368)1.00:0.148427)0.99:0.0260365,(KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.0992306,(((((((HSG3-10 ITS:0.00320901,SP-1:0.000496846)0.78:0.00107884,CD11-9:0.00248232):0,ShKm41:0.000480933)0.57:0.00108259,PO-16:0.000776792)1.00:0.0348463,K5-2:0.0122904)1.00:0.0311682,Paramecium jenningsi FL KF110697.1:0.0029335)1.00:0.0499551,((Paramecium primaurelia ThK-1 MG573194.1:0.00140471,(((Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.000490472,12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.000487421)0.97:0.00283253,((((strain14 PP-2:0.000481751,((SMM81-1:0.000492758,FCB10-1:0.000485082):0,PL4-1:0.000490188)0.79:0.00112374):0,(CyL3-21:0.000584257,T42-1:0.0030762)0.62:0.00104568):0,6 Paramecium multimicronucleatum OP13 JF741217.1:0.00117314)0.86:0.00285001,HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan:0.0544022)0.93:0.00444086)1.00:0.0237363,(((((((((((((ThK-16:0.00049227,CyP5-3:0.00115954):0,MSA-5:0.00521921):0,16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.000483867):0,17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.00119072)0.66:0.00178056,(LB-1:0.00186692,SK6-3:0.000506291)0.98:0.00116118):0,K4-2:0.000495986):0,L72-1:0.000494617):0,R51-6:0.000490965):0,ChP5-3:0.000492154):0,ChP10-2:0.00117308):0,OmN-1:0.00187206):0,Or4-3:0.00255944):0,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00118294)0.79:0.00678048)1.00:0.0343497)1.00:0.0252332,((Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00241111,Paramecium primaurelia CyL4-1 MH185950.1:0.0011041):0,(Paramecium primaurelia 16/IP 17-21 MG573196.1:0.000488332,(((Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.000483778,Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.00115624):0,Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.000486184)1.00:0.0117638,Paramecium pentaurelia strain Nr1-10 MG573197.1:0.000562292)0.85:0.00113664):0)1.00:0.0103723)0.78:0.0103114)1.00:0.0919052)0.87:0.0230441);

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# (("Paramecium putrinum ETu 7-4 MG573199.1":0.159966,("Pdub HE819875.1":0.000968492,"HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":0.000897751)1.00:0.0781682):0.0759122,(("Paramecium nephridiatum Sr 2-6 MG573198.1":0.0658341,("MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000522479,"KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000519368)1.00:0.148427)0.99:0.0260365,("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0992306,((((((("HSG3-10 ITS":0.00320901,"SP-1":0.000496846)0.78:0.00107884,"CD11-9":0.00248232):0,"ShKm41":0.000480933)0.57:0.00108259,"PO-16":0.000776792)1.00:0.0348463,"K5-2":0.0122904)1.00:0.0311682,"Paramecium jenningsi FL KF110697.1":0.0029335)1.00:0.0499551,(("Paramecium primaurelia ThK-1 MG573194.1":0.00140471,((("Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":0.000490472,"12 Paramecium multimicronucleatum AB9-8 JF741240.1":0.000487421)0.97:0.00283253,(((("strain14 PP-2":0.000481751,(("SMM81-1":0.000492758,"FCB10-1":0.000485082):0,"PL4-1":0.000490188)0.79:0.00112374):0,("CyL3-21":0.000584257,"T42-1":0.0030762)0.62:0.00104568):0,"6 Paramecium multimicronucleatum OP13 JF741217.1":0.00117314)0.86:0.00285001,"HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan":0.0544022)0.93:0.00444086)1.00:0.0237363,((((((((((((("ThK-16":0.00049227,"CyP5-3":0.00115954):0,"MSA-5":0.00521921):0,"16 Paramecium multimicronucleatum Ns2-16 JF741224.1":0.000483867):0,"17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.00119072)0.66:0.00178056,("LB-1":0.00186692,"SK6-3":0.000506291)0.98:0.00116118):0,"K4-2":0.000495986):0,"L72-1":0.000494617):0,"R51-6":0.000490965):0,"ChP5-3":0.000492154):0,"ChP10-2":0.00117308):0,"OmN-1":0.00187206):0,"Or4-3":0.00255944):0,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.00118294)0.79:0.00678048)1.00:0.0343497)1.00:0.0252332,(("Paramecium primaurelia 16/IP 4-1 MG573195.1":0.00241111,"Paramecium primaurelia CyL4-1 MH185950.1":0.0011041):0,("Paramecium primaurelia 16/IP 17-21 MG573196.1":0.000488332,((("Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":0.000483778,"Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00115624):0,"Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":0.000486184)1.00:0.0117638,"Paramecium pentaurelia strain Nr1-10 MG573197.1":0.000562292)0.85:0.00113664):0)1.00:0.0103723)0.78:0.0103114)1.00:0.0919052)0.87:0.0230441):0.00399538)1.00;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', format=0, quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/mb_ete_tree_.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1067.8771982192993, 8.0, 1080.8771982192993, 0, '1'],
#   [8.0, 991.0043964385986, 15.0, 1004.0043964385986, 1, '1'],
#   [27.56615, 912.2587928771973, 49.56615, 925.2587928771973, 2, '0.87'],
#   [180.42395, 811.0175857543945, 187.42395, 824.0175857543945, 3, '1'],
#   [187.42395, 658.1445465087891, 209.42395, 671.1445465087891, 4, '0.78'],
#   [240.27375, 545.7578430175781, 247.27375, 558.7578430175781, 5, '1'],
#   [291.7983, 453.01568603515625, 298.7983, 466.01568603515625, 6, '1'],
#   [298.7983, 338.4298095703125, 320.7983, 351.4298095703125, 7, '0.79'],
#   [320.7983, 313.359619140625, 327.7983, 326.359619140625, 8, '1'],
#   [327.7983, 288.21923828125, 334.7983, 301.21923828125, 9, '1'],
#   [334.7983, 262.9384765625, 341.7983, 275.9384765625, 10, '1'],
#   [341.7983, 237.376953125, 348.7983, 250.376953125, 11, '1'],
#   [348.7983, 211.25390625, 355.7983, 224.25390625, 12, '1'],
#   [355.7983, 184.0078125, 362.7983, 197.0078125, 13, '1'],
#   [362.7983, 154.515625, 369.7983, 167.515625, 14, '1'],
#   [369.7983, 120.53125, 376.7983, 133.53125, 15, '1'],
#   [376.7983, 90.0625, 398.7983, 103.0625, 16, '0.66'],
#   [398.7983, 66.625, 405.7983, 79.625, 17, '1'],
#   [405.7983, 44.75, 412.7983, 57.75, 18, '1'],
#   [412.7983, 26.0, 419.7983, 39.0, 19, '1'],
#   [421.53761, 6.0, 465.53761, 21.0, 20, 'CyP5-3'],
#   [420.536705, 31.0, 463.536705, 46.0, 21, 'ThK-16'],
#   [420.627115, 56.0, 460.627115, 71.0, 22, 'MSA-5'],
#   [406.5241005,
#    81.0,
#    738.5241005,
#    96.0,
#    23,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [400.58438,
#    106.0,
#    738.58438,
#    121.0,
#    24,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [376.7983, 151.0, 398.7983, 164.0, 25, '0.98'],
#   [399.5577365, 131.0, 436.5577365, 146.0, 26, 'SK6-3'],
#   [401.59868, 156.0, 429.59868, 171.0, 27, 'LB-1'],
#   [370.542279, 181.0, 398.542279, 196.0, 28, 'K4-2'],
#   [363.54022549999996, 206.0, 397.54022549999996, 221.0, 29, 'L72-1'],
#   [356.5347475, 231.0, 392.5347475, 246.0, 30, 'R51-6'],
#   [349.53653099999997, 256.0, 394.53653099999997, 271.0, 31, 'ChP5-3'],
#   [343.55791999999997, 281.0, 395.55791999999997, 296.0, 32, 'ChP10-2'],
#   [337.60639, 306.0, 379.60639, 321.0, 33, 'OmN-1'],
#   [331.63746, 331.0, 365.63746, 346.0, 34, 'Or4-3'],
#   [322.57271,
#    356.0,
#    643.5727099999999,
#    371.0,
#    35,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [327.40274999999997, 567.6015625, 334.40274999999997, 580.6015625, 36, '1'],
#   [334.40274999999997, 534.203125, 356.40274999999997, 547.203125, 37, '0.93'],
#   [356.40274999999997, 504.90625, 378.40274999999997, 517.90625, 38, '0.86'],
#   [378.40274999999997, 471.3125, 385.40274999999997, 484.3125, 39, '1'],
#   [385.40274999999997, 441.625, 392.40274999999997, 454.625, 40, '1'],
#   [392.40274999999997, 419.75, 414.40274999999997, 432.75, 41, '0.79'],
#   [414.40274999999997, 401.0, 421.40274999999997, 414.0, 42, '1'],
#   [422.13037299999996, 381.0, 474.13037299999996, 396.0, 43, 'FCB10-1'],
#   [422.141887, 406.0, 479.141887, 421.0, 44, 'SMM81-1'],
#   [415.13803199999995, 431.0, 450.13803199999995, 446.0, 45, 'PL4-1'],
#   [393.12537649999996, 456.0, 472.12537649999996, 471.0, 46, 'strain14 PP-2'],
#   [385.40274999999997, 501.0, 407.40274999999997, 514.0, 47, '0.62'],
#   [412.01705, 481.0, 446.01705, 496.0, 48, 'T42-1'],
#   [408.27913549999994, 506.0, 458.27913549999994, 521.0, 49, 'CyL3-21'],
#   [380.16245999999995,
#    531.0,
#    696.16246,
#    546.0,
#    50,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [438.00604999999996,
#    556.0,
#    825.00605,
#    571.0,
#    51,
#    'HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan'],
#   [334.40274999999997, 601.0, 356.40274999999997, 614.0, 52, '0.97'],
#   [357.1338815,
#    581.0,
#    682.1338814999999,
#    596.0,
#    53,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [357.13845799999996,
#    606.0,
#    700.1384579999999,
#    621.0,
#    54,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [249.38081499999998,
#    631.0,
#    508.380815,
#    646.0,
#    55,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [217.98239999999998, 770.53125, 224.98239999999998, 783.53125, 56, '1'],
#   [224.98239999999998, 740.0625, 231.98239999999998, 753.0625, 57, '1'],
#   [231.98239999999998, 716.625, 253.98239999999998, 729.625, 58, '0.85'],
#   [264.62809999999996, 694.75, 271.62809999999996, 707.75, 59, '1'],
#   [271.62809999999996, 676.0, 278.62809999999996, 689.0, 60, '1'],
#   [280.36245999999994,
#    656.0,
#    599.3624599999999,
#    671.0,
#    61,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [279.35376699999995,
#    681.0,
#    591.353767,
#    696.0,
#    62,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [272.357376,
#    706.0,
#    583.3573759999999,
#    721.0,
#    63,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [254.82583799999998,
#    731.0,
#    553.825838,
#    746.0,
#    64,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [232.714898,
#    756.0,
#    522.714898,
#    771.0,
#    65,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [224.98239999999998, 801.0, 231.98239999999998, 814.0, 66, '1'],
#   [233.63855,
#    781.0,
#    498.63855,
#    796.0,
#    67,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [235.599065,
#    806.0,
#    511.599065,
#    821.0,
#    68,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [255.35660000000001, 963.890625, 262.3566, 976.890625, 69, '1'],
#   [302.1089, 939.28125, 309.1089, 952.28125, 70, '1'],
#   [354.37835, 915.0625, 361.37835, 928.0625, 71, '1'],
#   [361.37835, 891.625, 383.37835, 904.625, 72, '0.57'],
#   [383.37835, 869.75, 390.37835, 882.75, 73, '1'],
#   [390.37835, 851.0, 412.37835, 864.0, 74, '0.78'],
#   [413.123619, 831.0, 442.123619, 846.0, 75, 'SP-1'],
#   [417.191865, 856.0, 495.191865, 871.0, 76, 'HSG3-10 ITS'],
#   [394.10183, 881.0, 439.10183, 896.0, 77, 'CD11-9'],
#   [384.09974950000003, 906.0, 434.09974950000003, 921.0, 78, 'ShKm41'],
#   [362.543538, 931.0, 400.543538, 946.0, 79, 'PO-16'],
#   [327.5445, 956.0, 355.5445, 971.0, 80, 'K5-2'],
#   [266.75685,
#    981.0,
#    487.75685,
#    996.0,
#    81,
#    'Paramecium jenningsi FL KF110697.1'],
#   [198.41205000000002,
#    1006.0,
#    524.41205,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [32.05475, 1069.75, 54.05475, 1082.75, 83, '0.99'],
#   [269.69525, 1051.0, 276.69525, 1064.0, 84, '1'],
#   [277.47430199999997,
#    1031.0,
#    702.474302,
#    1046.0,
#    85,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [277.4789685,
#    1056.0,
#    706.4789685000001,
#    1071.0,
#    86,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [152.8059,
#    1081.0,
#    422.8059,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [114.8683, 1144.75, 121.8683, 1157.75, 88, '1'],
#   [232.1206, 1126.0, 239.1206, 1139.0, 89, '1'],
#   [240.4672265,
#    1106.0,
#    699.4672265,
#    1121.0,
#    90,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [240.57333799999998, 1131.0, 347.573338, 1146.0, 91, 'Pdub HE819875.1'],
#   [361.81729999999993,
#    1156.0,
#    617.8172999999999,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 825.00605, 1176.0],
#   1: [8.0, 1.0, 825.00605, 1101.0],
#   2: [15.0, 1.0, 825.00605, 1026.0],
#   3: [49.56615, 1.0, 825.00605, 1001.0],
#   4: [187.42395, 1.0, 825.00605, 826.0],
#   5: [209.42395, 1.0, 825.00605, 651.0],
#   6: [247.27375, 1.0, 825.00605, 626.0],
#   7: [298.7983, 1.0, 738.58438, 376.0],
#   8: [320.7983, 1.0, 738.58438, 351.0],
#   9: [327.7983, 1.0, 738.58438, 326.0],
#   10: [334.7983, 1.0, 738.58438, 301.0],
#   11: [341.7983, 1.0, 738.58438, 276.0],
#   12: [348.7983, 1.0, 738.58438, 251.0],
#   13: [355.7983, 1.0, 738.58438, 226.0],
#   14: [362.7983, 1.0, 738.58438, 201.0],
#   15: [369.7983, 1.0, 738.58438, 176.0],
#   16: [376.7983, 1.0, 738.58438, 126.0],
#   17: [398.7983, 1.0, 738.5241005, 101.0],
#   18: [405.7983, 1.0, 465.53761, 76.0],
#   19: [412.7983, 1.0, 465.53761, 51.0],
#   20: [419.7983, 1.0, 465.53761, 26.0],
#   21: [419.7983, 26.0, 463.536705, 51.0],
#   22: [412.7983, 51.0, 460.627115, 76.0],
#   23: [405.7983, 76.0, 738.5241005, 101.0],
#   24: [398.7983, 101.0, 738.58438, 126.0],
#   25: [376.7983, 126.0, 436.5577365, 176.0],
#   26: [398.7983, 126.0, 436.5577365, 151.0],
#   27: [398.7983, 151.0, 429.59868, 176.0],
#   28: [369.7983, 176.0, 398.542279, 201.0],
#   29: [362.7983, 201.0, 397.54022549999996, 226.0],
#   30: [355.7983, 226.0, 392.5347475, 251.0],
#   31: [348.7983, 251.0, 394.53653099999997, 276.0],
#   32: [341.7983, 276.0, 395.55791999999997, 301.0],
#   33: [334.7983, 301.0, 379.60639, 326.0],
#   34: [327.7983, 326.0, 365.63746, 351.0],
#   35: [320.7983, 351.0, 643.5727099999999, 376.0],
#   36: [298.7983, 376.0, 825.00605, 626.0],
#   37: [334.40274999999997, 376.0, 825.00605, 576.0],
#   38: [356.40274999999997, 376.0, 696.16246, 551.0],
#   39: [378.40274999999997, 376.0, 479.141887, 526.0],
#   40: [385.40274999999997, 376.0, 479.141887, 476.0],
#   41: [392.40274999999997, 376.0, 479.141887, 451.0],
#   42: [414.40274999999997, 376.0, 479.141887, 426.0],
#   43: [421.40274999999997, 376.0, 474.13037299999996, 401.0],
#   44: [421.40274999999997, 401.0, 479.141887, 426.0],
#   45: [414.40274999999997, 426.0, 450.13803199999995, 451.0],
#   46: [392.40274999999997, 451.0, 472.12537649999996, 476.0],
#   47: [385.40274999999997, 476.0, 458.27913549999994, 526.0],
#   48: [407.40274999999997, 476.0, 446.01705, 501.0],
#   49: [407.40274999999997, 501.0, 458.27913549999994, 526.0],
#   50: [378.40274999999997, 526.0, 696.16246, 551.0],
#   51: [356.40274999999997, 551.0, 825.00605, 576.0],
#   52: [334.40274999999997, 576.0, 700.1384579999999, 626.0],
#   53: [356.40274999999997, 576.0, 682.1338814999999, 601.0],
#   54: [356.40274999999997, 601.0, 700.1384579999999, 626.0],
#   55: [247.27375, 626.0, 508.380815, 651.0],
#   56: [209.42395, 651.0, 599.3624599999999, 826.0],
#   57: [224.98239999999998, 651.0, 599.3624599999999, 776.0],
#   58: [231.98239999999998, 651.0, 599.3624599999999, 751.0],
#   59: [253.98239999999998, 651.0, 599.3624599999999, 726.0],
#   60: [271.62809999999996, 651.0, 599.3624599999999, 701.0],
#   61: [278.62809999999996, 651.0, 599.3624599999999, 676.0],
#   62: [278.62809999999996, 676.0, 591.353767, 701.0],
#   63: [271.62809999999996, 701.0, 583.3573759999999, 726.0],
#   64: [253.98239999999998, 726.0, 553.825838, 751.0],
#   65: [231.98239999999998, 751.0, 522.714898, 776.0],
#   66: [224.98239999999998, 776.0, 511.599065, 826.0],
#   67: [231.98239999999998, 776.0, 498.63855, 801.0],
#   68: [231.98239999999998, 801.0, 511.599065, 826.0],
#   69: [187.42395, 826.0, 495.191865, 1001.0],
#   70: [262.3566, 826.0, 495.191865, 976.0],
#   71: [309.1089, 826.0, 495.191865, 951.0],
#   72: [361.37835, 826.0, 495.191865, 926.0],
#   73: [383.37835, 826.0, 495.191865, 901.0],
#   74: [390.37835, 826.0, 495.191865, 876.0],
#   75: [412.37835, 826.0, 442.123619, 851.0],
#   76: [412.37835, 851.0, 495.191865, 876.0],
#   77: [390.37835, 876.0, 439.10183, 901.0],
#   78: [383.37835, 901.0, 434.09974950000003, 926.0],
#   79: [361.37835, 926.0, 400.543538, 951.0],
#   80: [309.1089, 951.0, 355.5445, 976.0],
#   81: [262.3566, 976.0, 487.75685, 1001.0],
#   82: [49.56615, 1001.0, 524.41205, 1026.0],
#   83: [15.0, 1026.0, 706.4789685000001, 1101.0],
#   84: [54.05475, 1026.0, 706.4789685000001, 1076.0],
#   85: [276.69525, 1026.0, 702.474302, 1051.0],
#   86: [276.69525, 1051.0, 706.4789685000001, 1076.0],
#   87: [54.05475, 1076.0, 422.8059, 1101.0],
#   88: [8.0, 1101.0, 699.4672265, 1176.0],
#   89: [121.8683, 1101.0, 699.4672265, 1151.0],
#   90: [239.1206, 1101.0, 699.4672265, 1126.0],
#   91: [239.1206, 1126.0, 347.573338, 1151.0],
#   92: [121.8683, 1151.0, 617.8172999999999, 1176.0]}}

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_bipartitions.result', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# ((Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.00000100000050002909,Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.00000100000050002909)78:0.00000100000050002909,(Paramecium pentaurelia strain Nr1-10 MG573197.1:0.00000100000050002909,(Paramecium primaurelia CyL4-1 MH185950.1:0.00036552329531847657,(Paramecium primaurelia 16/IP 17-21 MG573196.1:0.00000100000050002909,(Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00109858396286434379,((Paramecium primaurelia ThK-1 MG573194.1:0.00033566089789796886,(((12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.00000100000050002909,Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.00000100000050002909)100:0.00124368240731060611,(HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan:0.03123226739696923979,(((6 Paramecium multimicronucleatum OP13 JF741217.1:0.00036950788816404468,(T42-1:0.00147653546146667169,CyL3-21:0.00000100000050002909)54:0.00028631304361645984)55:0.00008218398760445993,strain14 PP-2:0.00000100000050002909)28:0.00000100000050002909,((PL4-1:0.00000100000050002909,FCB10-1:0.00000100000050002909)28:0.00000100000050002909,SMM81-1:0.00000100000050002909)70:0.00036766983225397851)94:0.00116201795430582685)27:0.00206750197721128131)66:0.01239135966112917854,((Or4-3:0.00111305268262485791,(((((16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.00000100000050002909,17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.00037220883451932063)66:0.00000100000050002909,(CyP5-3:0.00037018756500057585,MSA-5:0.00262899908388838748)29:0.00000100000050002909)0:0.00000100000050002909,ThK-16:0.00000100000050002909)61:0.00074126377183246646,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00037267981893100461)2:0.00000100000050002909,ChP5-3:0.00000100000050002909)3:0.00000100000050002909)18:0.00036928218882410687,((((LB-1:0.00074082939758374612,SK6-3:0.00000100000050002909)67:0.00037040425126952701,OmN-1:0.00074147671860648099)22:0.00000100000050002909,ChP10-2:0.00037037962415188984)1:0.00000100000050002909,((K4-2:0.00000100000050002909,L72-1:0.00000100000050002909)22:0.00000100000050002909,R51-6:0.00000100000050002909)37:0.00000100000050002909)59:0.00000100000050002909)51:0.00330884676254813905)91:0.01950118121909326374)86:0.01511311828836693107,((((Paramecium putrinum ETu 7-4 MG573199.1:0.09808307381111057432,(HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.00000100000050002909,Pdub HE819875.1:0.00042780676157963082)100:0.04610538271759073020)100:0.04855330854303629290,(Paramecium nephridiatum Sr 2-6 MG573198.1:0.03874860372342901066,(KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909,MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909)100:0.09072872384879329677)92:0.01406208729136564084)85:0.01235391777745888445,KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.05875010627885347142)100:0.05472332232219091069,(Paramecium jenningsi FL KF110697.1:0.00105128977179792240,((PO-16:0.00000100000050002909,((ShKm41:0.00000100000050002909,(SP-1:0.00000100000050002909,HSG3-10 ITS:0.00147718877317493352)63:0.00036472072760562502)8:0.00000100000050002909,CD11-9:0.00109629886085047565)63:0.00036460451911384710)100:0.01973832767709967836,K5-2:0.00666729268482950475)75:0.01775426311262667811)100:0.02820231786140228389)72:0.00509409712789645527)85:0.00559679776122058714)25:0.00000100000050002909)3:0.00000100000050002909)53:0.00036550631900386605)100:0.00636918833037019346,Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.000367350457606 ...

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# (("Paramecium putrinum ETu 7-4 MG573199.1":0.0980831,("HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":1e-06,"Pdub HE819875.1":0.000427807)100:0.0461054):0.0461256,(("Paramecium nephridiatum Sr 2-6 MG573198.1":0.0387486,("KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06,"MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06)100:0.0907287)92:0.0140621,("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0587501,(("Paramecium jenningsi FL KF110697.1":0.00105129,(("PO-16":1e-06,(("ShKm41":1e-06,("SP-1":1e-06,"HSG3-10 ITS":0.00147719)63:0.000364721)8:1e-06,"CD11-9":0.0010963)63:0.000364605)100:0.0197383,"K5-2":0.00666729)75:0.0177543)100:0.0282023,(("Paramecium primaurelia ThK-1 MG573194.1":0.000335661,((("12 Paramecium multimicronucleatum AB9-8 JF741240.1":1e-06,"Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":1e-06)100:0.00124368,("HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan":0.0312323,((("6 Paramecium multimicronucleatum OP13 JF741217.1":0.000369508,("T42-1":0.00147654,"CyL3-21":1e-06)54:0.000286313)55:8.2184e-05,"strain14 PP-2":1e-06)28:1e-06,(("PL4-1":1e-06,"FCB10-1":1e-06)28:1e-06,"SMM81-1":1e-06)70:0.00036767)94:0.00116202)27:0.0020675)66:0.0123914,(("Or4-3":0.00111305,((((("16 Paramecium multimicronucleatum Ns2-16 JF741224.1":1e-06,"17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.000372209)66:1e-06,("CyP5-3":0.000370188,"MSA-5":0.002629)29:1e-06)0:1e-06,"ThK-16":1e-06)61:0.000741264,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.00037268)2:1e-06,"ChP5-3":1e-06)3:1e-06)18:0.000369282,(((("LB-1":0.000740829,"SK6-3":1e-06)67:0.000370404,"OmN-1":0.000741477)22:1e-06,"ChP10-2":0.00037038)1:1e-06,(("K4-2":1e-06,"L72-1":1e-06)22:1e-06,"R51-6":1e-06)37:1e-06)59:1e-06)51:0.00330885)91:0.0195012)86:0.0151131,("Paramecium primaurelia 16/IP 4-1 MG573195.1":0.00109858,("Paramecium primaurelia 16/IP 17-21 MG573196.1":1e-06,("Paramecium primaurelia CyL4-1 MH185950.1":0.000365523,("Paramecium pentaurelia strain Nr1-10 MG573197.1":1e-06,(("Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":1e-06,"Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":1e-06)78:1e-06,"Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00036735)100:0.00636919)53:0.000365506)3:1e-06)25:1e-06)85:0.0055968)72:0.0050941)100:0.0547233)85:0.0123539):0.00242767)100;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1067.58935546875, 20.0, 1080.58935546875, 0, '100'],
#   [20.0, 990.4287109375, 27.0, 1003.4287109375, 1, '1'],
#   [32.53085, 911.107421875, 45.53085, 924.107421875, 2, '85'],
#   [108.61580000000001,
#    808.71484375,
#    127.61580000000001,
#    821.71484375,
#    3,
#    '100'],
#   [127.61580000000001, 653.5390625, 140.6158, 666.5390625, 4, '72'],
#   [150.28545, 518.1875, 163.28545, 531.1875, 5, '86'],
#   [179.53725, 397.875, 192.53725, 410.875, 6, '91'],
#   [192.53725, 234.203125, 205.53725, 247.203125, 7, '51'],
#   [205.53725, 162.71875, 218.53725, 175.71875, 8, '18'],
#   [218.53725, 136.9375, 225.53725, 149.9375, 9, '3'],
#   [225.53725, 110.375, 232.53725, 123.375, 10, '2'],
#   [232.53725, 82.25, 245.53725, 95.25, 11, '61'],
#   [245.53725, 51.0, 252.53725, 64.0, 12, '0'],
#   [252.53725, 26.0, 265.53725, 39.0, 13, '29'],
#   [269.48074999999994, 6.0, 309.48074999999994, 21.0, 14, 'MSA-5'],
#   [266.09253199999995, 31.0, 310.09253199999995, 46.0, 15, 'CyP5-3'],
#   [252.53725, 76.0, 265.53725, 89.0, 16, '66'],
#   [266.09556349999997,
#    56.0,
#    604.0955635,
#    71.0,
#    17,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [265.53875,
#    81.0,
#    597.5387499999999,
#    96.0,
#    18,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [245.53875, 106.0, 288.53875, 121.0, 19, 'ThK-16'],
#   [233.09626999999998,
#    131.0,
#    554.09627,
#    146.0,
#    20,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [225.53875, 156.0, 270.53875, 171.0, 21, 'ChP5-3'],
#   [220.206825, 181.0, 254.206825, 196.0, 22, 'Or4-3'],
#   [205.53725, 305.6875, 218.53725, 318.6875, 23, '59'],
#   [218.53725, 266.625, 225.53725, 279.625, 24, '1'],
#   [225.53725, 244.75, 238.53725, 257.75, 25, '22'],
#   [238.53725, 226.0, 251.53725, 239.0, 26, '67'],
#   [251.53875, 206.0, 288.53875, 221.0, 27, 'SK6-3'],
#   [252.6484935, 231.0, 280.6484935, 246.0, 28, 'LB-1'],
#   [239.6494655, 256.0, 281.6494655, 271.0, 29, 'OmN-1'],
#   [226.09282000000002, 281.0, 278.09282, 296.0, 30, 'ChP10-2'],
#   [218.53725, 344.75, 231.53725, 357.75, 31, '37'],
#   [231.53725, 326.0, 244.53725, 339.0, 32, '22'],
#   [244.53875, 306.0, 278.53875, 321.0, 33, 'L72-1'],
#   [244.53875, 331.0, 272.53875, 346.0, 34, 'K4-2'],
#   [231.53875, 356.0, 267.53875, 371.0, 35, 'R51-6'],
#   [198.12435, 561.546875, 211.12435, 574.546875, 36, '66'],
#   [211.12435, 522.09375, 224.12435, 535.09375, 37, '27'],
#   [224.12435, 480.6875, 237.12435, 493.6875, 38, '94'],
#   [237.12435, 441.625, 250.12435, 454.625, 39, '28'],
#   [250.12435, 419.75, 263.12435, 432.75, 40, '55'],
#   [263.12435, 401.0, 276.12435, 414.0, 41, '54'],
#   [276.12585, 381.0, 326.12585, 396.0, 42, 'CyL3-21'],
#   [278.33916, 406.0, 312.33916, 421.0, 43, 'T42-1'],
#   [263.678612,
#    431.0,
#    579.6786119999999,
#    446.0,
#    44,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [250.12584999999999, 456.0, 329.12585, 471.0, 45, 'strain14 PP-2'],
#   [237.12435, 519.75, 250.12435, 532.75, 46, '70'],
#   [250.12435, 501.0, 263.12435, 514.0, 47, '28'],
#   [263.12585, 481.0, 315.12585, 496.0, 48, 'FCB10-1'],
#   [263.12585, 506.0, 298.12585, 521.0, 49, 'PL4-1'],
#   [250.12584999999999, 531.0, 307.12585, 546.0, 50, 'SMM81-1'],
#   [270.9728,
#    556.0,
#    657.9728,
#    571.0,
#    51,
#    'HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan'],
#   [211.12435, 601.0, 230.12435, 614.0, 52, '100'],
#   [230.12585,
#    581.0,
#    573.12585,
#    596.0,
#    53,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [230.12585,
#    606.0,
#    555.12585,
#    621.0,
#    54,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [163.7889415,
#    631.0,
#    422.78894149999996,
#    646.0,
#    55,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [140.6158, 788.890625, 153.6158, 801.890625, 56, '85'],
#   [153.6158, 764.28125, 166.6158, 777.28125, 57, '25'],
#   [166.6158, 740.0625, 173.6158, 753.0625, 58, '3'],
#   [173.6158, 716.625, 186.6158, 729.625, 59, '53'],
#   [186.6158, 694.75, 205.6158, 707.75, 60, '100'],
#   [205.6158, 676.0, 218.6158, 689.0, 61, '78'],
#   [218.61730000000003,
#    656.0,
#    529.6173,
#    671.0,
#    62,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [218.61730000000003,
#    681.0,
#    530.6173,
#    696.0,
#    63,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [206.166825,
#    706.0,
#    525.166825,
#    721.0,
#    64,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [186.61730000000003,
#    731.0,
#    485.6173,
#    746.0,
#    65,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [174.16408450000003,
#    756.0,
#    439.16408450000006,
#    771.0,
#    66,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [166.61730000000003,
#    781.0,
#    456.6173,
#    796.0,
#    67,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [155.26367000000002,
#    806.0,
#    431.26367000000005,
#    821.0,
#    68,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [150.91925, 963.890625, 169.91925, 976.890625, 69, '100'],
#   [183.5507, 939.28125, 196.5507, 952.28125, 70, '75'],
#   [207.15815, 915.0625, 226.15815, 928.0625, 71, '100'],
#   [226.15815, 891.625, 239.15815, 904.625, 72, '63'],
#   [239.15815, 869.75, 246.15815, 882.75, 73, '8'],
#   [246.15815, 851.0, 259.15815, 864.0, 74, '63'],
#   [261.37393499999996, 831.0, 339.37393499999996, 846.0, 75, 'HSG3-10 ITS'],
#   [259.15965, 856.0, 288.15965, 871.0, 76, 'SP-1'],
#   [246.15965, 881.0, 296.15965, 896.0, 77, 'ShKm41'],
#   [240.8026, 906.0, 285.8026, 921.0, 78, 'CD11-9'],
#   [226.15965, 931.0, 264.15965, 946.0, 79, 'PO-16'],
#   [206.551635, 956.0, 234.551635, 971.0, 80, 'K5-2'],
#   [171.496185,
#    981.0,
#    392.49618499999997,
#    996.0,
#    81,
#    'Paramecium jenningsi FL KF110697.1'],
#   [133.656,
#    1006.0,
#    459.656,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [35.093149999999994, 1069.75, 48.093149999999994, 1082.75, 83, '92'],
#   [165.18619999999999, 1051.0, 184.18619999999999, 1064.0, 84, '100'],
#   [184.1877,
#    1031.0,
#    613.1877,
#    1046.0,
#    85,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [184.1877,
#    1056.0,
#    609.1877,
#    1071.0,
#    86,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [106.21605000000001,
#    1081.0,
#    376.21605,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [82.1884, 1144.75, 89.1884, 1157.75, 88, '1'],
#   [139.3465, 1126.0, 158.3465, 1139.0, 89, '100'],
#   [158.98821049999998, 1106.0, 265.9882105, 1121.0, 90, 'Pdub HE819875.1'],
#   [158.348,
#    1131.0,
#    617.348,
#    1146.0,
#    91,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [236.31304999999998,
#    1156.0,
#    492.31305,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 657.9728000000001, 1176.0],
#   1: [20.0, 1.0, 657.9728000000001, 1101.0],
#   2: [27.0, 1.0, 657.9728000000001, 1026.0],
#   3: [45.53085, 1.0, 657.9728000000001, 1001.0],
#   4: [127.61580000000001, 1.0, 657.9728000000001, 826.0],
#   5: [140.6158, 1.0, 657.9728000000001, 651.0],
#   6: [163.28545, 1.0, 657.9728, 626.0],
#   7: [192.53725, 1.0, 604.0955635, 376.0],
#   8: [205.53725, 1.0, 604.0955635, 201.0],
#   9: [218.53725, 1.0, 604.0955635, 176.0],
#   10: [225.53725, 1.0, 604.0955635, 151.0],
#   11: [232.53725, 1.0, 604.0955635, 126.0],
#   12: [245.53725, 1.0, 604.0955635, 101.0],
#   13: [252.53725, 1.0, 310.092532, 51.0],
#   14: [265.53725, 1.0, 309.48074999999994, 26.0],
#   15: [265.53725, 26.0, 310.09253199999995, 51.0],
#   16: [252.53725, 51.0, 604.0955635, 101.0],
#   17: [265.53725, 51.0, 604.0955635, 76.0],
#   18: [265.53725, 76.0, 597.5387499999999, 101.0],
#   19: [245.53725, 101.0, 288.53875, 126.0],
#   20: [232.53725, 126.0, 554.09627, 151.0],
#   21: [225.53725, 151.0, 270.53875, 176.0],
#   22: [218.53725, 176.0, 254.206825, 201.0],
#   23: [205.53725, 201.0, 288.53875, 376.0],
#   24: [218.53725, 201.0, 288.53875, 301.0],
#   25: [225.53725, 201.0, 288.53875, 276.0],
#   26: [238.53725, 201.0, 288.53875, 251.0],
#   27: [251.53725, 201.0, 288.53875, 226.0],
#   28: [251.53725, 226.0, 280.6484935, 251.0],
#   29: [238.53725, 251.0, 281.6494655, 276.0],
#   30: [225.53725, 276.0, 278.09282, 301.0],
#   31: [218.53725, 301.0, 278.53875, 376.0],
#   32: [231.53725, 301.0, 278.53875, 351.0],
#   33: [244.53725, 301.0, 278.53875, 326.0],
#   34: [244.53725, 326.0, 272.53875, 351.0],
#   35: [231.53725, 351.0, 267.53875, 376.0],
#   36: [192.53725, 376.0, 657.9728, 626.0],
#   37: [211.12435, 376.0, 657.9728, 576.0],
#   38: [224.12435, 376.0, 579.6786119999999, 551.0],
#   39: [237.12435, 376.0, 579.6786119999999, 476.0],
#   40: [250.12435, 376.0, 579.6786119999999, 451.0],
#   41: [263.12435, 376.0, 326.12585, 426.0],
#   42: [276.12435, 376.0, 326.12585, 401.0],
#   43: [276.12435, 401.0, 312.33916, 426.0],
#   44: [263.12435, 426.0, 579.6786119999999, 451.0],
#   45: [250.12435, 451.0, 329.12585, 476.0],
#   46: [237.12435, 476.0, 315.12585, 551.0],
#   47: [250.12435, 476.0, 315.12585, 526.0],
#   48: [263.12435, 476.0, 315.12585, 501.0],
#   49: [263.12435, 501.0, 298.12585, 526.0],
#   50: [250.12435, 526.0, 307.12585, 551.0],
#   51: [224.12435, 551.0, 657.9728, 576.0],
#   52: [211.12435, 576.0, 573.12585, 626.0],
#   53: [230.12435, 576.0, 573.12585, 601.0],
#   54: [230.12435, 601.0, 555.12585, 626.0],
#   55: [163.28545, 626.0, 422.78894149999996, 651.0],
#   56: [140.6158, 651.0, 530.6173, 826.0],
#   57: [153.6158, 651.0, 530.6173, 801.0],
#   58: [166.6158, 651.0, 530.6173, 776.0],
#   59: [173.6158, 651.0, 530.6173, 751.0],
#   60: [186.6158, 651.0, 530.6173, 726.0],
#   61: [205.6158, 651.0, 530.6173, 701.0],
#   62: [218.6158, 651.0, 529.6173, 676.0],
#   63: [218.6158, 676.0, 530.6173, 701.0],
#   64: [205.6158, 701.0, 525.166825, 726.0],
#   65: [186.6158, 726.0, 485.6173, 751.0],
#   66: [173.6158, 751.0, 439.16408450000006, 776.0],
#   67: [166.6158, 776.0, 456.6173, 801.0],
#   68: [153.6158, 801.0, 431.26367000000005, 826.0],
#   69: [127.61580000000001, 826.0, 392.49618499999997, 1001.0],
#   70: [169.91925, 826.0, 339.373935, 976.0],
#   71: [196.5507, 826.0, 339.373935, 951.0],
#   72: [226.15815, 826.0, 339.373935, 926.0],
#   73: [239.15815, 826.0, 339.373935, 901.0],
#   74: [246.15815, 826.0, 339.373935, 876.0],
#   75: [259.15815, 826.0, 339.37393499999996, 851.0],
#   76: [259.15815, 851.0, 288.15965, 876.0],
#   77: [246.15815, 876.0, 296.15965, 901.0],
#   78: [239.15815, 901.0, 285.8026, 926.0],
#   79: [226.15815, 926.0, 264.15965, 951.0],
#   80: [196.5507, 951.0, 234.551635, 976.0],
#   81: [169.91925, 976.0, 392.49618499999997, 1001.0],
#   82: [45.53085, 1001.0, 459.656, 1026.0],
#   83: [27.0, 1026.0, 613.1877000000001, 1101.0],
#   84: [48.093149999999994, 1026.0, 613.1877000000001, 1076.0],
#   85: [184.18619999999999, 1026.0, 613.1877, 1051.0],
#   86: [184.18619999999999, 1051.0, 609.1877, 1076.0],
#   87: [48.093149999999994, 1076.0, 376.21605, 1101.0],
#   88: [20.0, 1101.0, 617.348, 1176.0],
#   89: [89.1884, 1101.0, 617.348, 1151.0],
#   90: [158.3465, 1101.0, 265.9882105, 1126.0],
#   91: [158.3465, 1126.0, 617.348, 1151.0],
#   92: [89.1884, 1151.0, 492.31305, 1176.0]}}
