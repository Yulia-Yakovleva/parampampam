# %%
pth_to_stats = '/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv'
pth_to_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S/formated_id_full.fa'
pth_to_its = '/home/yulia/parampampam/raw_data/fasta_files/ITS/formated_id_with_add.fa'

outf_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa'
outf_its = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa'

# %%
# import pandas as pd
# from Bio import SeqIO

# ssu_out = []
# its_out = []


# df = pd.read_csv(pth_to_stats, sep='\t')
# ssu_recs = [rec for rec in SeqIO.parse(pth_to_ssu, 'fasta')]
# its_recs = [rec for rec in SeqIO.parse(pth_to_its, 'fasta')]

# foursev_its_recs = []
# c = 0
# with open(outf_its, 'w') as out_f:
#     for its in df.its_id:
#         foursev_its_recs.append(its)
#         c+=1
#         for rec in its_recs:
#             if its == rec.name:
#                 its_out.append(rec)
#                 SeqIO.write(rec, out_f, 'fasta')
# print(c)

# foursev_ssu_recs = []
# c = 0
# with open(outf_ssu, 'w') as out_f:
#     for ssu in df.ssu_id:
#         foursev_ssu_recs.append(ssu)
#         c+=1
#         for rec in ssu_recs:
#             if ssu == rec.name:
#                 ssu_out.append(rec)
#                 SeqIO.write(rec, out_f, 'fasta')

# ssu_names = set()
# with open(outf_ssu, 'r') as ssu_f:
#     for line in ssu_f:
#         line = line.strip()
#         if line.startswith('>'):
#             ssu_names.add(line[1:])
            
# its_names = set()
# with open(outf_its, 'r') as its_f:
#     for line in its_f:
#         line = line.strip()
#         if line.startswith('>'):
#             its_names.add(line[1:])

# check fails
for name in foursev_its_recs:
    print(name)
    if name not in its_names:
        print(name, 'here')
        
for name in foursev_ssu_recs:
    print(name)
    if name not in ssu_names:
        print(name, 'here')
# Out:
# 954787BF1B
# 55CEC58B7B
# A22A7EB077
# 84CE765D07
# A9D77FB142
# C0FF30338F
# 6A22C8816B
# A100F8A811
# FFCD65A9C1
# FE6BF56E99
# BAFBB32B3C
# 9F17B676E6
# A28E935B8D
# E4C28EC0EC
# D4CE20BD5A
# E24B3A4289
# 7EB0465780
# 87876A753A
# 5EDFE55A10
# 3B4F40C1B6
# 4C5F4E4CDE
# A50EB0413A
# 20D1316E5D
# 8E203F786B
# 4571A227E6
# 317A91CB34
# 754C622D24
# AFED3029BB
# 0C044FF14F
# F5F4A73DA3
# 3232DFC4C6
# 70890594D2
# 7AB785E8EB
# F2145CCC2C
# 7760F61162
# ABB2EFBA0D
# 06BCC826BF
# 7337CC22D1
# 55622BCCF2
# E5A80E2658
# 1B54F3DD84
# 4EC675C343
# 05EB3CB2EF
# FT8_ITS
# E53453BD54
# E53453BD54 here
# 27457DB888
# 27457DB888 here
# B9FA7E99CC
# B9FA7E99CC here
# 8263802E57
# 52AC81ACB3
# AC28253C84
# F2A09C7B50
# EE5B03DA5E
# 4953348A77
# 9EA5A82A4B
# B1830287A1
# B2119F1FC6
# E1AC33E295
# 0113C4C62A
# B9EAB39D24
# 7EE3E00E2C
# EE5B03DA5E
# 51771109E9
# AC8716D80A
# A6A557D074
# 4F5A67EC10
# A825F8899B
# 908F980B86
# 69229F7190
# D56B98A901
# E8A136DD40
# 18C947E131
# F9D739A7DA
# 10F7A85AF0
# 7F4AA4EA36
# 1297B09026
# 00B63B8005
# 6C5ADD699F
# E4E1C9608E
# AD44EE3174
# F052BC4099
# 22748EAD14
# C80A7427A2
# 59F4C3171A
# FA9DFCE9DB
# 6B46EBE0AD
# 44611EBDCA
# 0A30787B3B
# 948B5933CA
# F63C7027B7
# A25F53AB60
# DCB12F983A
# E53453BD54
# 27457DB888
# B9FA7E99CC

# %%
# для Максима
import pandas as pd

def rename_ids(stats, in_f, out_f):
    df = pd.read_csv(stats, sep='\t')
    with open(in_f) as inf, open(out_f, 'w') as outf:
        for line in inf:
            for idx, descr in zip(df['Unnamed: 0'], df['description']):
                if idx in line:
                    line = line.replace(idx, descr)
            outf.write(line)
                
                
stats = '/home/yulia/parampampam/raw_data/stats/COI/stats_final.tsv'
in_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/mafft_aln_fianl_more_outgroup_full.fa'
out_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/COI_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/18S/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/18S/18S_GBlocks_regions_3.fst'
out_f = '/home/yulia/parampampam/alignments/18S/SSU_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/ITS/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/ITS/ITS_GBlocks_2.fst'
out_f = '/home/yulia/parampampam/alignments/ITS/ITS_normal_names.fa'

rename_ids(stats, in_f, out_f)

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa > /home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    45 /46
# Reallocating..done. *alloclen = 6654
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-2851
# STEP 003-006-1  identical.    identical.    accepted. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    rejected. identical.    identical.    identical.    rejected. identical.    identical.    identical.    rejected. accepted. identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    rejected. identical.    accepted. accepted. accepted. identical.    accepted. identical.    identical.    identical.    accepted. identical.    accepted. identical.    identical.    rejected. identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    rejected. rejected. rejected. identical.    identical.    rejected. rejected. identical.    identical.    rejected. identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 843 ms, sys: 178 ms, total: 1.02 s
# Wall time: 43.5 s

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa > /home/yulia/parampampam/alignments/18S_and_ITS/18S_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    41 /46
# Reallocating..done. *alloclen = 6844
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-3086
# STEP 003-004-1  identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    accepted. identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    rejected. identical.    identical.    rejected. identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    accepted. rejected. identical.    accepted. accepted. accepted. identical.    accepted. identical.    accepted. accepted. identical.    rejected. rejected. rejected. accepted. rejected. identical.    rejected. identical.    rejected. rejected. rejected. identical.    rejected. identical.    rejected. identical.    rejected. identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 5.14 s, sys: 877 ms, total: 6.02 s
# Wall time: 1min 55s

# %%
# назвать ssu сиквенсы айдишниками its 
from Bio import SeqIO

ssu_in = '/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions.fa'
its_in = '/home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln_regions.fa'
ssu_out ='/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions_renamed.fa'

names = []
its_recs = [rec for rec in SeqIO.parse(its_in, 'fasta')]
for rec in its_recs:
    names.append(rec.name)

out_recs = []
ssu_recs = [rec for rec in SeqIO.parse(ssu_in, 'fasta')]
for rec, its_name in zip(ssu_recs, names):
    rec.id = its_name
    rec.name = its_name
    rec.description = its_name
    out_recs.append(rec)
    
with open(ssu_out, 'w') as out_f:
    for rec in out_recs:
        SeqIO.write(rec, out_f, 'fasta')

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/con_50_majrule.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# ((Paramecium putrinum ETu 7-4 MG573199.1:0.157911,(Pdub HE819875.1:0.000951634,HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.000912299)1.00:0.0830832)1.00:0.0776973,(Paramecium nephridiatum Sr 2-6 MG573198.1:0.0667947,(MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000509922,KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000514101)1.00:0.149615)0.99:0.0265659,(KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.0988535,(FT8:0.0687076,(((((((HSG3-10 ITS:0.00719653,SP-1:0.00124732)0.70:0.00104722,CD11-9:0.00247104):0,ShKm41:0.000481699)0.60:0.00109819,PO-16:0.000756464)1.00:0.035472,K5-2:0.0125202)1.00:0.0302547,Paramecium jenningsi FL KF110697.1:0.00371911)1.00:0.0444835,((Paramecium primaurelia ThK-1 MG573194.1:0.00156254,(((Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.000487691,12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.000502841)0.99:0.00326658,((((strain14 PP-2:0.000499484,((SMM81-1:0.000482569,FCB10-1:0.000490565):0,PL4-1:0.00112549)0.65:0.00107053):0,CyL3-21:0.0012097):0,T42-1:0.0036581):0,6 Paramecium multimicronucleatum OP13 JF741217.1:0.00116583)1.00:0.00629065)1.00:0.0225721,(((((((((((((ThK-16:0.000487258,CyP5-3:0.00115619):0,MSA-5:0.00514749):0,16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.000510366):0,17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.00118217)0.72:0.00170499,(LB-1:0.00187033,SK6-3:0.000511307)0.97:0.00115706):0,K4-2:0.000493399):0,L72-1:0.000486673):0,R51-6:0.000486305):0,ChP5-3:0.0004883):0,ChP10-2:0.00117765):0,OmN-1:0.00182738):0,Or4-3:0.00250981):0,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00118985)0.87:0.00693652)1.00:0.0341677)1.00:0.0283897,((Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00304228,Paramecium primaurelia CyL4-1 MH185950.1:0.00150267):0,(Paramecium primaurelia 16/IP 17-21 MG573196.1:0.000485164,(((Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.000492822,Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.00113517):0,Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.000488921)1.00:0.0115214,Paramecium pentaurelia strain Nr1-10 MG573197.1:0.000556106)0.84:0.00114176):0)1.00:0.00914744)1.00:0.0129745)1.00:0.0149762)1.00:0.0798091)0.92:0.0226181);

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# (("Paramecium putrinum ETu 7-4 MG573199.1":0.159966,("Pdub HE819875.1":0.000968492,"HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":0.000897751)1.00:0.0781682):0.0759122,(("Paramecium nephridiatum Sr 2-6 MG573198.1":0.0658341,("MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000522479,"KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000519368)1.00:0.148427)0.99:0.0260365,("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0992306,((((((("HSG3-10 ITS":0.00320901,"SP-1":0.000496846)0.78:0.00107884,"CD11-9":0.00248232):0,"ShKm41":0.000480933)0.57:0.00108259,"PO-16":0.000776792)1.00:0.0348463,"K5-2":0.0122904)1.00:0.0311682,"Paramecium jenningsi FL KF110697.1":0.0029335)1.00:0.0499551,(("Paramecium primaurelia ThK-1 MG573194.1":0.00140471,((("Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":0.000490472,"12 Paramecium multimicronucleatum AB9-8 JF741240.1":0.000487421)0.97:0.00283253,(((("strain14 PP-2":0.000481751,(("SMM81-1":0.000492758,"FCB10-1":0.000485082):0,"PL4-1":0.000490188)0.79:0.00112374):0,("CyL3-21":0.000584257,"T42-1":0.0030762)0.62:0.00104568):0,"6 Paramecium multimicronucleatum OP13 JF741217.1":0.00117314)0.86:0.00285001,"HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan":0.0544022)0.93:0.00444086)1.00:0.0237363,((((((((((((("ThK-16":0.00049227,"CyP5-3":0.00115954):0,"MSA-5":0.00521921):0,"16 Paramecium multimicronucleatum Ns2-16 JF741224.1":0.000483867):0,"17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.00119072)0.66:0.00178056,("LB-1":0.00186692,"SK6-3":0.000506291)0.98:0.00116118):0,"K4-2":0.000495986):0,"L72-1":0.000494617):0,"R51-6":0.000490965):0,"ChP5-3":0.000492154):0,"ChP10-2":0.00117308):0,"OmN-1":0.00187206):0,"Or4-3":0.00255944):0,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.00118294)0.79:0.00678048)1.00:0.0343497)1.00:0.0252332,(("Paramecium primaurelia 16/IP 4-1 MG573195.1":0.00241111,"Paramecium primaurelia CyL4-1 MH185950.1":0.0011041):0,("Paramecium primaurelia 16/IP 17-21 MG573196.1":0.000488332,((("Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":0.000483778,"Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00115624):0,"Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":0.000486184)1.00:0.0117638,"Paramecium pentaurelia strain Nr1-10 MG573197.1":0.000562292)0.85:0.00113664):0)1.00:0.0103723)0.78:0.0103114)1.00:0.0919052)0.87:0.0230441):0.00399538)1.00;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', format=0, quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/mb_ete_tree_.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1067.8771982192993, 8.0, 1080.8771982192993, 0, '1'],
#   [8.0, 991.0043964385986, 15.0, 1004.0043964385986, 1, '1'],
#   [27.56615, 912.2587928771973, 49.56615, 925.2587928771973, 2, '0.87'],
#   [180.42395, 811.0175857543945, 187.42395, 824.0175857543945, 3, '1'],
#   [187.42395, 658.1445465087891, 209.42395, 671.1445465087891, 4, '0.78'],
#   [240.27375, 545.7578430175781, 247.27375, 558.7578430175781, 5, '1'],
#   [291.7983, 453.01568603515625, 298.7983, 466.01568603515625, 6, '1'],
#   [298.7983, 338.4298095703125, 320.7983, 351.4298095703125, 7, '0.79'],
#   [320.7983, 313.359619140625, 327.7983, 326.359619140625, 8, '1'],
#   [327.7983, 288.21923828125, 334.7983, 301.21923828125, 9, '1'],
#   [334.7983, 262.9384765625, 341.7983, 275.9384765625, 10, '1'],
#   [341.7983, 237.376953125, 348.7983, 250.376953125, 11, '1'],
#   [348.7983, 211.25390625, 355.7983, 224.25390625, 12, '1'],
#   [355.7983, 184.0078125, 362.7983, 197.0078125, 13, '1'],
#   [362.7983, 154.515625, 369.7983, 167.515625, 14, '1'],
#   [369.7983, 120.53125, 376.7983, 133.53125, 15, '1'],
#   [376.7983, 90.0625, 398.7983, 103.0625, 16, '0.66'],
#   [398.7983, 66.625, 405.7983, 79.625, 17, '1'],
#   [405.7983, 44.75, 412.7983, 57.75, 18, '1'],
#   [412.7983, 26.0, 419.7983, 39.0, 19, '1'],
#   [421.53761, 6.0, 465.53761, 21.0, 20, 'CyP5-3'],
#   [420.536705, 31.0, 463.536705, 46.0, 21, 'ThK-16'],
#   [420.627115, 56.0, 460.627115, 71.0, 22, 'MSA-5'],
#   [406.5241005,
#    81.0,
#    738.5241005,
#    96.0,
#    23,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [400.58438,
#    106.0,
#    738.58438,
#    121.0,
#    24,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [376.7983, 151.0, 398.7983, 164.0, 25, '0.98'],
#   [399.5577365, 131.0, 436.5577365, 146.0, 26, 'SK6-3'],
#   [401.59868, 156.0, 429.59868, 171.0, 27, 'LB-1'],
#   [370.542279, 181.0, 398.542279, 196.0, 28, 'K4-2'],
#   [363.54022549999996, 206.0, 397.54022549999996, 221.0, 29, 'L72-1'],
#   [356.5347475, 231.0, 392.5347475, 246.0, 30, 'R51-6'],
#   [349.53653099999997, 256.0, 394.53653099999997, 271.0, 31, 'ChP5-3'],
#   [343.55791999999997, 281.0, 395.55791999999997, 296.0, 32, 'ChP10-2'],
#   [337.60639, 306.0, 379.60639, 321.0, 33, 'OmN-1'],
#   [331.63746, 331.0, 365.63746, 346.0, 34, 'Or4-3'],
#   [322.57271,
#    356.0,
#    643.5727099999999,
#    371.0,
#    35,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [327.40274999999997, 567.6015625, 334.40274999999997, 580.6015625, 36, '1'],
#   [334.40274999999997, 534.203125, 356.40274999999997, 547.203125, 37, '0.93'],
#   [356.40274999999997, 504.90625, 378.40274999999997, 517.90625, 38, '0.86'],
#   [378.40274999999997, 471.3125, 385.40274999999997, 484.3125, 39, '1'],
#   [385.40274999999997, 441.625, 392.40274999999997, 454.625, 40, '1'],
#   [392.40274999999997, 419.75, 414.40274999999997, 432.75, 41, '0.79'],
#   [414.40274999999997, 401.0, 421.40274999999997, 414.0, 42, '1'],
#   [422.13037299999996, 381.0, 474.13037299999996, 396.0, 43, 'FCB10-1'],
#   [422.141887, 406.0, 479.141887, 421.0, 44, 'SMM81-1'],
#   [415.13803199999995, 431.0, 450.13803199999995, 446.0, 45, 'PL4-1'],
#   [393.12537649999996, 456.0, 472.12537649999996, 471.0, 46, 'strain14 PP-2'],
#   [385.40274999999997, 501.0, 407.40274999999997, 514.0, 47, '0.62'],
#   [412.01705, 481.0, 446.01705, 496.0, 48, 'T42-1'],
#   [408.27913549999994, 506.0, 458.27913549999994, 521.0, 49, 'CyL3-21'],
#   [380.16245999999995,
#    531.0,
#    696.16246,
#    546.0,
#    50,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [438.00604999999996,
#    556.0,
#    825.00605,
#    571.0,
#    51,
#    'HE650907.2 Paramecium multimicronucleatum strain FT2 Pakistan'],
#   [334.40274999999997, 601.0, 356.40274999999997, 614.0, 52, '0.97'],
#   [357.1338815,
#    581.0,
#    682.1338814999999,
#    596.0,
#    53,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [357.13845799999996,
#    606.0,
#    700.1384579999999,
#    621.0,
#    54,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [249.38081499999998,
#    631.0,
#    508.380815,
#    646.0,
#    55,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [217.98239999999998, 770.53125, 224.98239999999998, 783.53125, 56, '1'],
#   [224.98239999999998, 740.0625, 231.98239999999998, 753.0625, 57, '1'],
#   [231.98239999999998, 716.625, 253.98239999999998, 729.625, 58, '0.85'],
#   [264.62809999999996, 694.75, 271.62809999999996, 707.75, 59, '1'],
#   [271.62809999999996, 676.0, 278.62809999999996, 689.0, 60, '1'],
#   [280.36245999999994,
#    656.0,
#    599.3624599999999,
#    671.0,
#    61,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [279.35376699999995,
#    681.0,
#    591.353767,
#    696.0,
#    62,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [272.357376,
#    706.0,
#    583.3573759999999,
#    721.0,
#    63,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [254.82583799999998,
#    731.0,
#    553.825838,
#    746.0,
#    64,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [232.714898,
#    756.0,
#    522.714898,
#    771.0,
#    65,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [224.98239999999998, 801.0, 231.98239999999998, 814.0, 66, '1'],
#   [233.63855,
#    781.0,
#    498.63855,
#    796.0,
#    67,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [235.599065,
#    806.0,
#    511.599065,
#    821.0,
#    68,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [255.35660000000001, 963.890625, 262.3566, 976.890625, 69, '1'],
#   [302.1089, 939.28125, 309.1089, 952.28125, 70, '1'],
#   [354.37835, 915.0625, 361.37835, 928.0625, 71, '1'],
#   [361.37835, 891.625, 383.37835, 904.625, 72, '0.57'],
#   [383.37835, 869.75, 390.37835, 882.75, 73, '1'],
#   [390.37835, 851.0, 412.37835, 864.0, 74, '0.78'],
#   [413.123619, 831.0, 442.123619, 846.0, 75, 'SP-1'],
#   [417.191865, 856.0, 495.191865, 871.0, 76, 'HSG3-10 ITS'],
#   [394.10183, 881.0, 439.10183, 896.0, 77, 'CD11-9'],
#   [384.09974950000003, 906.0, 434.09974950000003, 921.0, 78, 'ShKm41'],
#   [362.543538, 931.0, 400.543538, 946.0, 79, 'PO-16'],
#   [327.5445, 956.0, 355.5445, 971.0, 80, 'K5-2'],
#   [266.75685,
#    981.0,
#    487.75685,
#    996.0,
#    81,
#    'Paramecium jenningsi FL KF110697.1'],
#   [198.41205000000002,
#    1006.0,
#    524.41205,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [32.05475, 1069.75, 54.05475, 1082.75, 83, '0.99'],
#   [269.69525, 1051.0, 276.69525, 1064.0, 84, '1'],
#   [277.47430199999997,
#    1031.0,
#    702.474302,
#    1046.0,
#    85,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [277.4789685,
#    1056.0,
#    706.4789685000001,
#    1071.0,
#    86,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [152.8059,
#    1081.0,
#    422.8059,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [114.8683, 1144.75, 121.8683, 1157.75, 88, '1'],
#   [232.1206, 1126.0, 239.1206, 1139.0, 89, '1'],
#   [240.4672265,
#    1106.0,
#    699.4672265,
#    1121.0,
#    90,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [240.57333799999998, 1131.0, 347.573338, 1146.0, 91, 'Pdub HE819875.1'],
#   [361.81729999999993,
#    1156.0,
#    617.8172999999999,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 825.00605, 1176.0],
#   1: [8.0, 1.0, 825.00605, 1101.0],
#   2: [15.0, 1.0, 825.00605, 1026.0],
#   3: [49.56615, 1.0, 825.00605, 1001.0],
#   4: [187.42395, 1.0, 825.00605, 826.0],
#   5: [209.42395, 1.0, 825.00605, 651.0],
#   6: [247.27375, 1.0, 825.00605, 626.0],
#   7: [298.7983, 1.0, 738.58438, 376.0],
#   8: [320.7983, 1.0, 738.58438, 351.0],
#   9: [327.7983, 1.0, 738.58438, 326.0],
#   10: [334.7983, 1.0, 738.58438, 301.0],
#   11: [341.7983, 1.0, 738.58438, 276.0],
#   12: [348.7983, 1.0, 738.58438, 251.0],
#   13: [355.7983, 1.0, 738.58438, 226.0],
#   14: [362.7983, 1.0, 738.58438, 201.0],
#   15: [369.7983, 1.0, 738.58438, 176.0],
#   16: [376.7983, 1.0, 738.58438, 126.0],
#   17: [398.7983, 1.0, 738.5241005, 101.0],
#   18: [405.7983, 1.0, 465.53761, 76.0],
#   19: [412.7983, 1.0, 465.53761, 51.0],
#   20: [419.7983, 1.0, 465.53761, 26.0],
#   21: [419.7983, 26.0, 463.536705, 51.0],
#   22: [412.7983, 51.0, 460.627115, 76.0],
#   23: [405.7983, 76.0, 738.5241005, 101.0],
#   24: [398.7983, 101.0, 738.58438, 126.0],
#   25: [376.7983, 126.0, 436.5577365, 176.0],
#   26: [398.7983, 126.0, 436.5577365, 151.0],
#   27: [398.7983, 151.0, 429.59868, 176.0],
#   28: [369.7983, 176.0, 398.542279, 201.0],
#   29: [362.7983, 201.0, 397.54022549999996, 226.0],
#   30: [355.7983, 226.0, 392.5347475, 251.0],
#   31: [348.7983, 251.0, 394.53653099999997, 276.0],
#   32: [341.7983, 276.0, 395.55791999999997, 301.0],
#   33: [334.7983, 301.0, 379.60639, 326.0],
#   34: [327.7983, 326.0, 365.63746, 351.0],
#   35: [320.7983, 351.0, 643.5727099999999, 376.0],
#   36: [298.7983, 376.0, 825.00605, 626.0],
#   37: [334.40274999999997, 376.0, 825.00605, 576.0],
#   38: [356.40274999999997, 376.0, 696.16246, 551.0],
#   39: [378.40274999999997, 376.0, 479.141887, 526.0],
#   40: [385.40274999999997, 376.0, 479.141887, 476.0],
#   41: [392.40274999999997, 376.0, 479.141887, 451.0],
#   42: [414.40274999999997, 376.0, 479.141887, 426.0],
#   43: [421.40274999999997, 376.0, 474.13037299999996, 401.0],
#   44: [421.40274999999997, 401.0, 479.141887, 426.0],
#   45: [414.40274999999997, 426.0, 450.13803199999995, 451.0],
#   46: [392.40274999999997, 451.0, 472.12537649999996, 476.0],
#   47: [385.40274999999997, 476.0, 458.27913549999994, 526.0],
#   48: [407.40274999999997, 476.0, 446.01705, 501.0],
#   49: [407.40274999999997, 501.0, 458.27913549999994, 526.0],
#   50: [378.40274999999997, 526.0, 696.16246, 551.0],
#   51: [356.40274999999997, 551.0, 825.00605, 576.0],
#   52: [334.40274999999997, 576.0, 700.1384579999999, 626.0],
#   53: [356.40274999999997, 576.0, 682.1338814999999, 601.0],
#   54: [356.40274999999997, 601.0, 700.1384579999999, 626.0],
#   55: [247.27375, 626.0, 508.380815, 651.0],
#   56: [209.42395, 651.0, 599.3624599999999, 826.0],
#   57: [224.98239999999998, 651.0, 599.3624599999999, 776.0],
#   58: [231.98239999999998, 651.0, 599.3624599999999, 751.0],
#   59: [253.98239999999998, 651.0, 599.3624599999999, 726.0],
#   60: [271.62809999999996, 651.0, 599.3624599999999, 701.0],
#   61: [278.62809999999996, 651.0, 599.3624599999999, 676.0],
#   62: [278.62809999999996, 676.0, 591.353767, 701.0],
#   63: [271.62809999999996, 701.0, 583.3573759999999, 726.0],
#   64: [253.98239999999998, 726.0, 553.825838, 751.0],
#   65: [231.98239999999998, 751.0, 522.714898, 776.0],
#   66: [224.98239999999998, 776.0, 511.599065, 826.0],
#   67: [231.98239999999998, 776.0, 498.63855, 801.0],
#   68: [231.98239999999998, 801.0, 511.599065, 826.0],
#   69: [187.42395, 826.0, 495.191865, 1001.0],
#   70: [262.3566, 826.0, 495.191865, 976.0],
#   71: [309.1089, 826.0, 495.191865, 951.0],
#   72: [361.37835, 826.0, 495.191865, 926.0],
#   73: [383.37835, 826.0, 495.191865, 901.0],
#   74: [390.37835, 826.0, 495.191865, 876.0],
#   75: [412.37835, 826.0, 442.123619, 851.0],
#   76: [412.37835, 851.0, 495.191865, 876.0],
#   77: [390.37835, 876.0, 439.10183, 901.0],
#   78: [383.37835, 901.0, 434.09974950000003, 926.0],
#   79: [361.37835, 926.0, 400.543538, 951.0],
#   80: [309.1089, 951.0, 355.5445, 976.0],
#   81: [262.3566, 976.0, 487.75685, 1001.0],
#   82: [49.56615, 1001.0, 524.41205, 1026.0],
#   83: [15.0, 1026.0, 706.4789685000001, 1101.0],
#   84: [54.05475, 1026.0, 706.4789685000001, 1076.0],
#   85: [276.69525, 1026.0, 702.474302, 1051.0],
#   86: [276.69525, 1051.0, 706.4789685000001, 1076.0],
#   87: [54.05475, 1076.0, 422.8059, 1101.0],
#   88: [8.0, 1101.0, 699.4672265, 1176.0],
#   89: [121.8683, 1101.0, 699.4672265, 1151.0],
#   90: [239.1206, 1101.0, 699.4672265, 1126.0],
#   91: [239.1206, 1126.0, 347.573338, 1151.0],
#   92: [121.8683, 1151.0, 617.8172999999999, 1176.0]}}

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_bipartitions.result', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# (Paramecium primaurelia 16/IP 17-21 MG573196.1:0.00000100000050002909,((Paramecium pentaurelia strain Nr1-10 MG573197.1:0.00000100000050002909,(Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.00036359027347960583,(Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.00000100000050002909,Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.00000100000050002909)79:0.00000100000050002909)100:0.00630081735027730044)49:0.00036199165406176881,((((Paramecium jenningsi FL KF110697.1:0.00145212634033222159,(K5-2:0.00675080779318507507,(PO-16:0.00000100000050002909,(ShKm41:0.00000100000050002909,(CD11-9:0.00108797380185419036,(HSG3-10 ITS:0.00369395812538990138,SP-1:0.00037253600517297264)61:0.00035232524027589766)25:0.00000100000050002909)64:0.00036138898235167914)100:0.02023852339891233157)40:0.01737688514489611757)100:0.02620873796592209162,(FT8:0.03998108296553097574,(KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.05885541940389021204,(((HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.00000100000050002909,Pdub HE819875.1:0.00042030820563855159)100:0.04894385085110164457,Paramecium putrinum ETu 7-4 MG573199.1:0.09701895441896435379)100:0.04718605113271110568,(Paramecium nephridiatum Sr 2-6 MG573198.1:0.03954189685838276763,(KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909,MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909)100:0.09100315673194878108)98:0.01429593475726342010)38:0.01225262120474774653)100:0.04786671586614528462)38:0.00811597808832681400)91:0.00724002186777915856,(Paramecium primaurelia ThK-1 MG573194.1:0.00037261428843280456,(((Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.00000100000050002909,12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.00000100000050002909)100:0.00152507219367586477,((PL4-1:0.00036316320011481795,(SMM81-1:0.00000100000050002909,FCB10-1:0.00000100000050002909)55:0.00000100000050002909)49:0.00036287159442227964,(strain14 PP-2:0.00000100000050002909,(6 Paramecium multimicronucleatum OP13 JF741217.1:0.00037295109635564775,(T42-1:0.00183223686998013014,CyL3-21:0.00035828982865843221)46:0.00030645957656995479)44:0.00006209155110023329)22:0.00000100000050002909)98:0.00326703920809036071)100:0.01204338942543753399,(((((R51-6:0.00000100000050002909,L72-1:0.00000100000050002909)32:0.00000100000050002909,ChP10-2:0.00036596559446614937)2:0.00000100000050002909,((LB-1:0.00073179427109890029,SK6-3:0.00000100000050002909)67:0.00036591662148408711,OmN-1:0.00073400107670426151)16:0.00000100000050002909)0:0.00000100000050002909,K4-2:0.00000100000050002909)46:0.00000100000050002909,(((Or4-3:0.00110187619873106514,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00037616510365644278)21:0.00000100000050002909,ChP5-3:0.00000100000050002909)21:0.00000100000050002909,(((CyP5-3:0.00036582431184428406,MSA-5:0.00260273680794496053)26:0.00000100000050002909,(16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.00000100000050002909,17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.00037568757463154936)84:0.00000100000050002909)2:0.00000100000050002909,ThK-16:0.00000100000050002909)55:0.00073232660918139667)19:0.00036485916964723423)50:0.00355363459780737561)100:0.01974694847101816919)100:0.01561679357841633600)76:0.00488270566015121081,Paramecium primaurelia CyL4-1 MH185950.1:0.00000100000050002909)59:0.00072383588960330566)27:0.00000100000050002909,Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00145362500416030107);

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# HE662765.2 Paramecium caudatum partial 18S rRNA gene strain FT8
# ((("HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":1e-06,"Pdub HE819875.1":0.000420308)100:0.0489439,"Paramecium putrinum ETu 7-4 MG573199.1":0.097019):0.0433176,(("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0588554,(FT8:0.0399811,(("Paramecium jenningsi FL KF110697.1":0.00145213,("K5-2":0.00675081,("PO-16":1e-06,("ShKm41":1e-06,("CD11-9":0.00108797,("HSG3-10 ITS":0.00369396,"SP-1":0.000372536)61:0.000352325)25:1e-06)64:0.000361389)100:0.0202385)40:0.0173769)100:0.0262087,(("Paramecium primaurelia ThK-1 MG573194.1":0.000372614,((("Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":1e-06,"12 Paramecium multimicronucleatum AB9-8 JF741240.1":1e-06)100:0.00152507,(("PL4-1":0.000363163,("SMM81-1":1e-06,"FCB10-1":1e-06)55:1e-06)49:0.000362872,("strain14 PP-2":1e-06,("6 Paramecium multimicronucleatum OP13 JF741217.1":0.000372951,("T42-1":0.00183224,"CyL3-21":0.00035829)46:0.00030646)44:6.20916e-05)22:1e-06)98:0.00326704)100:0.0120434,((((("R51-6":1e-06,"L72-1":1e-06)32:1e-06,"ChP10-2":0.000365966)2:1e-06,(("LB-1":0.000731794,"SK6-3":1e-06)67:0.000365917,"OmN-1":0.000734001)16:1e-06)0:1e-06,"K4-2":1e-06)46:1e-06,((("Or4-3":0.00110188,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.000376165)21:1e-06,"ChP5-3":1e-06)21:1e-06,((("CyP5-3":0.000365824,"MSA-5":0.00260274)26:1e-06,("16 Paramecium multimicronucleatum Ns2-16 JF741224.1":1e-06,"17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.000375688)84:1e-06)2:1e-06,"ThK-16":1e-06)55:0.000732327)19:0.000364859)50:0.00355363)100:0.0197469)100:0.0156168,("Paramecium primaurelia CyL4-1 MH185950.1":1e-06,(("Paramecium pentaurelia strain Nr1-10 MG573197.1":1e-06,("Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00036359,("Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":1e-06,"Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":1e-06)79:1e-06)100:0.00630082)49:0.000361992,("Paramecium primaurelia 16/IP 17-21 MG573196.1":1e-06,"Paramecium primaurelia 16/IP 4-1 MG573195.1":0.00145363)27:1e-06)59:0.000723836)76:0.00488271)91:0.00724002)38:0.00811598)100:0.0478667)38:0.0122526,("Paramecium nephridiatum Sr 2-6 MG573198.1":0.0395419,("KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06,"MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06)100:0.0910032)98:0.0142959):0.00386844)100;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1077.1505126953125, 20.0, 1090.1505126953125, 0, '100'],
#   [20.0, 1009.551025390625, 27.0, 1022.551025390625, 1, '1'],
#   [32.3789, 949.35205078125, 45.3789, 962.35205078125, 2, '38'],
#   [98.17895, 885.2041015625, 117.17895, 898.2041015625, 3, '100'],
#   [117.17895, 781.908203125, 130.17895, 794.908203125, 4, '38'],
#   [130.17895, 624.92578125, 143.17895, 637.92578125, 5, '91'],
#   [147.60414999999998, 494.9453125, 166.60414999999998, 507.9453125, 6, '100'],
#   [177.22449999999998, 376.390625, 196.22449999999998, 389.390625, 7, '100'],
#   [196.22449999999998, 224.4375, 209.22449999999998, 237.4375, 8, '50'],
#   [209.22449999999998, 126.0, 222.22449999999998, 139.0, 9, '19'],
#   [222.22449999999998, 82.25, 235.22449999999998, 95.25, 10, '55'],
#   [235.22449999999998, 51.0, 242.22449999999998, 64.0, 11, '2'],
#   [242.22449999999998, 26.0, 255.22449999999998, 39.0, 12, '84'],
#   [255.788032,
#    6.0,
#    593.7880319999999,
#    21.0,
#    13,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [255.226,
#    31.0,
#    587.226,
#    46.0,
#    14,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [242.22449999999998, 76.0, 255.22449999999998, 89.0, 15, '26'],
#   [259.12861, 56.0, 299.12861, 71.0, 16, 'MSA-5'],
#   [255.77323599999997, 81.0, 299.773236, 96.0, 17, 'CyP5-3'],
#   [235.22599999999997, 106.0, 278.226, 121.0, 18, 'ThK-16'],
#   [222.22449999999998, 169.75, 235.22449999999998, 182.75, 19, '21'],
#   [235.22449999999998, 151.0, 248.22449999999998, 164.0, 20, '21'],
#   [248.7887475,
#    131.0,
#    569.7887475,
#    146.0,
#    21,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [249.87731999999997, 156.0, 283.87731999999994, 171.0, 22, 'Or4-3'],
#   [235.22599999999997, 181.0, 280.226, 196.0, 23, 'ChP5-3'],
#   [209.22449999999998, 322.875, 222.22449999999998, 335.875, 24, '46'],
#   [222.22449999999998, 282.25, 229.22449999999998, 295.25, 25, '0'],
#   [229.22449999999998, 244.75, 242.22449999999998, 257.75, 26, '16'],
#   [242.22449999999998, 226.0, 255.22449999999998, 239.0, 27, '67'],
#   [255.22599999999997, 206.0, 292.226, 221.0, 28, 'SK6-3'],
#   [256.322191, 231.0, 284.322191, 246.0, 29, 'LB-1'],
#   [243.32550149999997, 256.0, 285.3255015, 271.0, 30, 'OmN-1'],
#   [229.22449999999998, 319.75, 236.22449999999998, 332.75, 31, '2'],
#   [236.22449999999998, 301.0, 249.22449999999998, 314.0, 32, '32'],
#   [249.22599999999997, 281.0, 283.226, 296.0, 33, 'L72-1'],
#   [249.22599999999997, 306.0, 285.226, 321.0, 34, 'R51-6'],
#   [236.77344899999997, 331.0, 288.77344899999997, 346.0, 35, 'ChP10-2'],
#   [222.22599999999997, 356.0, 250.22599999999997, 371.0, 36, 'K4-2'],
#   [196.22449999999998, 528.34375, 215.22449999999998, 541.34375, 37, '100'],
#   [215.22449999999998, 480.6875, 228.22449999999998, 493.6875, 38, '98'],
#   [228.22449999999998, 441.625, 241.22449999999998, 454.625, 39, '22'],
#   [241.22449999999998, 419.75, 254.22449999999998, 432.75, 40, '44'],
#   [254.22449999999998, 401.0, 267.2245, 414.0, 41, '46'],
#   [267.761935, 381.0, 317.761935, 396.0, 42, 'CyL3-21'],
#   [269.97285999999997, 406.0, 303.97285999999997, 421.0, 43, 'T42-1'],
#   [254.78392649999995,
#    431.0,
#    570.7839265,
#    446.0,
#    44,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [241.22599999999997, 456.0, 320.226, 471.0, 45, 'strain14 PP-2'],
#   [228.22449999999998, 519.75, 241.22449999999998, 532.75, 46, '49'],
#   [241.22449999999998, 501.0, 254.22449999999998, 514.0, 47, '55'],
#   [254.22599999999997, 481.0, 306.226, 496.0, 48, 'FCB10-1'],
#   [254.22599999999997, 506.0, 311.226, 521.0, 49, 'SMM81-1'],
#   [241.76924449999999, 531.0, 276.7692445, 546.0, 50, 'PL4-1'],
#   [215.22449999999998, 576.0, 234.22449999999998, 589.0, 51, '100'],
#   [234.226,
#    556.0,
#    559.226,
#    571.0,
#    52,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [234.226,
#    581.0,
#    577.226,
#    596.0,
#    53,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [167.16307099999997,
#    606.0,
#    426.16307099999995,
#    621.0,
#    54,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [143.17895, 754.90625, 156.17895, 767.90625, 55, '76'],
#   [156.17895, 721.3125, 169.17895, 734.3125, 56, '59'],
#   [169.17895, 691.625, 182.17895, 704.625, 57, '49'],
#   [182.17895, 669.75, 201.17895, 682.75, 58, '100'],
#   [201.17895, 651.0, 214.17895, 664.0, 59, '79'],
#   [214.18045,
#    631.0,
#    526.1804500000001,
#    646.0,
#    60,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [214.18045,
#    656.0,
#    525.1804500000001,
#    671.0,
#    61,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [201.724335,
#    681.0,
#    520.724335,
#    696.0,
#    62,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [182.18045,
#    706.0,
#    481.18045,
#    721.0,
#    63,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [169.17895, 751.0, 182.17895, 764.0, 64, '27'],
#   [184.359395,
#    731.0,
#    460.359395,
#    746.0,
#    65,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [182.18045,
#    756.0,
#    472.18045,
#    771.0,
#    66,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [156.18045,
#    781.0,
#    421.18045,
#    796.0,
#    67,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [150.492, 938.890625, 169.492, 951.890625, 68, '100'],
#   [182.55734999999999, 914.28125, 195.55734999999999, 927.28125, 69, '40'],
#   [206.9151, 890.0625, 225.9151, 903.0625, 70, '100'],
#   [225.9151, 866.625, 238.9151, 879.625, 71, '64'],
#   [238.9151, 844.75, 251.9151, 857.75, 72, '25'],
#   [251.9151, 826.0, 264.9151, 839.0, 73, '61'],
#   [265.473904, 806.0, 294.473904, 821.0, 74, 'SP-1'],
#   [270.45604000000003, 831.0, 348.45604000000003, 846.0, 75, 'HSG3-10 ITS'],
#   [253.547055, 856.0, 298.547055, 871.0, 76, 'CD11-9'],
#   [238.9166, 881.0, 288.9166, 896.0, 77, 'ShKm41'],
#   [225.9166, 906.0, 263.9166, 921.0, 78, 'PO-16'],
#   [205.683565, 931.0, 233.683565, 946.0, 79, 'K5-2'],
#   [171.67019499999998,
#    956.0,
#    392.670195,
#    971.0,
#    80,
#    'Paramecium jenningsi FL KF110697.1'],
#   [177.1506, 981.0, 201.1506, 996.0, 81, 'FT8'],
#   [133.66199999999998,
#    1006.0,
#    459.662,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [35.44385, 1069.75, 48.44385, 1082.75, 83, '98'],
#   [165.94865000000001, 1051.0, 184.94865000000001, 1064.0, 84, '100'],
#   [184.95015000000004,
#    1031.0,
#    613.95015,
#    1046.0,
#    85,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [184.95015000000004,
#    1056.0,
#    609.95015,
#    1071.0,
#    86,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [107.75670000000002,
#    1081.0,
#    377.7567,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [77.9764, 1144.75, 84.9764, 1157.75, 88, '1'],
#   [139.39225, 1126.0, 158.39225, 1139.0, 89, '100'],
#   [159.02271199999998,
#    1106.0,
#    266.02271199999996,
#    1121.0,
#    90,
#    'Pdub HE819875.1'],
#   [158.39375,
#    1131.0,
#    617.39375,
#    1146.0,
#    91,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [230.50490000000002,
#    1156.0,
#    486.5049,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 617.3937500000001, 1176.0],
#   1: [20.0, 1.0, 613.95015, 1101.0],
#   2: [27.0, 1.0, 593.788032, 1026.0],
#   3: [45.3789, 1.0, 593.788032, 1001.0],
#   4: [117.17895, 1.0, 593.788032, 976.0],
#   5: [130.17895, 1.0, 593.788032, 801.0],
#   6: [143.17895, 1.0, 593.788032, 626.0],
#   7: [166.60414999999998, 1.0, 593.788032, 601.0],
#   8: [196.22449999999998, 1.0, 593.7880319999999, 376.0],
#   9: [209.22449999999998, 1.0, 593.7880319999999, 201.0],
#   10: [222.22449999999998, 1.0, 593.7880319999999, 126.0],
#   11: [235.22449999999998, 1.0, 593.7880319999999, 101.0],
#   12: [242.22449999999998, 1.0, 593.7880319999999, 51.0],
#   13: [255.22449999999998, 1.0, 593.7880319999999, 26.0],
#   14: [255.22449999999998, 26.0, 587.226, 51.0],
#   15: [242.22449999999998, 51.0, 299.773236, 101.0],
#   16: [255.22449999999998, 51.0, 299.12861, 76.0],
#   17: [255.22449999999998, 76.0, 299.773236, 101.0],
#   18: [235.22449999999998, 101.0, 278.226, 126.0],
#   19: [222.22449999999998, 126.0, 569.7887475, 201.0],
#   20: [235.22449999999998, 126.0, 569.7887475, 176.0],
#   21: [248.22449999999998, 126.0, 569.7887475, 151.0],
#   22: [248.22449999999998, 151.0, 283.87732, 176.0],
#   23: [235.22449999999998, 176.0, 280.226, 201.0],
#   24: [209.22449999999998, 201.0, 292.226, 376.0],
#   25: [222.22449999999998, 201.0, 292.226, 351.0],
#   26: [229.22449999999998, 201.0, 292.226, 276.0],
#   27: [242.22449999999998, 201.0, 292.226, 251.0],
#   28: [255.22449999999998, 201.0, 292.226, 226.0],
#   29: [255.22449999999998, 226.0, 284.322191, 251.0],
#   30: [242.22449999999998, 251.0, 285.3255015, 276.0],
#   31: [229.22449999999998, 276.0, 288.77344899999997, 351.0],
#   32: [236.22449999999998, 276.0, 285.226, 326.0],
#   33: [249.22449999999998, 276.0, 283.226, 301.0],
#   34: [249.22449999999998, 301.0, 285.226, 326.0],
#   35: [236.22449999999998, 326.0, 288.77344899999997, 351.0],
#   36: [222.22449999999998, 351.0, 250.22599999999997, 376.0],
#   37: [196.22449999999998, 376.0, 577.226, 601.0],
#   38: [215.22449999999998, 376.0, 570.7839265, 551.0],
#   39: [228.22449999999998, 376.0, 570.7839265, 476.0],
#   40: [241.22449999999998, 376.0, 570.7839265, 451.0],
#   41: [254.22449999999998, 376.0, 317.761935, 426.0],
#   42: [267.2245, 376.0, 317.761935, 401.0],
#   43: [267.2245, 401.0, 303.97285999999997, 426.0],
#   44: [254.22449999999998, 426.0, 570.7839265, 451.0],
#   45: [241.22449999999998, 451.0, 320.226, 476.0],
#   46: [228.22449999999998, 476.0, 311.226, 551.0],
#   47: [241.22449999999998, 476.0, 311.226, 526.0],
#   48: [254.22449999999998, 476.0, 306.226, 501.0],
#   49: [254.22449999999998, 501.0, 311.226, 526.0],
#   50: [241.22449999999998, 526.0, 276.76924449999996, 551.0],
#   51: [215.22449999999998, 551.0, 577.226, 601.0],
#   52: [234.22449999999998, 551.0, 559.226, 576.0],
#   53: [234.22449999999998, 576.0, 577.226, 601.0],
#   54: [166.60414999999998, 601.0, 426.16307099999995, 626.0],
#   55: [143.17895, 626.0, 526.1804500000001, 801.0],
#   56: [156.17895, 626.0, 526.1804500000001, 776.0],
#   57: [169.17895, 626.0, 526.1804500000001, 726.0],
#   58: [182.17895, 626.0, 526.1804500000001, 701.0],
#   59: [201.17895, 626.0, 526.1804500000001, 676.0],
#   60: [214.17895, 626.0, 526.1804500000001, 651.0],
#   61: [214.17895, 651.0, 525.1804500000001, 676.0],
#   62: [201.17895, 676.0, 520.724335, 701.0],
#   63: [182.17895, 701.0, 481.18045, 726.0],
#   64: [169.17895, 726.0, 472.18045, 776.0],
#   65: [182.17895, 726.0, 460.359395, 751.0],
#   66: [182.17895, 751.0, 472.18045, 776.0],
#   67: [156.17895, 776.0, 421.18045, 801.0],
#   68: [130.17895, 801.0, 392.670195, 976.0],
#   69: [169.492, 801.0, 348.45604000000003, 951.0],
#   70: [195.55734999999999, 801.0, 348.45604000000003, 926.0],
#   71: [225.9151, 801.0, 348.45604000000003, 901.0],
#   72: [238.9151, 801.0, 348.45604000000003, 876.0],
#   73: [251.9151, 801.0, 348.45604000000003, 851.0],
#   74: [264.9151, 801.0, 294.473904, 826.0],
#   75: [264.9151, 826.0, 348.45604000000003, 851.0],
#   76: [251.9151, 851.0, 298.547055, 876.0],
#   77: [238.9151, 876.0, 288.9166, 901.0],
#   78: [225.9151, 901.0, 263.9166, 926.0],
#   79: [195.55734999999999, 926.0, 233.683565, 951.0],
#   80: [169.492, 951.0, 392.670195, 976.0],
#   81: [117.17895, 976.0, 201.1506, 1001.0],
#   82: [45.3789, 1001.0, 459.662, 1026.0],
#   83: [27.0, 1026.0, 613.95015, 1101.0],
#   84: [48.44385, 1026.0, 613.95015, 1076.0],
#   85: [184.94865000000001, 1026.0, 613.95015, 1051.0],
#   86: [184.94865000000001, 1051.0, 609.95015, 1076.0],
#   87: [48.44385, 1076.0, 377.7567, 1101.0],
#   88: [20.0, 1101.0, 617.3937500000001, 1176.0],
#   89: [84.9764, 1101.0, 617.3937500000001, 1151.0],
#   90: [158.39225, 1101.0, 266.02271199999996, 1126.0],
#   91: [158.39225, 1126.0, 617.39375, 1151.0],
#   92: [84.9764, 1151.0, 486.5049, 1176.0]}}
