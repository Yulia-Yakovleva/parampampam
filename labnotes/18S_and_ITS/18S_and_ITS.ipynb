# %%
pth_to_stats = '/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv'
pth_to_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S/formated_id_full.fa'
pth_to_its = '/home/yulia/parampampam/raw_data/fasta_files/ITS/formated_id_with_add.fa'

outf_ssu = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa'
outf_its = '/home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa'

# %%
import pandas as pd
from Bio import SeqIO

ssu_out = []
its_out = []


df = pd.read_csv(pth_to_stats, sep='\t')
ssu_recs = [rec for rec in SeqIO.parse(pth_to_ssu, 'fasta')]
its_recs = [rec for rec in SeqIO.parse(pth_to_its, 'fasta')]

foursev_its_recs = []
c = 0
with open(outf_its, 'w') as out_f:
    for its in df.its_id:
        foursev_its_recs.append(its)
        c+=1
        for rec in its_recs:
            if its == rec.name:
                its_out.append(rec)
                SeqIO.write(rec, out_f, 'fasta')
print(c)

foursev_ssu_recs = []
c = 0
with open(outf_ssu, 'w') as out_f:
    for ssu in df.ssu_id:
        foursev_ssu_recs.append(ssu)
        c+=1
        for rec in ssu_recs:
            if ssu == rec.name:
                ssu_out.append(rec)
                SeqIO.write(rec, out_f, 'fasta')

ssu_names = set()
with open(outf_ssu, 'r') as ssu_f:
    for line in ssu_f:
        line = line.strip()
        if line.startswith('>'):
            ssu_names.add(line[1:])
            
its_names = set()
with open(outf_its, 'r') as its_f:
    for line in its_f:
        line = line.strip()
        if line.startswith('>'):
            its_names.add(line[1:])

# check fails
for name in foursev_its_recs:
    print(name)
    if name not in its_names:
        print(name, 'here')
        
for name in foursev_ssu_recs:
    print(name)
    if name not in ssu_names:
        print(name, 'here')
# Out:
# 47
# 954787BF1B
# 55CEC58B7B
# A22A7EB077
# 84CE765D07
# A9D77FB142
# C0FF30338F
# 6A22C8816B
# A100F8A811
# FFCD65A9C1
# FE6BF56E99
# BAFBB32B3C
# 9F17B676E6
# A28E935B8D
# E4C28EC0EC
# D4CE20BD5A
# E24B3A4289
# 7EB0465780
# 87876A753A
# 5EDFE55A10
# 3B4F40C1B6
# 4C5F4E4CDE
# A50EB0413A
# 20D1316E5D
# 8E203F786B
# 4571A227E6
# 317A91CB34
# 754C622D24
# AFED3029BB
# 0C044FF14F
# F5F4A73DA3
# 3232DFC4C6
# 70890594D2
# 7AB785E8EB
# F2145CCC2C
# 7760F61162
# ABB2EFBA0D
# 06BCC826BF
# 7337CC22D1
# 55622BCCF2
# E5A80E2658
# 1B54F3DD84
# 4EC675C343
# 05EB3CB2EF
# FT8_ITS
# E53453BD54
# E53453BD54 here
# 27457DB888
# 27457DB888 here
# B9FA7E99CC
# B9FA7E99CC here
# 8263802E57
# 52AC81ACB3
# AC28253C84
# F2A09C7B50
# F6F7DBAD01
# 4953348A77
# 9EA5A82A4B
# B1830287A1
# B2119F1FC6
# E1AC33E295
# 0113C4C62A
# B9EAB39D24
# 7EE3E00E2C
# EE5B03DA5E
# 51771109E9
# AC8716D80A
# A6A557D074
# 4F5A67EC10
# A825F8899B
# 908F980B86
# 69229F7190
# D56B98A901
# E8A136DD40
# 18C947E131
# F9D739A7DA
# 10F7A85AF0
# 7F4AA4EA36
# 1297B09026
# 00B63B8005
# 6C5ADD699F
# E4E1C9608E
# AD44EE3174
# F052BC4099
# 22748EAD14
# C80A7427A2
# 59F4C3171A
# FA9DFCE9DB
# 6B46EBE0AD
# 44611EBDCA
# 0A30787B3B
# 948B5933CA
# F63C7027B7
# 1FC8A5CFC3
# DCB12F983A
# E53453BD54
# 27457DB888
# B9FA7E99CC

# %%
# для Максима
import pandas as pd

def rename_ids(stats, in_f, out_f):
    df = pd.read_csv(stats, sep='\t')
    with open(in_f) as inf, open(out_f, 'w') as outf:
        for line in inf:
            for idx, descr in zip(df['Unnamed: 0'], df['description']):
                if idx in line:
                    line = line.replace(idx, descr)
            outf.write(line)
                
                
stats = '/home/yulia/parampampam/raw_data/stats/COI/stats_final.tsv'
in_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/mafft_aln_fianl_more_outgroup_full.fa'
out_f = '/home/yulia/parampampam/alignments/COI/tree_4_more_outgroup/COI_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/18S/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/18S/18S_GBlocks_regions_3.fst'
out_f = '/home/yulia/parampampam/alignments/18S/SSU_normal_names.fa'

stats = '/home/yulia/parampampam/raw_data/stats/ITS/total_stats_full.tsv'
in_f = '/home/yulia/parampampam/alignments/ITS/ITS_GBlocks_2.fst'
out_f = '/home/yulia/parampampam/alignments/ITS/ITS_normal_names.fa'

rename_ids(stats, in_f, out_f)

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/ITS.fa > /home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    45 /46
# Reallocating..done. *alloclen = 6654
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-2851
# STEP 003-006-1  identical.    identical.    accepted. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    rejected. rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    accepted. identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    identical.    rejected. identical.    accepted. accepted. accepted. identical.    accepted. identical.    identical.    identical.    identical.    identical.    identical.    accepted. identical.    identical.    identical.    rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    rejected. rejected. rejected. identical.    identical.    rejected. identical.    rejected. identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 951 ms, sys: 199 ms, total: 1.15 s
# Wall time: 43.5 s

# %%
# %%time
! mafft --maxiterate 1000 --localpair /home/yulia/parampampam/raw_data/fasta_files/18S_and_ITS/18S.fa > /home/yulia/parampampam/alignments/18S_and_ITS/18S_aln.fa
# Out:
# outputhat23=16
# treein = 0
# compacttree = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# All-to-all alignment.
# tbfast-pair (nuc) Version 7.429
# alg=L, model=DNA200 (2), 2.00 (6.00), -0.10 (-0.30), noshift, amax=0.0
# 0 thread(s)
#
# outputhat23=16
# Loading 'hat3.seed' ...
# done.
# Writing hat3 for iterative refinement
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
# tbutree = 1, compacttree = 0
# Constructing a UPGMA tree ...
#    40 / 47
# done.
#
# Progressive alignment ...
# STEP    39 /46
# Reallocating..done. *alloclen = 6646
# STEP    46 /46
# done.
# tbfast (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
# minimumweight = 0.000010
# autosubalignment = 0.000000
# nthread = 0
# randomseed = 0
# blosum 62 / kimura 200
# poffset = 0
# niter = 16
# sueff_global = 0.100000
# nadd = 16
# Loading 'hat3' ... done.
# generating a scoring matrix for nucleotide (dist=200) ... done
#
#    40 / 47
# Segment   1/  1    1-3086
# STEP 003-008-0  identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    accepted. identical.    accepted. rejected. accepted. rejected. identical.    accepted. identical.    identical.    accepted. rejected. identical.    identical.    accepted. identical.    accepted. rejected. rejected. rejected. identical.    identical.    identical.    accepted. accepted. identical.    rejected. accepted. rejected. identical.    identical.    identical.    rejected. rejected. identical.    identical.    identical.    identical.    rejected. identical.    rejected. rejected. identical.    rejected. identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    rejected. identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.    identical.
# Converged.
#
# done
# dvtditr (nuc) Version 7.429
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  L-INS-i (Probably most accurate, very slow)
#  Iterative refinement method (<16) with LOCAL pairwise alignment information
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
#
# CPU times: user 1.22 s, sys: 192 ms, total: 1.41 s
# Wall time: 57 s

# %%
# сделать Gblocks

# %%
# назвать ssu сиквенсы айдишниками its 
from Bio import SeqIO

ssu_in = '/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions.fa'
its_in = '/home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln_regions.fa'
ssu_out ='/home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions_renamed.fa'

names = []
its_recs = [rec for rec in SeqIO.parse(its_in, 'fasta')]
for rec in its_recs:
    names.append(rec.name)

out_recs = []
ssu_recs = [rec for rec in SeqIO.parse(ssu_in, 'fasta')]
for rec, its_name in zip(ssu_recs, names):
    rec.id = its_name
    rec.name = its_name
    rec.description = its_name
    out_recs.append(rec)
    
with open(ssu_out, 'w') as out_f:
    for rec in out_recs:
        SeqIO.write(rec, out_f, 'fasta')

# %%
! seqkit concat /home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions_renamed.fa /home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln_regions.fa > /home/yulia/parampampam/alignments/18S_and_ITS/concatenated.fa
# Out:
# [INFO] read file: /home/yulia/parampampam/alignments/18S_and_ITS/18S_aln_regions_renamed.fa
# [INFO] 47 records loaded
# [INFO] read file: /home/yulia/parampampam/alignments/18S_and_ITS/ITS_aln_regions.fa
# [INFO] 47 records loaded

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/con_50_majrule.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# (Paramecium putrinum ETu 7-4 MG573199.1:0.149481,(Pdub HE819875.1:0.000955616,HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.000911354)1.00:0.0728254,((Paramecium nephridiatum Sr 2-6 MG573198.1:0.0616023,(MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000512234,KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.000521276)1.00:0.139758)0.98:0.023449,(KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.0999512,((((((HSG3-10 ITS:0.00246207,SP-1:0.000493312)0.90:0.00109953,CD11-9:0.00242933):0,ShKm41:0.000477691)0.79:0.00111702,PO-16:0.000611641)1.00:0.012109,K5-2:0.0327197)1.00:0.039107,(FT8:0.0593486,((((Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.000492926,12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.000479361)1.00:0.00357154,(((strain14 PP-2:0.000481997,((SMM81-1:0.000480878,FCB10-1:0.000488527):0,PL4-1:0.000481024)0.76:0.00110392):0,(CyL3-21:0.000607713,T42-1:0.00231184)0.63:0.00104566):0,6 Paramecium multimicronucleatum OP13 JF741217.1:0.00116134)1.00:0.00453448)1.00:0.0110488,(((((((((((((ThK-16:0.000485799,CyP5-3:0.00114786):0,MSA-5:0.00504485):0,16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.000482468):0,17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.0011586)0.97:0.00177452,ChP5-3:0.00049578):0,Or4-3:0.00246484):0,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00116499)0.74:0.00112404,(LB-1:0.00179997,SK6-3:0.000497343)0.97:0.00115673):0,K4-2:0.000480994):0,L72-1:0.000491138):0,R51-6:0.000482955):0,ChP10-2:0.00115126):0,OmN-1:0.00179346)1.00:0.0163224)1.00:0.0368101,(Paramecium jenningsi FL KF110697.1:0.00829667,(((Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.000476822,Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.00113762):0,Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.000477202)1.00:0.00849807,((Paramecium pentaurelia strain Nr1-10 MG573197.1:0.00111249,Paramecium primaurelia CyL4-1 MH185950.1:0.000485992):0,(Paramecium primaurelia 16/IP 17-21 MG573196.1:0.000489851,(Paramecium primaurelia ThK-1 MG573194.1:0.00118058,Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00180945)0.93:0.00112782):0)1.00:0.00387787)0.78:0.00329165)1.00:0.0191391)0.84:0.0151343)0.68:0.0110645)1.00:0.0738938)0.82:0.0199719)1.00:0.0765174);

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# HE662765.2 Paramecium caudatum partial 18S rRNA gene strain FT8
# (("Paramecium putrinum ETu 7-4 MG573199.1":0.149481,("Pdub HE819875.1":0.000955616,"HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":0.000911354)1.00:0.0728254):0.0540884,(("Paramecium nephridiatum Sr 2-6 MG573198.1":0.0616023,("MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000512234,"KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":0.000521276)1.00:0.139758)0.98:0.023449,("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0999512,(((((("HSG3-10 ITS":0.00246207,"SP-1":0.000493312)0.90:0.00109953,"CD11-9":0.00242933):0,"ShKm41":0.000477691)0.79:0.00111702,"PO-16":0.000611641)1.00:0.012109,"K5-2":0.0327197)1.00:0.039107,(FT8:0.0593486,(((("Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":0.000492926,"12 Paramecium multimicronucleatum AB9-8 JF741240.1":0.000479361)1.00:0.00357154,((("strain14 PP-2":0.000481997,(("SMM81-1":0.000480878,"FCB10-1":0.000488527):0,"PL4-1":0.000481024)0.76:0.00110392):0,("CyL3-21":0.000607713,"T42-1":0.00231184)0.63:0.00104566):0,"6 Paramecium multimicronucleatum OP13 JF741217.1":0.00116134)1.00:0.00453448)1.00:0.0110488,((((((((((((("ThK-16":0.000485799,"CyP5-3":0.00114786):0,"MSA-5":0.00504485):0,"16 Paramecium multimicronucleatum Ns2-16 JF741224.1":0.000482468):0,"17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.0011586)0.97:0.00177452,"ChP5-3":0.00049578):0,"Or4-3":0.00246484):0,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.00116499)0.74:0.00112404,("LB-1":0.00179997,"SK6-3":0.000497343)0.97:0.00115673):0,"K4-2":0.000480994):0,"L72-1":0.000491138):0,"R51-6":0.000482955):0,"ChP10-2":0.00115126):0,"OmN-1":0.00179346)1.00:0.0163224)1.00:0.0368101,("Paramecium jenningsi FL KF110697.1":0.00829667,((("Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":0.000476822,"Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00113762):0,"Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":0.000477202)1.00:0.00849807,(("Paramecium pentaurelia strain Nr1-10 MG573197.1":0.00111249,"Paramecium primaurelia CyL4-1 MH185950.1":0.000485992):0,("Paramecium primaurelia 16/IP 17-21 MG573196.1":0.000489851,("Paramecium primaurelia ThK-1 MG573194.1":0.00118058,"Paramecium primaurelia 16/IP 4-1 MG573195.1":0.00180945)0.93:0.00112782):0)1.00:0.00387787)0.78:0.00329165)1.00:0.0191391)0.84:0.0151343)0.68:0.0110645)1.00:0.0738938)0.82:0.0199719):0.022429)1.00;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/mb_ete_tree.newick', format=0, quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/mb_ete_tree_.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1071.8236932754517, 8.0, 1084.8236932754517, 0, '1'],
#   [34.6435, 998.8973865509033, 41.6435, 1011.8973865509033, 1, '1'],
#   [49.601350000000004,
#    928.0447731018066,
#    71.60135,
#    941.0447731018066,
#    2,
#    '0.82'],
#   [175.44205, 842.5895462036133, 182.44205, 855.5895462036133, 3, '1'],
#   [182.44205, 720.8978424072266, 204.44205, 733.8978424072266, 4, '0.68'],
#   [205.1435, 603.2956848144531, 227.1435, 616.2956848144531, 5, '0.84'],
#   [275.35865, 439.18511962890625, 282.35865, 452.18511962890625, 6, '1'],
#   [299.84225000000004,
#    337.9171142578125,
#    306.84225000000004,
#    350.9171142578125,
#    7,
#    '1'],
#   [306.84225000000004,
#    312.334228515625,
#    313.84225000000004,
#    325.334228515625,
#    8,
#    '1'],
#   [313.84225000000004,
#    286.16845703125,
#    320.84225000000004,
#    299.16845703125,
#    9,
#    '1'],
#   [320.84225000000004,
#    258.8369140625,
#    327.84225000000004,
#    271.8369140625,
#    10,
#    '1'],
#   [327.84225000000004,
#    229.173828125,
#    334.84225000000004,
#    242.173828125,
#    11,
#    '1'],
#   [334.84225000000004,
#    194.84765625,
#    341.84225000000004,
#    207.84765625,
#    12,
#    '1'],
#   [341.84225000000004,
#    163.6953125,
#    363.84225000000004,
#    176.6953125,
#    13,
#    '0.74'],
#   [363.84225000000004, 138.890625, 370.84225000000004, 151.890625, 14, '1'],
#   [370.84225000000004, 114.28125, 377.84225000000004, 127.28125, 15, '1'],
#   [377.84225000000004, 90.0625, 399.84225000000004, 103.0625, 16, '0.97'],
#   [399.84225000000004, 66.625, 406.84225000000004, 79.625, 17, '1'],
#   [406.84225000000004, 44.75, 413.84225000000004, 57.75, 18, '1'],
#   [413.84225000000004, 26.0, 420.84225000000004, 39.0, 19, '1'],
#   [422.56404000000003, 6.0, 466.56404000000003, 21.0, 20, 'CyP5-3'],
#   [421.57094850000004, 31.0, 464.57094850000004, 46.0, 21, 'ThK-16'],
#   [421.40952500000003, 56.0, 461.40952500000003, 71.0, 22, 'MSA-5'],
#   [407.56595200000004,
#    81.0,
#    739.565952,
#    96.0,
#    23,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [401.58015000000006,
#    106.0,
#    739.58015,
#    121.0,
#    24,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [378.58592000000004, 131.0, 423.58592000000004, 146.0, 25, 'ChP5-3'],
#   [374.53951000000006, 156.0, 408.53951000000006, 171.0, 26, 'Or4-3'],
#   [365.589735,
#    181.0,
#    686.589735,
#    196.0,
#    27,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [341.84225000000004, 226.0, 363.84225000000004, 239.0, 28, '0.97'],
#   [364.58826450000004, 206.0, 401.58826450000004, 221.0, 29, 'SK6-3'],
#   [366.542205, 231.0, 394.542205, 246.0, 30, 'LB-1'],
#   [335.56374100000005, 256.0, 363.56374100000005, 271.0, 31, 'K4-2'],
#   [328.57895700000006, 281.0, 362.57895700000006, 296.0, 32, 'L72-1'],
#   [321.5666825, 306.0, 357.5666825, 321.0, 33, 'R51-6'],
#   [315.56914000000006, 331.0, 367.56914000000006, 346.0, 34, 'ChP10-2'],
#   [309.53244000000007, 356.0, 351.53244000000007, 371.0, 35, 'OmN-1'],
#   [291.93185, 540.453125, 298.93185, 553.453125, 36, '1'],
#   [298.93185, 504.90625, 305.93185, 517.90625, 37, '1'],
#   [305.93185, 471.3125, 312.93185, 484.3125, 38, '1'],
#   [312.93185, 441.625, 319.93185, 454.625, 39, '1'],
#   [319.93185, 419.75, 341.93185, 432.75, 40, '0.76'],
#   [341.93185, 401.0, 348.93185, 414.0, 41, '1'],
#   [349.6646405, 381.0, 401.6646405, 396.0, 42, 'FCB10-1'],
#   [349.653167, 406.0, 406.653167, 421.0, 43, 'SMM81-1'],
#   [342.653386, 431.0, 377.653386, 446.0, 44, 'PL4-1'],
#   [320.65484549999996, 456.0, 399.65484549999996, 471.0, 45, 'strain14 PP-2'],
#   [312.93185, 501.0, 334.93185, 514.0, 46, '0.63'],
#   [338.39961, 481.0, 372.39961, 496.0, 47, 'T42-1'],
#   [335.8434195, 506.0, 385.8434195, 521.0, 48, 'CyL3-21'],
#   [307.67386,
#    531.0,
#    623.67386,
#    546.0,
#    49,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [298.93185, 576.0, 305.93185, 589.0, 50, '1'],
#   [306.6508915,
#    556.0,
#    631.6508915,
#    571.0,
#    51,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [306.671239,
#    581.0,
#    649.671239,
#    596.0,
#    52,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [248.85215, 767.40625, 255.85215, 780.40625, 53, '1'],
#   [255.85215, 721.3125, 277.85215, 734.3125, 54, '0.78'],
#   [277.85215, 672.875, 284.85215, 685.875, 55, '1'],
#   [284.85215, 644.75, 291.85215, 657.75, 56, '1'],
#   [291.85215, 626.0, 313.85215, 639.0, 57, '0.93'],
#   [316.566325,
#    606.0,
#    592.566325,
#    621.0,
#    58,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [315.62302,
#    631.0,
#    574.62302,
#    646.0,
#    59,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [292.5869265,
#    656.0,
#    582.5869265,
#    671.0,
#    60,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [284.85215, 701.0, 291.85215, 714.0, 61, '1'],
#   [292.581138,
#    681.0,
#    557.581138,
#    696.0,
#    62,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [293.520885,
#    706.0,
#    592.520885,
#    721.0,
#    63,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [283.59925499999997, 769.75, 290.59925499999997, 782.75, 64, '1'],
#   [290.59925499999997, 751.0, 297.59925499999997, 764.0, 65, '1'],
#   [299.305685,
#    731.0,
#    618.305685,
#    746.0,
#    66,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [298.314488,
#    756.0,
#    610.314488,
#    771.0,
#    67,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [291.31505799999996,
#    781.0,
#    602.3150579999999,
#    796.0,
#    68,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [268.297155,
#    806.0,
#    489.297155,
#    821.0,
#    69,
#    'Paramecium jenningsi FL KF110697.1'],
#   [293.46495, 831.0, 317.46495, 846.0, 70, 'FT8'],
#   [234.10255, 964.28125, 241.10255, 977.28125, 71, '1'],
#   [252.26605, 940.0625, 259.26605, 953.0625, 72, '1'],
#   [259.26605, 916.625, 281.26605, 929.625, 73, '0.79'],
#   [281.26605, 894.75, 288.26605, 907.75, 74, '1'],
#   [288.26605, 876.0, 304.26605, 889.0, 75, '0.9'],
#   [305.006018, 856.0, 334.006018, 871.0, 76, 'SP-1'],
#   [307.959155, 881.0, 385.959155, 896.0, 77, 'HSG3-10 ITS'],
#   [291.910045, 906.0, 336.910045, 921.0, 78, 'CD11-9'],
#   [281.9825865, 931.0, 331.9825865, 946.0, 79, 'ShKm41'],
#   [260.1835115, 956.0, 298.1835115, 971.0, 80, 'PO-16'],
#   [290.1821, 981.0, 318.1821, 996.0, 81, 'K5-2'],
#   [221.52815,
#    1006.0,
#    547.52815,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [54.81700000000001, 1069.75, 76.81700000000001, 1082.75, 83, '0.98'],
#   [279.454, 1051.0, 286.454, 1064.0, 84, '1'],
#   [287.235914,
#    1031.0,
#    712.235914,
#    1046.0,
#    85,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [287.222351,
#    1056.0,
#    716.222351,
#    1071.0,
#    86,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [169.22045000000003,
#    1081.0,
#    439.22045,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [82.1326, 1144.75, 89.1326, 1157.75, 88, '1'],
#   [191.3707, 1126.0, 198.3707, 1139.0, 89, '1'],
#   [199.737731,
#    1106.0,
#    658.7377309999999,
#    1121.0,
#    90,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [199.804124, 1131.0, 306.804124, 1146.0, 91, 'Pdub HE819875.1'],
#   [313.3541,
#    1156.0,
#    569.3541,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 739.5801500000001, 1176.0],
#   1: [8.0, 1.0, 739.5801500000001, 1101.0],
#   2: [41.6435, 1.0, 739.5801500000001, 1026.0],
#   3: [71.60135, 1.0, 739.5801500000001, 1001.0],
#   4: [182.44205, 1.0, 739.5801500000001, 851.0],
#   5: [204.44205, 1.0, 739.5801500000001, 826.0],
#   6: [227.1435, 1.0, 739.5801500000001, 601.0],
#   7: [282.35865, 1.0, 739.58015, 376.0],
#   8: [306.84225000000004, 1.0, 739.58015, 351.0],
#   9: [313.84225000000004, 1.0, 739.58015, 326.0],
#   10: [320.84225000000004, 1.0, 739.58015, 301.0],
#   11: [327.84225000000004, 1.0, 739.58015, 276.0],
#   12: [334.84225000000004, 1.0, 739.58015, 251.0],
#   13: [341.84225000000004, 1.0, 739.58015, 201.0],
#   14: [363.84225000000004, 1.0, 739.58015, 176.0],
#   15: [370.84225000000004, 1.0, 739.58015, 151.0],
#   16: [377.84225000000004, 1.0, 739.58015, 126.0],
#   17: [399.84225000000004, 1.0, 739.565952, 101.0],
#   18: [406.84225000000004, 1.0, 466.56404000000003, 76.0],
#   19: [413.84225000000004, 1.0, 466.56404000000003, 51.0],
#   20: [420.84225000000004, 1.0, 466.56404000000003, 26.0],
#   21: [420.84225000000004, 26.0, 464.57094850000004, 51.0],
#   22: [413.84225000000004, 51.0, 461.40952500000003, 76.0],
#   23: [406.84225000000004, 76.0, 739.565952, 101.0],
#   24: [399.84225000000004, 101.0, 739.58015, 126.0],
#   25: [377.84225000000004, 126.0, 423.58592000000004, 151.0],
#   26: [370.84225000000004, 151.0, 408.53951000000006, 176.0],
#   27: [363.84225000000004, 176.0, 686.589735, 201.0],
#   28: [341.84225000000004, 201.0, 401.58826450000004, 251.0],
#   29: [363.84225000000004, 201.0, 401.58826450000004, 226.0],
#   30: [363.84225000000004, 226.0, 394.542205, 251.0],
#   31: [334.84225000000004, 251.0, 363.56374100000005, 276.0],
#   32: [327.84225000000004, 276.0, 362.57895700000006, 301.0],
#   33: [320.84225000000004, 301.0, 357.5666825, 326.0],
#   34: [313.84225000000004, 326.0, 367.56914000000006, 351.0],
#   35: [306.84225000000004, 351.0, 351.53244000000007, 376.0],
#   36: [282.35865, 376.0, 649.671239, 601.0],
#   37: [298.93185, 376.0, 623.67386, 551.0],
#   38: [305.93185, 376.0, 406.653167, 526.0],
#   39: [312.93185, 376.0, 406.653167, 476.0],
#   40: [319.93185, 376.0, 406.653167, 451.0],
#   41: [341.93185, 376.0, 406.653167, 426.0],
#   42: [348.93185, 376.0, 401.6646405, 401.0],
#   43: [348.93185, 401.0, 406.653167, 426.0],
#   44: [341.93185, 426.0, 377.653386, 451.0],
#   45: [319.93185, 451.0, 399.65484549999996, 476.0],
#   46: [312.93185, 476.0, 385.8434195, 526.0],
#   47: [334.93185, 476.0, 372.39961, 501.0],
#   48: [334.93185, 501.0, 385.8434195, 526.0],
#   49: [305.93185, 526.0, 623.67386, 551.0],
#   50: [298.93185, 551.0, 649.671239, 601.0],
#   51: [305.93185, 551.0, 631.6508915, 576.0],
#   52: [305.93185, 576.0, 649.671239, 601.0],
#   53: [227.1435, 601.0, 618.3056849999999, 826.0],
#   54: [255.85215, 601.0, 618.305685, 801.0],
#   55: [277.85215, 601.0, 592.566325, 726.0],
#   56: [284.85215, 601.0, 592.566325, 676.0],
#   57: [291.85215, 601.0, 592.566325, 651.0],
#   58: [313.85215, 601.0, 592.566325, 626.0],
#   59: [313.85215, 626.0, 574.62302, 651.0],
#   60: [291.85215, 651.0, 582.5869265, 676.0],
#   61: [284.85215, 676.0, 592.520885, 726.0],
#   62: [291.85215, 676.0, 557.581138, 701.0],
#   63: [291.85215, 701.0, 592.520885, 726.0],
#   64: [277.85215, 726.0, 618.305685, 801.0],
#   65: [290.59925499999997, 726.0, 618.305685, 776.0],
#   66: [297.59925499999997, 726.0, 618.305685, 751.0],
#   67: [297.59925499999997, 751.0, 610.314488, 776.0],
#   68: [290.59925499999997, 776.0, 602.3150579999999, 801.0],
#   69: [255.85215, 801.0, 489.297155, 826.0],
#   70: [204.44205, 826.0, 317.46495, 851.0],
#   71: [182.44205, 851.0, 385.959155, 1001.0],
#   72: [241.10255, 851.0, 385.959155, 976.0],
#   73: [259.26605, 851.0, 385.959155, 951.0],
#   74: [281.26605, 851.0, 385.959155, 926.0],
#   75: [288.26605, 851.0, 385.959155, 901.0],
#   76: [304.26605, 851.0, 334.006018, 876.0],
#   77: [304.26605, 876.0, 385.959155, 901.0],
#   78: [288.26605, 901.0, 336.910045, 926.0],
#   79: [281.26605, 926.0, 331.9825865, 951.0],
#   80: [259.26605, 951.0, 298.1835115, 976.0],
#   81: [241.10255, 976.0, 318.1821, 1001.0],
#   82: [71.60135, 1001.0, 547.52815, 1026.0],
#   83: [41.6435, 1026.0, 716.222351, 1101.0],
#   84: [76.81700000000001, 1026.0, 716.222351, 1076.0],
#   85: [286.454, 1026.0, 712.235914, 1051.0],
#   86: [286.454, 1051.0, 716.222351, 1076.0],
#   87: [76.81700000000001, 1076.0, 439.22045, 1101.0],
#   88: [8.0, 1101.0, 658.737731, 1176.0],
#   89: [89.1326, 1101.0, 658.737731, 1151.0],
#   90: [198.3707, 1101.0, 658.7377309999999, 1126.0],
#   91: [198.3707, 1126.0, 306.804124, 1151.0],
#   92: [89.1326, 1151.0, 569.3541, 1176.0]}}

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('/home/yulia/parampampam/raw_data/stats/18S_and_ITS/stats_final.tsv', sep='\t', index_col=0)
# print(df)

with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_bipartitions.result', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['strain'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# (Paramecium primaurelia 16/IP 17-21 MG573196.1:0.00000100000050002909,((Paramecium primaurelia ThK-1 MG573194.1:0.00036553473078584610,Paramecium primaurelia 16/IP 4-1 MG573195.1:0.00073069243813947003)72:0.00036326753224832193,(Paramecium pentaurelia strain Nr1-10 MG573197.1:0.00036379944077350259,((Paramecium biaurelia isolate US_Bl 11III1 KU729876.1:0.00036552961985702651,(Paramecium biaurelia isolate US_Bl 12I1 KX712111.1:0.00000100000050002909,Paramecium biaurelia isolate US_Bl 15I1 KU729877.1:0.00000100000050002909)75:0.00000100000050002909)100:0.00481368614765109379,(Paramecium jenningsi FL KF110697.1:0.00416060073740229935,((((KX669629.1 Paramecium chlorelligerum strain HSG1-11:0.06004788659498528497,((Paramecium putrinum ETu 7-4 MG573199.1:0.09385834321046580830,(Pdub HE819875.1:0.00042284158128709460,HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene ITS1 5.8S rRNA gene ITS2 and 28S rRNA gene strain IG2-1:0.00000100000050002909)100:0.04388539845853415416)100:0.04803077062506020539,((KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909,MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and large subunit ribosomal RNA gene partial sequence:0.00000100000050002909)100:0.08706472785206000042,Paramecium nephridiatum Sr 2-6 MG573198.1:0.03676691513687980334)98:0.01259462841042918377)22:0.01108481749234067198)100:0.04431978742496888585,(K5-2:0.01914869301858681053,(PO-16:0.00000100000050002909,(ShKm41:0.00000100000050002909,((HSG3-10 ITS:0.00109879088991823447,SP-1:0.00000100000050002909)61:0.00036266119461885431,CD11-9:0.00108998748659889025)24:0.00000100000050002909)65:0.00036260688331009376)99:0.00658053209383454435)100:0.02194262013786514934)27:0.00575444554562308530,FT8:0.03553526129226946412)60:0.00888367040190272093,(((((ChP10-2:0.00036841062771048310,((R51-6:0.00000100000050002909,K4-2:0.00000100000050002909)22:0.00000100000050002909,(SK6-3:0.00000100000050002909,LB-1:0.00073681601825528601)65:0.00036842676594229812)0:0.00000100000050002909)0:0.00000100000050002909,L72-1:0.00000100000050002909)15:0.00000100000050002909,OmN-1:0.00073748840550116228)57:0.00000100000050002909,((((17 Paramecium multimicronucleatum Vv171-1 JF741234.1:0.00037039332419364193,(((CyP5-3:0.00036824429770508947,MSA-5:0.00261045613775512993)37:0.00000100000050002909,ThK-16:0.00000100000050002909)4:0.00000100000050002909,16 Paramecium multimicronucleatum Ns2-16 JF741224.1:0.00000100000050002909)12:0.00000100000050002909)75:0.00073730472060587731,Or4-3:0.00110705652073167515)26:0.00000100000050002909,ChP5-3:0.00000100000050002909)16:0.00000100000050002909,4 Paramecium multimicronucleatum MB2-5 JF741213.1:0.00037092670731081408)52:0.00036788424373862262)93:0.00947985196604806193,((12 Paramecium multimicronucleatum AB9-8 JF741240.1:0.00000100000050002909,Paramecium multimicronucleatum US_Bl 16I1 MK595741.1:0.00000100000050002909)100:0.00176911781511741948,(((6 Paramecium multimicronucleatum OP13 JF741217.1:0.00036830557706810975,(CyL3-21:0.00000100000050002909,T42-1:0.00110054893517042831)47:0.00028735211507595852)53:0.00007970717627046657,strain14 PP-2:0.00000100000050002909)23:0.00000100000050002909,((PL4-1:0.00000100000050002909,FCB10-1:0.00000100000050002909)31:0.00000100000050002909,SMM81-1:0.00000100000050002909)70:0.00036630130324194395)99:0.00229969967435890302)99:0.00570658919678103047)100:0.02260806132634579635)100:0.01069967498713103593)50:0.00161500657526759267)95:0.00190305948338234275)58:0.00000100000050002909)58:0.00000100000050002909,Paramecium primaurelia CyL4-1 MH185950.1:0.00000100000050002909);

# %%
with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_rooted.newick', 'r') as in_f:
    with open('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.strain):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['strain'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# HE662765.2 Paramecium caudatum partial 18S rRNA gene strain FT8
# (("Paramecium putrinum ETu 7-4 MG573199.1":0.0938583,("Pdub HE819875.1":0.000422842,"HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, ITS1, 5.8S rRNA gene, ITS2 and 28S rRNA gene, strain IG2-1":1e-06)100:0.0438854):0.0300119,((("KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06,"MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and large subunit ribosomal RNA gene, partial sequence":1e-06)100:0.0870647,"Paramecium nephridiatum Sr 2-6 MG573198.1":0.0367669)98:0.0125946,("KX669629.1 Paramecium chlorelligerum strain HSG1-11":0.0600479,(("K5-2":0.0191487,("PO-16":1e-06,("ShKm41":1e-06,(("HSG3-10 ITS":0.00109879,"SP-1":1e-06)61:0.000362661,"CD11-9":0.00108999)24:1e-06)65:0.000362607)99:0.00658053)100:0.0219426,(FT8:0.0355353,(((((("ChP10-2":0.000368411,(("R51-6":1e-06,"K4-2":1e-06)22:1e-06,("SK6-3":1e-06,"LB-1":0.000736816)65:0.000368427)0:1e-06)0:1e-06,"L72-1":1e-06)15:1e-06,"OmN-1":0.000737488)57:1e-06,(((("17 Paramecium multimicronucleatum Vv171-1 JF741234.1":0.000370393,((("CyP5-3":0.000368244,"MSA-5":0.00261046)37:1e-06,"ThK-16":1e-06)4:1e-06,"16 Paramecium multimicronucleatum Ns2-16 JF741224.1":1e-06)12:1e-06)75:0.000737305,"Or4-3":0.00110706)26:1e-06,"ChP5-3":1e-06)16:1e-06,"4 Paramecium multimicronucleatum MB2-5 JF741213.1":0.000370927)52:0.000367884)93:0.00947985,(("12 Paramecium multimicronucleatum AB9-8 JF741240.1":1e-06,"Paramecium multimicronucleatum US_Bl 16I1 MK595741.1":1e-06)100:0.00176912,((("6 Paramecium multimicronucleatum OP13 JF741217.1":0.000368306,("CyL3-21":1e-06,"T42-1":0.00110055)47:0.000287352)53:7.97072e-05,"strain14 PP-2":1e-06)23:1e-06,(("PL4-1":1e-06,"FCB10-1":1e-06)31:1e-06,"SMM81-1":1e-06)70:0.000366301)99:0.0022997)99:0.00570659)100:0.0226081,("Paramecium jenningsi FL KF110697.1":0.0041606,(("Paramecium biaurelia isolate US_Bl 11III1 KU729876.1":0.00036553,("Paramecium biaurelia isolate US_Bl 12I1 KX712111.1":1e-06,"Paramecium biaurelia isolate US_Bl 15I1 KU729877.1":1e-06)75:1e-06)100:0.00481369,("Paramecium pentaurelia strain Nr1-10 MG573197.1":0.000363799,(("Paramecium primaurelia ThK-1 MG573194.1":0.000365535,"Paramecium primaurelia 16/IP 4-1 MG573195.1":0.000730692)72:0.000363268,("Paramecium primaurelia 16/IP 17-21 MG573196.1":1e-06,"Paramecium primaurelia CyL4-1 MH185950.1":1e-06)58:1e-06)58:1e-06)95:0.00190306)50:0.00161501)100:0.0106997)60:0.00888367)27:0.00575445)100:0.0443198)22:0.0110848):0.0180189)100;

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('/home/yulia/parampampam/trees/18S_and_ITS/RAxML_ete_tree.newick', quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('/home/yulia/parampampam/figures/18S_and_ITS/RAxML_ete_tree.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1071.0813293457031, 20.0, 1084.0813293457031, 0, '100'],
#   [40.02835, 997.4126586914062, 47.02835, 1010.4126586914062, 1, '1'],
#   [50.655550000000005,
#    925.0753173828125,
#    63.655550000000005,
#    938.0753173828125,
#    2,
#    '22'],
#   [111.13525,
#    836.650634765625,
#    130.13524999999998,
#    849.650634765625,
#    3,
#    '100'],
#   [130.13524999999998,
#    709.02001953125,
#    143.13524999999998,
#    722.02001953125,
#    4,
#    '27'],
#   [143.46075499999998,
#    579.5400390625,
#    156.46075499999998,
#    592.5400390625,
#    5,
#    '60'],
#   [171.37290499999997,
#    389.330078125,
#    190.37290499999997,
#    402.330078125,
#    6,
#    '100'],
#   [191.59267999999997,
#    250.31640625,
#    204.59267999999997,
#    263.31640625,
#    7,
#    '93'],
#   [204.59267999999997, 163.6953125, 217.59267999999997, 176.6953125, 8, '52'],
#   [217.59267999999997, 138.890625, 230.59267999999997, 151.890625, 9, '16'],
#   [230.59267999999997, 114.28125, 243.59267999999997, 127.28125, 10, '26'],
#   [243.59267999999997, 90.0625, 256.59268, 103.0625, 11, '75'],
#   [256.59268, 66.625, 269.59268, 79.625, 12, '12'],
#   [269.59268, 44.75, 276.59268, 57.75, 13, '4'],
#   [276.59268, 26.0, 289.59268, 39.0, 14, '37'],
#   [293.50836999999996, 6.0, 333.50836999999996, 21.0, 15, 'MSA-5'],
#   [290.145046, 31.0, 334.145046, 46.0, 16, 'CyP5-3'],
#   [276.59418, 56.0, 319.59418, 71.0, 17, 'ThK-16'],
#   [269.59418,
#    81.0,
#    601.59418,
#    96.0,
#    18,
#    '16 Paramecium multimicronucleatum Ns2-16 JF741224.1'],
#   [257.14826949999997,
#    106.0,
#    595.1482695,
#    121.0,
#    19,
#    '17 Paramecium multimicronucleatum Vv171-1 JF741234.1'],
#   [245.25327, 131.0, 279.25327, 146.0, 20, 'Or4-3'],
#   [230.59417999999997, 156.0, 275.59417999999994, 171.0, 21, 'ChP5-3'],
#   [218.1490705,
#    181.0,
#    539.1490705,
#    196.0,
#    22,
#    '4 Paramecium multimicronucleatum MB2-5 JF741213.1'],
#   [204.59267999999997, 336.9375, 217.59267999999997, 349.9375, 23, '57'],
#   [217.59267999999997, 310.375, 230.59267999999997, 323.375, 24, '15'],
#   [230.59267999999997, 282.25, 237.59267999999997, 295.25, 25, '0'],
#   [237.59267999999997, 251.0, 244.59267999999997, 264.0, 26, '0'],
#   [244.59267999999997, 226.0, 257.59268, 239.0, 27, '65'],
#   [258.697904, 206.0, 286.697904, 221.0, 28, 'LB-1'],
#   [257.59418, 231.0, 294.59418, 246.0, 29, 'SK6-3'],
#   [244.59267999999997, 276.0, 257.59268, 289.0, 30, '22'],
#   [257.59418, 256.0, 285.59418, 271.0, 31, 'K4-2'],
#   [257.59418, 281.0, 293.59418, 296.0, 32, 'R51-6'],
#   [238.14529649999997, 306.0, 290.1452965, 321.0, 33, 'ChP10-2'],
#   [230.59417999999997, 331.0, 264.59417999999994, 346.0, 34, 'L72-1'],
#   [218.69891199999998, 356.0, 260.69891199999995, 371.0, 35, 'OmN-1'],
#   [190.37290499999997, 528.34375, 203.37290499999997, 541.34375, 36, '99'],
#   [203.37290499999997, 480.6875, 216.37290499999997, 493.6875, 37, '99'],
#   [216.37290499999997, 441.625, 229.37290499999997, 454.625, 38, '23'],
#   [229.37290499999997, 419.75, 242.37290499999997, 432.75, 39, '53'],
#   [242.37290499999997, 401.0, 255.37290499999997, 414.0, 40, '47'],
#   [257.02373, 381.0, 291.02373, 396.0, 41, 'T42-1'],
#   [255.37440499999997, 406.0, 305.37440499999997, 421.0, 42, 'CyL3-21'],
#   [242.92536399999997,
#    431.0,
#    558.925364,
#    446.0,
#    43,
#    '6 Paramecium multimicronucleatum OP13 JF741217.1'],
#   [229.37440499999997, 456.0, 308.37440499999997, 471.0, 44, 'strain14 PP-2'],
#   [216.37290499999997, 519.75, 229.37290499999997, 532.75, 45, '70'],
#   [229.37290499999997, 501.0, 242.37290499999997, 514.0, 46, '31'],
#   [242.37440499999997, 481.0, 294.37440499999997, 496.0, 47, 'FCB10-1'],
#   [242.37440499999997, 506.0, 277.37440499999997, 521.0, 48, 'PL4-1'],
#   [229.37440499999997, 531.0, 286.37440499999997, 546.0, 49, 'SMM81-1'],
#   [203.37290499999997, 576.0, 222.37290499999997, 589.0, 50, '100'],
#   [222.374405,
#    556.0,
#    565.374405,
#    571.0,
#    51,
#    'Paramecium multimicronucleatum US_Bl 16I1 MK595741.1'],
#   [222.374405,
#    581.0,
#    547.374405,
#    596.0,
#    52,
#    '12 Paramecium multimicronucleatum AB9-8 JF741240.1'],
#   [156.46075499999998, 769.75, 175.46075499999998, 782.75, 53, '100'],
#   [175.46075499999998, 726.0, 188.46075499999998, 739.0, 54, '50'],
#   [188.46075499999998, 682.25, 201.46075499999998, 695.25, 55, '95'],
#   [201.46075499999998, 651.0, 214.46075499999998, 664.0, 56, '58'],
#   [214.46075499999998, 626.0, 227.46075499999998, 639.0, 57, '58'],
#   [227.462255,
#    606.0,
#    492.462255,
#    621.0,
#    58,
#    'Paramecium primaurelia CyL4-1 MH185950.1'],
#   [227.462255,
#    631.0,
#    517.462255,
#    646.0,
#    59,
#    'Paramecium primaurelia 16/IP 17-21 MG573196.1'],
#   [214.46075499999998, 676.0, 227.46075499999998, 689.0, 60, '72'],
#   [228.556793,
#    656.0,
#    504.55679299999997,
#    671.0,
#    61,
#    'Paramecium primaurelia 16/IP 4-1 MG573195.1'],
#   [228.00905749999995,
#    681.0,
#    487.0090574999999,
#    696.0,
#    62,
#    'Paramecium primaurelia ThK-1 MG573194.1'],
#   [202.0064535,
#    706.0,
#    501.0064535,
#    721.0,
#    63,
#    'Paramecium pentaurelia strain Nr1-10 MG573197.1'],
#   [188.46075499999998, 769.75, 207.46075499999998, 782.75, 64, '100'],
#   [207.46075499999998, 751.0, 220.46075499999998, 764.0, 65, '75'],
#   [220.462255,
#    731.0,
#    532.462255,
#    746.0,
#    66,
#    'Paramecium biaurelia isolate US_Bl 15I1 KU729877.1'],
#   [220.462255,
#    756.0,
#    531.462255,
#    771.0,
#    67,
#    'Paramecium biaurelia isolate US_Bl 12I1 KX712111.1'],
#   [208.00904999999997,
#    781.0,
#    527.00905,
#    796.0,
#    68,
#    'Paramecium biaurelia isolate US_Bl 11III1 KU729876.1'],
#   [181.701655,
#    806.0,
#    402.70165499999996,
#    821.0,
#    69,
#    'Paramecium jenningsi FL KF110697.1'],
#   [196.4382, 831.0, 220.4382, 846.0, 70, 'FT8'],
#   [144.04915, 964.28125, 163.04915, 977.28125, 71, '100'],
#   [163.04915, 940.0625, 176.04915, 953.0625, 72, '99'],
#   [176.04915, 916.625, 189.04915, 929.625, 73, '65'],
#   [189.04915, 894.75, 202.04915, 907.75, 74, '24'],
#   [202.04915, 876.0, 215.04915, 889.0, 75, '61'],
#   [215.05065, 856.0, 244.05065, 871.0, 76, 'SP-1'],
#   [216.697335, 881.0, 294.697335, 896.0, 77, 'HSG3-10 ITS'],
#   [203.684135, 906.0, 248.684135, 921.0, 78, 'CD11-9'],
#   [189.05065, 931.0, 239.05065, 946.0, 79, 'ShKm41'],
#   [176.05065, 956.0, 214.05065, 971.0, 80, 'PO-16'],
#   [191.7722, 981.0, 219.7722, 996.0, 81, 'K5-2'],
#   [153.7274,
#    1006.0,
#    479.7274,
#    1021.0,
#    82,
#    'KX669629.1 Paramecium chlorelligerum strain HSG1-11'],
#   [52.92025, 1069.75, 65.92025000000001, 1082.75, 83, '98'],
#   [177.5173, 1051.0, 196.5173, 1064.0, 84, '100'],
#   [196.51880000000003,
#    1031.0,
#    625.5188,
#    1046.0,
#    85,
#    'MG018200.1 Paramecium calkinsi strain CyL 1-24 small subunit ribosomal'],
#   [196.51880000000003,
#    1056.0,
#    621.5188,
#    1071.0,
#    86,
#    'KY996811.1 Paramecium calkinsi strain CyL 8-33 small subunit ribosomal'],
#   [121.07060000000001,
#    1081.0,
#    391.0706,
#    1096.0,
#    87,
#    'Paramecium nephridiatum Sr 2-6 MG573198.1'],
#   [58.01785, 1144.75, 65.01785000000001, 1157.75, 88, '1'],
#   [111.84595, 1126.0, 130.84595000000002, 1139.0, 89, '100'],
#   [130.84745000000004,
#    1106.0,
#    589.84745,
#    1121.0,
#    90,
#    'HE819874.1 Paramecium duboscqui genomic DNA containing 18S rRNA gene, '],
#   [131.48021300000002,
#    1131.0,
#    238.48021300000002,
#    1146.0,
#    91,
#    'Pdub HE819875.1'],
#   [205.80530000000005,
#    1156.0,
#    461.80530000000005,
#    1171.0,
#    92,
#    'Paramecium putrinum ETu 7-4 MG573199.1']],
#  'node_areas': {0: [1.0, 1.0, 625.5188, 1176.0],
#   1: [20.0, 1.0, 625.5188, 1101.0],
#   2: [47.02835, 1.0, 601.5941800000002, 1026.0],
#   3: [63.655550000000005, 1.0, 601.59418, 1001.0],
#   4: [130.13524999999998, 1.0, 601.59418, 851.0],
#   5: [143.13524999999998, 1.0, 601.59418, 826.0],
#   6: [156.46075499999998, 1.0, 601.59418, 601.0],
#   7: [190.37290499999997, 1.0, 601.59418, 376.0],
#   8: [204.59267999999997, 1.0, 601.59418, 201.0],
#   9: [217.59267999999997, 1.0, 601.59418, 176.0],
#   10: [230.59267999999997, 1.0, 601.59418, 151.0],
#   11: [243.59267999999997, 1.0, 601.59418, 126.0],
#   12: [256.59268, 1.0, 601.59418, 101.0],
#   13: [269.59268, 1.0, 334.145046, 76.0],
#   14: [276.59268, 1.0, 334.145046, 51.0],
#   15: [289.59268, 1.0, 333.50836999999996, 26.0],
#   16: [289.59268, 26.0, 334.145046, 51.0],
#   17: [276.59268, 51.0, 319.59418, 76.0],
#   18: [269.59268, 76.0, 601.59418, 101.0],
#   19: [256.59268, 101.0, 595.1482695, 126.0],
#   20: [243.59267999999997, 126.0, 279.25327, 151.0],
#   21: [230.59267999999997, 151.0, 275.59418, 176.0],
#   22: [217.59267999999997, 176.0, 539.1490705, 201.0],
#   23: [204.59267999999997, 201.0, 294.59417999999994, 376.0],
#   24: [217.59267999999997, 201.0, 294.59417999999994, 351.0],
#   25: [230.59267999999997, 201.0, 294.59417999999994, 326.0],
#   26: [237.59267999999997, 201.0, 294.59418, 301.0],
#   27: [244.59267999999997, 201.0, 294.59418, 251.0],
#   28: [257.59268, 201.0, 286.697904, 226.0],
#   29: [257.59268, 226.0, 294.59418, 251.0],
#   30: [244.59267999999997, 251.0, 293.59418, 301.0],
#   31: [257.59268, 251.0, 285.59418, 276.0],
#   32: [257.59268, 276.0, 293.59418, 301.0],
#   33: [237.59267999999997, 301.0, 290.1452965, 326.0],
#   34: [230.59267999999997, 326.0, 264.59418, 351.0],
#   35: [217.59267999999997, 351.0, 260.69891199999995, 376.0],
#   36: [190.37290499999997, 376.0, 565.374405, 601.0],
#   37: [203.37290499999997, 376.0, 558.925364, 551.0],
#   38: [216.37290499999997, 376.0, 558.925364, 476.0],
#   39: [229.37290499999997, 376.0, 558.925364, 451.0],
#   40: [242.37290499999997, 376.0, 305.37440499999997, 426.0],
#   41: [255.37290499999997, 376.0, 291.02373, 401.0],
#   42: [255.37290499999997, 401.0, 305.37440499999997, 426.0],
#   43: [242.37290499999997, 426.0, 558.925364, 451.0],
#   44: [229.37290499999997, 451.0, 308.37440499999997, 476.0],
#   45: [216.37290499999997, 476.0, 294.37440499999997, 551.0],
#   46: [229.37290499999997, 476.0, 294.37440499999997, 526.0],
#   47: [242.37290499999997, 476.0, 294.37440499999997, 501.0],
#   48: [242.37290499999997, 501.0, 277.37440499999997, 526.0],
#   49: [229.37290499999997, 526.0, 286.37440499999997, 551.0],
#   50: [203.37290499999997, 551.0, 565.374405, 601.0],
#   51: [222.37290499999997, 551.0, 565.374405, 576.0],
#   52: [222.37290499999997, 576.0, 547.374405, 601.0],
#   53: [156.46075499999998, 601.0, 532.462255, 826.0],
#   54: [175.46075499999998, 601.0, 532.462255, 801.0],
#   55: [188.46075499999998, 601.0, 517.462255, 726.0],
#   56: [201.46075499999998, 601.0, 517.462255, 701.0],
#   57: [214.46075499999998, 601.0, 517.462255, 651.0],
#   58: [227.46075499999998, 601.0, 492.462255, 626.0],
#   59: [227.46075499999998, 626.0, 517.462255, 651.0],
#   60: [214.46075499999998, 651.0, 504.55679299999997, 701.0],
#   61: [227.46075499999998, 651.0, 504.55679299999997, 676.0],
#   62: [227.46075499999998, 676.0, 487.0090574999999, 701.0],
#   63: [201.46075499999998, 701.0, 501.0064535, 726.0],
#   64: [188.46075499999998, 726.0, 532.462255, 801.0],
#   65: [207.46075499999998, 726.0, 532.462255, 776.0],
#   66: [220.46075499999998, 726.0, 532.462255, 751.0],
#   67: [220.46075499999998, 751.0, 531.462255, 776.0],
#   68: [207.46075499999998, 776.0, 527.00905, 801.0],
#   69: [175.46075499999998, 801.0, 402.70165499999996, 826.0],
#   70: [143.13524999999998, 826.0, 220.4382, 851.0],
#   71: [130.13524999999998, 851.0, 294.697335, 1001.0],
#   72: [163.04915, 851.0, 294.697335, 976.0],
#   73: [176.04915, 851.0, 294.697335, 951.0],
#   74: [189.04915, 851.0, 294.697335, 926.0],
#   75: [202.04915, 851.0, 294.697335, 901.0],
#   76: [215.04915, 851.0, 244.05065, 876.0],
#   77: [215.04915, 876.0, 294.697335, 901.0],
#   78: [202.04915, 901.0, 248.684135, 926.0],
#   79: [189.04915, 926.0, 239.05065, 951.0],
#   80: [176.04915, 951.0, 214.05065, 976.0],
#   81: [163.04915, 976.0, 219.7722, 1001.0],
#   82: [63.655550000000005, 1001.0, 479.7274, 1026.0],
#   83: [47.02835, 1026.0, 625.5188, 1101.0],
#   84: [65.92025000000001, 1026.0, 625.5188, 1076.0],
#   85: [196.5173, 1026.0, 625.5188, 1051.0],
#   86: [196.5173, 1051.0, 621.5188, 1076.0],
#   87: [65.92025000000001, 1076.0, 391.0706, 1101.0],
#   88: [20.0, 1101.0, 589.84745, 1176.0],
#   89: [65.01785000000001, 1101.0, 589.84745, 1151.0],
#   90: [130.84595000000002, 1101.0, 589.84745, 1126.0],
#   91: [130.84595000000002, 1126.0, 238.48021300000002, 1151.0],
#   92: [65.01785000000001, 1151.0, 461.80530000000005, 1176.0]}}
