# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle
import pandas as pd

df = pd.read_csv('../../raw_data/stats/ITS/total_stats_full.tsv', sep='\t', index_col=0)
# print(df)

with open('../../trees/ITS/tree_2/con_50_majrule.newick', 'r') as in_f:
    with open('../../trees/ITS/tree_2/mb_for_seaview.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for el in df.index:
                if el in line:
                    new_name = df['description'][el].replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                    line = line.replace(el, new_name)
            out_f.write(line)
            print(line)
            
### тут укореняла в seaview
# Out:
# ((JN998651.1 Paramecium polycaryum strain Khb7-20 18S ribosomal RNA gene partial sequence internal transcribed spacer 1 5.8S ribosomal RNA gene and internal transcribed spacer 2 complete sequence and 28S ribosomal RNA gene partial sequence macronuclear:0.168267,((((((((((CD11-9:0.0053623,(HSG3-10 ITS:0.00110002,SP-1:0.00109248)0.97:0.00250292):0,ShKm41:0.00106997):0,Paramecium multimicronucleatum TRB101-4 JF741231.1:0.00104298):0,Paramecium multimicronucleatum TRB101-1 JF741230.1:0.00104992)0.93:0.00248811,PO-16:0.00113455)1.00:0.00405256,Paramecium sp. C8-2 MN264574.1:0.0010626):0,Paramecium sp. V105-1 MN264572.1:0.00103806)1.00:0.0208235,((K5-2:0.00252556,Paramecium multimicronucleatum Kr113-3 JF741226.1:0.0010615)0.62:0.00317609,(Paramecium caudatum CA JF304170.1:0.00109903,Paramecium multimicronucleatum GB4-26 MN264569.1:0.00351889)0.74:0.00504408)1.00:0.030277)1.00:0.028873,(((((((strain14 PP-2:0.00106501,Paramecium multimicronucleatum AM MN264570.1:0.00106964):0,CyL3-21:0.00105
# ...

# %%
with open('../../trees/ITS/tree_2/mb_rooted.newick', 'r') as in_f:
    with open('../../trees/ITS/tree_2/mb_ete_tree.newick', 'w') as out_f:
        for line in in_f:
            line = line.strip()
            for ind, name in zip(df.index, df.description):
                # print(ind, name)
                name = name.lstrip(' ')
                name = name.replace(',', '').replace(';', '').replace(':', '').replace('(', '').replace(')', '')
                if name in line:
                    new_name = '"' + df['description'][ind] + '"'
                    line = line.replace(name, new_name)
                else:
                    print(name)
            out_f.write(line)
            print(line)
# Out:
# ((("Paramecium bursaria Ek JF708936.1":0.00341664,"Paramecium bursaria T316 JF708925.1":0.00426988)0.77:0.0107346,"Paramecium bursaria HZ75-5 JF708933.1":0.0271075):0.313521,("Paramecium putrinum ETu 7-4 MG573199.1":0.197061,(("JN998651.1 Paramecium polycaryum strain Khb7-20 18S ribosomal RNA gene, partial sequence; internal transcribed spacer 1, 5.8S ribosomal RNA gene, and internal transcribed spacer 2, complete sequence; and 28S ribosomal RNA gene, partial sequence; macronuclear":0.168267,(((((((((("CD11-9":0.0053623,("HSG3-10 ITS":0.00110002,"SP-1":0.00109248)0.97:0.00250292):0,"ShKm41":0.00106997):0,"Paramecium multimicronucleatum TRB101-4 JF741231.1":0.00104298):0,"Paramecium multimicronucleatum TRB101-1 JF741230.1":0.00104992)0.93:0.00248811,"PO-16":0.00113455)1.00:0.00405256,"Paramecium sp. C8-2 MN264574.1":0.0010626):0,"Paramecium sp. V105-1 MN264572.1":0.00103806)1.00:0.0208235,(("K5-2":0.00252556,"Paramecium multimicronucleatum Kr113-3 JF741226.1":0.0010615)0.62:0.00317609
# ...

# %%
from ete3 import Tree, faces, AttrFace, TreeStyle, NodeStyle

t = Tree('../../trees/ITS/tree_2/mb_ete_tree.newick', format=0, quoted_node_names=True)
# print(t)

for node in t.traverse():
    node.img_style['size'] = 0
    
for n in t.get_leaves():
    n.name = n.name[:70]
    
t.ladderize(direction=1)
ts = TreeStyle()
ts.show_branch_support = True
ts.scale =  1500
ts.branch_vertical_margin = 10
# ts.mode = "c"
t.show(tree_style=ts)
t.render('../../trees/ITS/tree_2/mb_ete_tree_.pdf', dpi=1200, tree_style=ts)
# Out:
# {'nodes': [],
#  'faces': [[1.0, 1939.5498046889552, 8.0, 1952.5498046889552, 0, '1'],
#   [25.75165, 1884.3496093779104, 32.75165, 1897.3496093779104, 1, '1'],
#   [101.53405000000001,
#    1830.1992187558208,
#    123.53405000000001,
#    1843.1992187558208,
#    2,
#    '0.99'],
#   [271.17055000000005,
#    1746.8984375116415,
#    278.17055000000005,
#    1759.8984375116415,
#    3,
#    '1'],
#   [321.04030000000006,
#    1605.296875023283,
#    343.04030000000006,
#    1618.296875023283,
#    4,
#    '0.81'],
#   [466.0606, 1365.8437500465661, 473.0606, 1378.8437500465661, 5, '1'],
#   [479.64565000000005,
#    1024.3886719681323,
#    501.64565000000005,
#    1037.3886719681323,
#    6,
#    '0.94'],
#   [551.6056000000001,
#    750.0234376862645,
#    558.6056000000001,
#    763.0234376862645,
#    7,
#    '1'],
#   [575.0554000000001,
#    638.500000372529,
#    582.0554000000001,
#    651.500000372529,
#    8,
#    '1'],
#   [582.0554000000001,
#    613.5000007450581,
# ...
